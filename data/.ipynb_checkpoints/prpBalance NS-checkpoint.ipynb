# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/RRRDP/"                
os.chdir(path)

# %%
dfsoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoS.columns = ['','Date','so_storage']
dfsoS.index = dfsoS['Date']
dfsoS = dfsoS.iloc[:,2:]

dfsogS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogS.columns = ['','Date','sog_storage']
dfsogS.index = dfsogS['Date']
dfsogS = dfsogS.iloc[:,2:]

dfptS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptS.columns = ['','Date','pt_storage']
dfptS.index = dfptS['Date']
dfptS = dfptS.iloc[:,2:]

dffaoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoS.columns = ['','Date','fao_storage']
dffaoS.index = dffaoS['Date']
dffaoS = dffaoS.iloc[:,2:]


dfsoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoROS.columns = ['','Date','so_runoff']
dfsoROS.index = dfsoROS['Date']
dfsoROS = dfsoROS.iloc[:,2:]

dfsogROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_KGE_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogROS.columns = ['','Date','sog_runoff']
dfsogROS.index = dfsogROS['Date']
dfsogROS = dfsogROS.iloc[:,2:]

dfptROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_PT_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptROS.columns = ['','Date','pt_runoff']
dfptROS.index = dfptROS['Date']
dfptROS = dfptROS.iloc[:,2:]

dffaoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_FAO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoROS.columns = ['','Date','fao_runoff']
dffaoROS.index = dffaoROS['Date']
dffaoROS = dffaoROS.iloc[:,2:]

dfObsS= pd.read_csv('data/RioRessi/1/RioRessi_Root.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsS.columns = ['','Date','obs_storage']
dfObsS.index = dfObsS['Date']
dfObsS = dfObsS.iloc[:,2:]

dfObsR= pd.read_csv('data/RioRessi/1/RioRessi_RUNOFF.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsR.columns = ['','Date','obs_runoff']
dfObsR.index = dfObsR['Date']
dfObsR = dfObsR.iloc[:,2:]

dfPrp= pd.read_csv('data/RioRessi/1/RioRessi_PRP.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfPrp.columns = ['','Date','prp']
dfPrp.index = dfPrp['Date']
dfPrp = dfPrp.iloc[:,2:]

dfso= pd.read_csv('data/RioRessi/1/RioRessi_ET_SOSt.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfso.columns = ['','Date','so_et']
dfso.index = dfso['Date']
dfso = dfso.iloc[:,2:]

dfsog = pd.read_csv('data/RioRessi/1/RioRessi_ET_SO_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsog.columns = ['','Date','sog_et']
dfsog.index = dfsog['Date']
dfsog = dfsog.iloc[:,2:]

dfpt= pd.read_csv('data/RioRessi/1/RioRessi_ET_PT126.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfpt.columns = ['','Date','pt_et']
dfpt.index = dfpt['Date']
dfpt = dfpt.iloc[:,2:]

dffao= pd.read_csv('data/RioRessi/1/RioRessi_ET_FAO.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffao.columns = ['','Date','fao_et']
dffao.index = dffao['Date']
dffao = dffao.iloc[:,2:]

# print(dfR.head(2))
# print(dfSt.head(2))
# print(dfEt.head(2))
# print(dfPrp.head(2))

# %%
dfsog.resample('Y').agg('sum')
# Out:
#                 sog_et
# Date
# 2012-12-31  171.654681
# 2013-12-31  472.902771
# 2014-12-31  436.622266
# 2015-12-31  526.693843
# 2016-12-31  484.748541
# 2017-12-31  558.054164
# 2018-12-31  491.140634
# 2019-12-31  127.102420

# %%
print(dfsoROS.head(3))
print(dfsogROS.head(3))
print(dfptROS.head(3))
print(dffaoROS.head(3))

# print(dfso.iloc[12432:,:].head(2))
# print(dfsog.iloc[12432:,:].head(2))
# Out:
#                      so_runoff
# Date
# 2014-01-01 00:00:00   0.000227
# 2014-01-01 01:00:00   0.000249
# 2014-01-01 02:00:00   0.000231
#                        sog_runoff
# Date
# 2014-01-01 00:00:00  1.245559e-10
# 2014-01-01 01:00:00  1.650393e-10
# 2014-01-01 02:00:00  1.679004e-10
#                      pt_runoff
# Date
# 2014-01-01 00:00:00   0.000169
# 2014-01-01 01:00:00   0.000189
# 2014-01-01 02:00:00   0.000172
#                        fao_runoff
# Date
# 2014-01-01 00:00:00  9.613060e-18
# 2014-01-01 01:00:00  1.092695e-17
# 2014-01-01 02:00:00  9.933847e-18

# %%
print(dfObsR.head(2))
print(dfPrp.iloc[12432:,:].head(2))
print(dfso.iloc[12432:,:].head(2))
print(dfsog.iloc[12432:,:].head(2))
print(dffao.iloc[12432:,:].head(2))
print(dfpt.iloc[12432:,:].head(2))
print(dfObsS.iloc[12432:,:].head(2))
print(dfsoS.head(2))
print(dfsogS.head(2))
print(dffaoS.head(2))
print(dfptS.head(2))
# Out:
#                      obs_runoff
# Date
# 2014-01-01 00:00:00    0.000858
# 2014-01-01 01:00:00    0.000850
#                      prp
# Date
# 2014-01-01 00:00:00  0.0
# 2014-01-01 01:00:00  0.0
#                      so_et
# Date
# 2014-01-01 00:00:00    NaN
# 2014-01-01 01:00:00    NaN
#                      sog_et
# Date
# 2014-01-01 00:00:00     NaN
# 2014-01-01 01:00:00     NaN
#                        fao_et
# Date
# 2014-01-01 00:00:00  0.010114
# 2014-01-01 01:00:00  0.010065
#                      pt_et
# Date
# 2014-01-01 00:00:00    0.0
# 2014-01-01 01:00:00    0.0
#                      obs_storage
# Date
# 2014-01-01 00:00:00     291.9405
# 2014-01-01 01:00:00     291.5100
#                      so_storage
# Date
# 2014-01-01 00:00:00  134.335339
# 2014-01-01 01:00:00  134.335339
#                      sog_storage
# Date
# 2014-01-01 00:00:00   172.098228
# 2014-01-01 01:00:00   172.149160
#                      fao_storage
# Date
# 2014-01-01 00:00:00   173.414028
# ...

# %%
df = pd.concat([dfObsR,dfPrp.iloc[12432:,:],dfso.iloc[12432:,:],dfsog.iloc[12432:,:],
                dfsoROS,dfsogROS,dfptROS,dffaoROS,
                dffao.iloc[12432:,:],dfpt.iloc[12432:,:], dfObsS.iloc[12432:,:],dfsoS,dfsogS,dffaoS,dfptS],axis=1)
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et  obs_storage  \
# Date
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0    291.94050
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0    291.51000
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0    291.23325
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0    290.80275
# 2014-01-01 04:00:00   0.000175  1.011714e-17  0.008917    0.0    290.43375
#
# ...

# %%
df.shape
# Out:
# (46944, 15)

# %%
df2=df.dropna(subset=['obs_runoff','so_runoff','sog_runoff','pt_runoff','fao_runoff','prp',
                     'obs_storage','so_storage','sog_storage','fao_storage','pt_storage'])

# %%
df2.shape
# Out:
# (27908, 15)

# %%
df2.iloc[:,:].tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.007814
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.007159
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.006740
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.006510
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.006429
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.009280   0.007706    0.005391  0.000290  0.000000
# 2017-12-12 08:00:00    0.008293   0.007032    0.004958  0.000224  0.000000
# 2017-12-12 09:00:00    0.007574   0.006651    0.004589  0.000186  0.000000
# 2017-12-12 10:00:00    0.006976   0.006503    0.004308  0.002708  0.003355
# 2017-12-12 11:00:00    0.006518   0.006536    0.004064  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# ...

# %%
df.tail()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff  sog_runoff  \
# Date
# 2019-05-10 19:00:00         NaN  NaN    0.0     0.0        NaN         NaN
# 2019-05-10 20:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 21:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 22:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 23:00:00         NaN  NaN    NaN     NaN        NaN         NaN
#
#                      pt_runoff  fao_runoff    fao_et     pt_et  obs_storage  \
# Date
# 2019-05-10 19:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 20:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 21:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 22:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 23:00:00        NaN         NaN  0.011843  0.000589          NaN
#
# ...

# %%
idf = pd.date_range('2014-01-01 00:00','2017-12-12 11:00',freq='1H')
# # 2017-12-12 11:00:00
df = df.reindex(idf)

# %%
df = df2
df3 = df2

# %%
df3.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.007814
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.007159
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.006740
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.006510
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.006429
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.009280   0.007706    0.005391  0.000290  0.000000
# 2017-12-12 08:00:00    0.008293   0.007032    0.004958  0.000224  0.000000
# 2017-12-12 09:00:00    0.007574   0.006651    0.004589  0.000186  0.000000
# 2017-12-12 10:00:00    0.006976   0.006503    0.004308  0.002708  0.003355
# 2017-12-12 11:00:00    0.006518   0.006536    0.004064  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# ...

# %%
df['obs_D_storage'] = df['obs_storage'].diff()
df['so_D_storage'] = df['so_storage'].diff()
df['sog_D_storage'] = df['sog_storage'].diff()
df['fao_D_storage'] = df['fao_storage'].diff()
df['pt_D_storage'] = df['pt_storage'].diff()
df['obs_mm_runoff'] = df['obs_runoff']*1000*3600/21930
df['so_mm_runoff'] = df['so_runoff']*1000*3600/21930
df['sog_mm_runoff'] = df['sog_runoff']*1000*3600/21930
df['pt_mm_runoff'] = df['pt_runoff']*1000*3600/21930
df['fao_mm_runoff'] = df['fao_runoff']*1000*3600/21930

# %%
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et      ...        \
# Date                                                               ...
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0      ...
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0      ...
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0      ...
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0      ...
# ...

# %%
df['residual_obs + et_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']
df['residual_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']- df['so_et']
df['residual_so'] = df['prp'] - df['so_mm_runoff'] - df['so_D_storage'] - df['so_et']
df['residual_sog'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage'] - df['sog_et']
df['residual_pt'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage'] - df['pt_et']
df['residual_fao'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage'] - df['fao_et']

# %%
dfMon = df.resample('1MS').agg('sum')
dfAnn = df.resample('1YS').agg('sum')

# %%
dfso.resample('1YS').agg('sum')
# Out:
#                  so_et
# Date
# 2012-01-01  243.433610
# 2013-01-01  676.688947
# 2014-01-01  615.741610
# 2015-01-01  754.605690
# 2016-01-01  686.587825
# 2017-01-01  797.666584
# 2018-01-01  693.603661
# 2019-01-01  184.172939

# %%
dfAnn
# Out:
#             obs_runoff     prp       so_et      sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01   10.985771  2659.6  613.861752  435.153854  12.317527   11.770462
# 2015-01-01    1.913841   808.2  476.979159  332.653075   2.925932    2.811980
# 2016-01-01    3.667234  1532.0  655.400515  461.831025   5.104403    5.270374
# 2017-01-01    1.675053  1090.4  486.415867  341.027683   2.366178    2.874133
#
#             pt_runoff  fao_runoff      fao_et       pt_et      ...       \
# Date                                                           ...
# 2014-01-01  12.862001   12.350659  450.347029  503.225470      ...
# 2015-01-01   3.626246    3.428927  292.851203  363.289747      ...
# 2016-01-01   6.276028    6.626923  398.554888  552.058491      ...
# 2017-01-01   3.371048    3.168280  156.592047  398.345034      ...
#
#             so_mm_runoff  sog_mm_runoff  pt_mm_runoff  fao_mm_runoff  \
# Date
# 2014-01-01   2022.028985    1932.223629   2111.409268    2027.467919
# ...

# %%
df[['residual_obs']].plot()
df[['residual_pt']].plot()

# %%
df.sum()
# Out:
# obs_runoff               1.824190e+01
# prp                      6.090200e+03
# so_et                    2.232657e+03
# sog_et                   1.570666e+03
# so_runoff                2.271404e+01
# sog_runoff               2.272695e+01
# pt_runoff                2.613532e+01
# fao_runoff               2.557479e+01
# fao_et                   1.298345e+03
# pt_et                    1.816919e+03
# obs_storage              7.560180e+06
# so_storage               4.994884e+06
# sog_storage              6.514061e+06
# fao_storage              6.421320e+06
# pt_storage               7.054559e+06
# obs_D_storage           -6.020700e+01
# so_D_storage             7.961249e+01
# sog_D_storage            9.756512e+01
# fao_D_storage            9.240370e+01
# pt_D_storage             1.064439e+02
# obs_mm_runoff            2.994566e+03
# so_mm_runoff             3.728707e+03
# sog_mm_runoff            3.730826e+03
# pt_mm_runoff             4.290340e+03
# fao_mm_runoff            4.198324e+03
# ...

# %%
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et      ...       \
# Date                                                               ...
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0      ...
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0      ...
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0      ...
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0      ...
# ...

# %%
dfDay = df.resample('1D').agg('sum')

# %%
dfDay.plot()

# %%
df2 = df

# %%
dfMon['month'] = pd.DatetimeIndex(dfMon.index).year#.month
dfMon['Date'] = dfMon.index

# %%
dfMon.head()
# Out:
#             obs_runoff    prp      so_et     sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01    1.429458    0.0  11.719283   8.817884   0.115043  1.582719e-07
# 2014-02-01    1.114175  220.0  18.958799  13.668465   1.325512  1.050736e+00
# 2014-03-01    0.824545  179.6  70.896314  49.182022   0.923722  7.571305e-01
# 2014-04-01    0.741807  261.0  65.303575  45.605552   0.651290  7.438187e-01
# 2014-05-01    0.597163  143.8  84.437723  58.891763   0.822160  7.556089e-01
#
#             pt_runoff    fao_runoff     fao_et      pt_et    ...      \
# Date                                                         ...
# 2014-01-01   0.094062  6.591783e-15  10.431780  10.024666    ...
# 2014-02-01   1.044203  5.487431e-01  14.770438  15.176535    ...
# 2014-03-01   0.994710  7.196488e-01  50.860102  51.793558    ...
# 2014-04-01   0.816970  7.897913e-01  44.877742  49.528728    ...
# 2014-05-01   0.908846  9.005097e-01  61.138770  68.733898    ...
#
# ...

# %%
dfM = dfMon[['so_et','prp','obs_mm_runoff','so_storage',]]#,'roA','tot']]
# dfMM = dfMon[['stMA','so','prpA','roMA']]#,'roA','tot']]
dfM.columns = ['ET','Rainfall','Runoff sim.','Storage sim.']
# dfMM.columns = ['ET','Rainfall','Runoff obs.','Storage obs.']

# %%
dfM['Date'] = dfM.index
# dfMM['Date'] = dfMM.index
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfM.head()
# Out:
#                    ET  Rainfall  Runoff sim.   Storage sim.       Date
# Date
# 2014-01-01  11.719283       0.0   234.658006   84012.544359 2014-01-01
# 2014-02-01  18.958799     220.0   182.901517  110145.206260 2014-02-01
# 2014-03-01  70.896314     179.6   135.356160  140831.650275 2014-03-01
# 2014-04-01  65.303575     261.0   121.773993  125847.086521 2014-04-01
# 2014-05-01  84.437723     143.8    98.029460  145153.885123 2014-05-01

# %%
dataM = dfM.melt(id_vars=['Date'], var_name='Components', value_name='Water budget')
# dataMM = dfMM.melt(id_vars=['Date'], var_name='Components', value_name='Water budget')

# %%
import seaborn as sns
import matplotlib.dates as mdates

# %% [markdown]
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
# fig = plt.figure()
# ax1 = fig.add_subplot(211)
# ax2 = fig.add_subplot(212)

# sns.catplot(ax = ax1, x="Date", y="Water budget", hue="Components", data=dataM,
#                         palette="Accent", edgecolor=".3", height=4, kind="bar", linewidth=3.5)
# sns.catplot(ax = ax2, x="Date", y="Water budget", hue="Components", data=dataMM,
#                         palette="BuGn", edgecolor=".3", height=10, kind="bar", linewidth=3.5)
# sns.set_context("paper", rc={"axes.labelsize":24})

# for ax in [ax1, ax2]:
# #     ax.set_ylim((-0.8E7,1.2E7))
#     ax.xaxis.set_major_locator(dates.YearLocator(1))    
#     ax.tick_params(axis='both', which='major', labelsize=24)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#     plt.setp(ax.get_legend().get_texts(), fontsize='16') # for legend text
#     plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title
    
# fig.set_size_inches(15,30)
# fig.autofmt_xdate()
# ax1.set_ylabel("Water budget [m3]",size = 24,color="k",alpha=1)
# ax2.set_ylabel("Water budget [m3]",size = 24,color="k",alpha=1)

# # fig.set_xticklabels(rotation=0)
# # g.set(xticklabels=[])
# # sns.tsplot(df, time='Date', value='Value', unit='Unit', ax=ax)

# # assign locator and formatter for the xaxis ticks.
# ax1.xaxis.set_major_locator(mdates.AutoDateLocator())
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y.%m.%d'))

# # put the labels at 45deg since they tend to be too long
# # fig.autofmt_xdate()

# %%
# dfMon['roAN'] = dfMon['roA']/abs(dfMon['totM'])
# dfMon['prpAN'] = dfMon['prpA']/abs(dfMon['totM'])
dfMon['so_et2'] = dfMon['so_et']/(dfMon['so_et']+dfMon['prp'])
# dfMon['roMAN'] = dfMon['roA']/abs(dfMon['roA']+dfMon['etA']-dfMon['stA'])
# dfMon['stAN'] = dfMon['stA']/abs(dfMon['totM'])
# dfMon['stMAN'] = dfMon['stMA']/abs(dfMon['totM'])

# %%
dfMon['so_et2'].plot()
# dfMon['tot'].plot()
# dfMon['roAN'].plot()
# dfMon['roMAN'].plot()

# %%
# from matplotlib.dates import YearLocator, MonthLocator, WeekdayLocator, DateFormatter

# %%
import datetime
import matplotlib.ticker as mticker

# %%
# import matplotlib.ticker as tkr
# dfMon[['stA','roA','prpA','etA','stMA','roMA','tot','totM']] = dfMon[['stA','roA','prpA','etA','stMA','roMA','tot','totM']]/1E6

# %%
# idx = pd.date_range('2013-01-01','2016-12-31',freq='6M')
idy = pd.date_range('2014-01-01','2017-12-12',freq='1MS')

# %%
# dfMon = dfMon.reindex(idy)
dfMon
# Out:
#             obs_runoff    prp       so_et     sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01    1.429458    0.0   11.719283   8.817884   0.115043  1.582719e-07
# 2014-02-01    1.114175  220.0   18.958799  13.668465   1.325512  1.050736e+00
# 2014-03-01    0.824545  179.6   70.896314  49.182022   0.923722  7.571305e-01
# 2014-04-01    0.741807  261.0   65.303575  45.605552   0.651290  7.438187e-01
# 2014-05-01    0.597163  143.8   84.437723  58.891763   0.822160  7.556089e-01
# 2014-06-01    0.141895  132.4   94.188117  66.351654   0.347945  3.188921e-01
# 2014-07-01    0.997382  401.4   82.466784  58.575440   1.184979  1.597640e+00
# 2014-08-01    0.771021  261.4   66.368406  47.514773   1.160610  1.046377e+00
# 2014-09-01    0.253743   57.0   53.471250  38.416125   0.594917  4.336280e-01
# 2014-10-01    0.432284  207.4   39.673192  28.310840   0.719666  7.822160e-01
# 2014-11-01    2.856556  616.2   12.418325   9.469947   3.230909  3.248566e+00
# ...

# %%
# idx = idx.strftime('%Y-%m')
dfMon['Data'] = idy
dfMon['Data'] = pd.to_datetime(dfMon['Data'], dayfirst=True)
dfMon['Data'] = dfMon['Data'].dt.strftime('%Y-%m')
dfMon.index = dfMon['Data']

# %%
dfMon
# Out:
#          obs_runoff    prp       so_et     sog_et  so_runoff    sog_runoff  \
# Data
# 2014-01    1.429458    0.0   11.719283   8.817884   0.115043  1.582719e-07
# 2014-02    1.114175  220.0   18.958799  13.668465   1.325512  1.050736e+00
# 2014-03    0.824545  179.6   70.896314  49.182022   0.923722  7.571305e-01
# 2014-04    0.741807  261.0   65.303575  45.605552   0.651290  7.438187e-01
# 2014-05    0.597163  143.8   84.437723  58.891763   0.822160  7.556089e-01
# 2014-06    0.141895  132.4   94.188117  66.351654   0.347945  3.188921e-01
# 2014-07    0.997382  401.4   82.466784  58.575440   1.184979  1.597640e+00
# 2014-08    0.771021  261.4   66.368406  47.514773   1.160610  1.046377e+00
# 2014-09    0.253743   57.0   53.471250  38.416125   0.594917  4.336280e-01
# 2014-10    0.432284  207.4   39.673192  28.310840   0.719666  7.822160e-01
# 2014-11    2.856556  616.2   12.418325   9.469947   3.230909  3.248566e+00
# ...

# %%
import calendar
import matplotlib.dates as mdates

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao', 'month', 'Date', 'so_et2', 'Data'],
#       dtype='object')

# %%
fig, ax = plt.subplots(nrows = 2, ncols =1,figsize=(20,20))
ax11 = ax[0]
ax12 = ax[1]
#  xticks=dfMon.index,
# dfMon.plot(x = 'Data',y=['tot'],ax=ax11,kind='bar', edgecolor=".3",linewidth=3.5,
#            color="r",label = ['Error'],rot = -0,stacked=True)
dfMon.plot(x = 'Data',y=['residual_obs','obs_D_storage','obs_mm_runoff','prp','so_et'],ax=ax11,kind='bar', edgecolor=".3",linewidth=1.5,
           colormap="Dark2",label = ['tot','Storage sim.','Runoff sim.','Rainfall','ET'],rot = -0,stacked=True)

# dfMon.plot(ax=ax12,kind='bar',y=['totM'], edgecolor=".3",linewidth=3.5,
#            color="r",label = ['Error'],rot = -0,stacked=True)
# dfMon.plot(ax=ax12,kind='bar',y=['totM','stMA','roMA','prpA','etA'], edgecolor=".3",linewidth=3.5,
#            colormap="Dark2",
#            label = ['totM','Storage obs.','Runoff obs.','Rainfall','ET'],rot = -0,stacked=True) 

# ax11.set_xlim([datetime.date(2013, 1, 1), datetime.date(2016,11,23)])
for ax in [ax11, ax12]:
#     ax.set_ylim([-10,20])
#     ax.set_xlim([datetime.date(2013, 1, 1), datetime.date(2016,11,23)])
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Water budget',fontsize=20)
    ax.set_xlabel('Date',fontsize=20)


ticklabels = ['']*len(dfMon)
skip = len(dfMon)//7
ticklabels[::skip] = dfMon['Date'].iloc[::skip].dt.strftime('%Y-%m')
ax11.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
fig.autofmt_xdate(rotation=0)
ax12.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))



def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# ax11.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ax11.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
len(dfMon)//8
# Out:
# 6

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
# 'tot_so','soStA','roA','prp','so'
dfMon.plot(x='Data',y=['residual_so','so_D_storage','so_mm_runoff','so_et'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,
#            colormap="GnBu",alpha=0.5,
           label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
ax.legend(loc='lower left',fontsize=20)

ax.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall',
        color='k',linewidth = 1)

ax.set_ylim([-400,800])

for ax in [ax]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    ax.set_ylabel('Simulated water budget [mm]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ax.set_ylim([-300,700])
for ax in [ax]: 
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ticklabels = ['']*len(dfMon)
skip = len(dfMon)//8
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
fig.autofmt_xdate(rotation=45)
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

plt.title("Simulated", size=30, family='DejaVu Sans');               

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
# 'tot_so','soStA','roA','prp','so'
dfMon.plot(x='Data',y=['residual_sog','sog_D_storage','sog_mm_runoff','sog_et'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,
#            colormap="GnBu",alpha=0.5,
           label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
ax.legend(loc='lower left',fontsize=20)

ax.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall',
        color='k',linewidth = 1)

ax.set_ylim([-400,800])

for ax in [ax]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    ax.set_ylabel('Simulated water budget [mm]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ax.set_ylim([-300,700])
for ax in [ax]: 
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ticklabels = ['']*len(dfMon)
skip = len(dfMon)//8
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
fig.autofmt_xdate(rotation=0)
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

plt.title("Simulated - Forest with grass", size=30, family='DejaVu Sans');               

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# %%
plt.style.use('default')


fig, ax = plt.subplots(nrows = 4, ncols =1,figsize=(30,60))
ax11 = ax[0]
ax12 = ax[1]
ax21 = ax[2]
ax22 = ax[3]

dfMon.plot(x='Data',y=['residual_so','so_D_storage','so_mm_runoff','so_et'],kind='bar', ax = ax11,  edgecolor=".3",linewidth=1.5,
#            title='GEOframe - Forest',labelsize=40,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)

dfMon.plot(x='Data',y=['residual_sog','sog_D_storage','sog_mm_runoff','sog_et'],kind='bar', ax = ax12,  edgecolor=".3",linewidth=1.5,
#            title='GEOframe - Forest/Grass',fontsize=20,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)

dfMon.plot(y=['residual_obs + et_obs','obs_D_storage','obs_mm_runoff'],kind='bar', ax = ax21,  edgecolor=".3",linewidth=1.5,
#            title='Observed',fontsize=20,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual+ET','Storage obs.','Runoff obs.'],rot = -0,stacked=True)

dfMon.plot(x='Data',y=['residual_pt','pt_D_storage','pt_mm_runoff','pt_et'],kind='bar', ax = ax22,  edgecolor=".3",linewidth=1.5,
#            title='Priestley-Taylor',fontsize=20,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
# ax.legend(loc='lower left',fontsize=20)

ax11.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
ax12.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
ax21.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
ax22.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)

# ax.set_ylim([-400,800])
ticklabels = ['']*len(dfMon)
skip = len(dfMon)//4
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')

for ax in [ax11, ax12, ax21, ax22]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
#     ax.set_ylabel('Simulated water budget [mm]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
#     ax.legend(loc='upper right',fontsize=20)
    ax.set_ylim([-300,700])
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=20)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

ax11.set_title('GEOframe - Forest', fontdict={'fontsize': 30, 'fontweight': 'medium'})
ax12.set_title('GEOframe - Forest/Grass', fontdict={'fontsize':30, 'fontweight': 'medium'})
ax21.set_title('Observed', fontdict={'fontsize': 30, 'fontweight': 'medium'})
ax22.set_title('Priestley-Taylor', fontdict={'fontsize':30, 'fontweight': 'medium'})
# ax12.set_ylim([-300,700])
# ax21.set_ylim([-300,700])
# ax22.set_ylim([-300,700])

ax11.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
ax12.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
ax22.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
ax21.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)

# for ax in [ax11, ax12, ax21, ax22]:
#     ax.tick_params(axis='both', which='major', labelsize=25)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
#     ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
#     ax.set_xlabel('',fontsize=30)
   

fig.autofmt_xdate(rotation=0)

# plt.title("Simulated - Forest with grass", size=30, family='DejaVu Sans');               

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao', 'month', 'Date', 'so_et2', 'Data'],
#       dtype='object')

# %%
dfETT = dfMon[['Data','residual_obs + et_obs','so_et','sog_et','fao_et','pt_et','residual_so','residual_sog','residual_fao','residual_pt']]

# %%
dfETT['soet+r']= dfETT['so_et']+dfETT['residual_so']
dfETT['soget+r']= dfETT['sog_et']+dfETT['residual_sog']
dfETT['faoet+r']= dfETT['fao_et']+dfETT['residual_fao']
dfETT['ptet+r']= dfETT['pt_et']+dfETT['residual_pt']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.style.use('default')


fig, ax = plt.subplots(nrows = 3, ncols =1,figsize=(30,20))
ax11 = ax[0]
ax12 = ax[1]
ax21 = ax[2]
# ax22 = ax[3]
# ax11 = ax[0][0]
# ax12 = ax[0][1]
# ax21 = ax[1][0]
# ax22 = ax[1][1]

dfMon.plot(x='Data',y=['obs_mm_runoff','so_mm_runoff','sog_mm_runoff','pt_mm_runoff'],kind='bar', ax = ax11,  
           edgecolor=".3",linewidth=1.5,colormap='Blues',
           alpha=0.5,label = ['obs_mm_runoff','so_mm_runoff','sog_mm_runoff','pt_mm_runoff'],rot = -0,stacked=False)

# dfMon.plot(x='Data',y=['residual_so','so_D_storage','so_mm_runoff','so_et'],kind='bar', ax = ax11,  edgecolor=".3",linewidth=1.5,
# #            title='GEOframe - Forest',labelsize=40,
#            color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
dfMon.plot(x='Data',y=['obs_D_storage','so_D_storage','sog_D_storage','pt_D_storage'],kind='bar', ax = ax12,  
           edgecolor=".3",linewidth=1.5,colormap='Oranges',
           alpha=0.5,label = ['obs_D_storage','so_D_storage','sog_D_storage','pt_D_storage'],rot = -0,stacked=False)

dfETT.plot(x='Data',y=['residual_obs + et_obs','soet+r','soget+r','faoet+r','ptet+r'],kind='bar', ax = ax21,  
           edgecolor=".3",linewidth=1.5,colormap='Greens',
           alpha=0.5,label = ['residual_obs + et_obs','soet+r','soget+r','faoet+r','ptet+r'],rot = -0,stacked=False)

# dfMon.plot(x='Data',y=['obs_mm_runoff','so_mm_runoff','sog_mm_runoff','pt_mm_runoff'],kind='bar', ax = ax22,  
#            edgecolor=".3",linewidth=1.5,color=['crimson','peru','cornflowerblue','forestgreen'],
#            alpha=0.5,label = ['obs_mm_runoff','so_mm_runoff','sog_mm_runoff','pt_mm_runoff'],rot = -0,stacked=False)


# dfMon.plot(x='Data',y=['residual_sog','sog_D_storage','sog_mm_runoff','sog_et'],kind='bar', ax = ax12,  edgecolor=".3",linewidth=1.5,
# #            title='GEOframe - Forest/Grass',fontsize=20,
#            color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)

# dfMon.plot(y=['residual_obs + et_obs','obs_D_storage','obs_mm_runoff'],kind='bar', ax = ax21,  edgecolor=".3",linewidth=1.5,
# #            title='Observed',fontsize=20,
#            color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual+ET','Storage obs.','Runoff obs.'],rot = -0,stacked=True)

# dfMon.plot(x='Data',y=['residual_pt','pt_D_storage','pt_mm_runoff','pt_et'],kind='bar', ax = ax22,  edgecolor=".3",linewidth=1.5,
# #            title='Priestley-Taylor',fontsize=20,
#            color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
# ax.legend(loc='lower left',fontsize=20)

# ax11.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
# ax12.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
# ax21.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)
# ax22.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall', color='k',linewidth = 1)

# ax.set_ylim([-400,800])
ticklabels = ['']*len(dfMon)
skip = len(dfMon)//4
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')

for ax in [ax11, ax12, ax21]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
#     ax.set_ylabel('Simulated water budget [mm]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
#     ax.legend(loc='upper right',fontsize=20)
#     ax.set_ylim([-300,700])
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=20)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

# ax11.set_title('GEOframe - Forest', fontdict={'fontsize': 30, 'fontweight': 'medium'})
# ax12.set_title('GEOframe - Forest/Grass', fontdict={'fontsize':30, 'fontweight': 'medium'})
# ax21.set_title('Observed', fontdict={'fontsize': 30, 'fontweight': 'medium'})
# ax22.set_title('Priestley-Taylor', fontdict={'fontsize':30, 'fontweight': 'medium'})
# ax12.set_ylim([-300,700])
# ax21.set_ylim([-300,700])
# ax22.set_ylim([-300,700])

# ax11.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
# ax21.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)

# for ax in [ax11, ax12, ax21, ax22]:
#     ax.tick_params(axis='both', which='major', labelsize=25)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
#     ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
#     ax.set_xlabel('',fontsize=30)
   

fig.autofmt_xdate(rotation=0)

# plt.title("Simulated - Forest with grass", size=30, family='DejaVu Sans');               

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
skip = len(dfMon)//4
print(skip)
# Out:
# 12

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
# 'tot_so','soStA','roA','prp','so'
dfMon.plot(x='Data',y=['residual_so','obs_D_storage','obs_mm_runoff','so_et'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,
#            colormap="GnBu",alpha=0.5,
           label = ['Residual','Storage sim.','Runoff sim.','ET'],rot = -0,stacked=True)
ax.legend(loc='lower left',fontsize=20)

ax.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall',
        color='k',linewidth = 1)

ax.set_ylim([-400,800])

for ax in [ax]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    ax.set_ylabel('Simulated water budget [mm]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
    

ax.legend(loc='upper right',fontsize=20)

ax.set_ylim([-300,700])
for ax in [ax]: 
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ticklabels = ['']*len(dfMon)
skip = len(dfMon)//8
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
fig.autofmt_xdate(rotation=0)
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

plt.title("Simulated", size=30, family='DejaVu Sans');               

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
dfMon.plot(y=['residual_obs + et_obs','obs_D_storage','obs_mm_runoff'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           color=['crimson','peru','cornflowerblue','forestgreen'],alpha=0.5,

#            colormap="GnBu",alpha=0.5,
           label = ['Residual+ET','Storage obs.','Runoff obs.'],rot = -0,stacked=True)
ax.legend(loc='lower left',fontsize=20)

ax.bar(dfMon.index,+dfMon['prp'], 0.1,label = 'Rainfall',
        color='k',linewidth = 1)

ax.set_ylim([-300,700])
for ax in [ax]: 
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Water budget [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

ticklabels = ['']*len(dfMon)
skip = len(dfMon)//8
ticklabels[5::skip] = dfMon['Date'].iloc[5::skip].dt.strftime('%Y-%m')
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
fig.autofmt_xdate(rotation=0)
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

plt.title("Observed", size=30, family='DejaVu Sans');               


def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# %%
dfMon.head()
# Out:
#          obs_runoff    prp      so_et     sog_et  so_runoff    sog_runoff  \
# Data
# 2014-01    1.429458    0.0  11.719283   8.817884   0.115043  1.582719e-07
# 2014-02    1.114175  220.0  18.958799  13.668465   1.325512  1.050736e+00
# 2014-03    0.824545  179.6  70.896314  49.182022   0.923722  7.571305e-01
# 2014-04    0.741807  261.0  65.303575  45.605552   0.651290  7.438187e-01
# 2014-05    0.597163  143.8  84.437723  58.891763   0.822160  7.556089e-01
#
#          pt_runoff    fao_runoff     fao_et      pt_et   ...     \
# Data                                                     ...
# 2014-01   0.094062  6.591783e-15  10.431780  10.024666   ...
# 2014-02   1.044203  5.487431e-01  14.770438  15.176535   ...
# 2014-03   0.994710  7.196488e-01  50.860102  51.793558   ...
# 2014-04   0.816970  7.897913e-01  44.877742  49.528728   ...
# 2014-05   0.908846  9.005097e-01  61.138770  68.733898   ...
#
#          residual_obs + et_obs  residual_obs  residual_so  residual_sog  \
# ...

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# dfMon.plot(x='Data',y=['residual_so'],kind='bar', ax = ax, edgecolor=".3",linewidth=1.5,
#            color="r",label = ['Error'],rot = -0,stacked=True)
dfMon.plot(x='Data',y=['so_D_storage','obs_mm_runoff','prp','so_et','residual_so'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           colormap="Dark2",label = ['Storage sim.','Runoff sim.','Rainfall','ET','residual_so'],rot = -0,stacked=True)

for ax in [ax]:
#     ax.set_ylim([-10,20])
#     ax.set_xlim([datetime.date(2013, 1, 1), datetime.date(2016,11,23)])
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    ax.set_ylabel('Simulated water budget [Mm3]',fontsize=20)
    ax.set_xlabel('Date',fontsize=20)

ax.legend(loc='upper right',fontsize=15)

# ticklabels = ['']*len(dfMon)
# skip = len(dfMon)//8
# ticklabels[3::skip] = dfMon['Date'].iloc[3::skip].dt.strftime('%Y-%m')
# ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
# fig.autofmt_xdate(rotation=0)


# def fmt(x, pos=0, max_i=len(ticklabels)-1):
#     i = int(x) 
#     i = 0 if i < 0 else max_i if i > max_i else i
#     return dates[i]
# ax.fmt_xdata = fmt
ticklabelsY = ['', '', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabelsY))
fig.autofmt_xdate(rotation=0)


def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt


# plt.grid(On)

# %%
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)

dfMon.plot(x='Data',y=['residual_obs'],kind='bar', ax = ax, edgecolor=".3",linewidth=1.5,
           color="r",label = ['Error'],rot = -0,stacked=True)
dfMon.plot(x='Data',y=['obs_D_storage','so_mm_runoff','prp','so_et'],kind='bar', ax = ax,  edgecolor=".3",linewidth=1.5,
           colormap="Dark2",label = ['Storage obs.','Runoff obs.','Rainfall','ET'],rot = -0,stacked=True)

for ax in [ax]:
    ax.set_ylim([-10,20])
#     ax.set_xlim([datetime.date(2013, 1, 1), datetime.date(2016,11,23)])
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    ax.set_ylabel('Measured water budget [Mm3]',fontsize=30)
    ax.set_xlabel('Date',fontsize=30)
ax.legend(loc='upper right',fontsize=20)

ticklabelsY = ['','', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabelsY))
fig.autofmt_xdate(rotation=0)


def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt
# ticklabels = ['']*len(dfMon)
# skip = len(dfMon)//8
# ticklabels[3::skip] = dfMon['Date'].iloc[3::skip].dt.strftime('%Y-%m')
# ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
# fig.autofmt_xdate(rotation=0)


# def fmt(x, pos=0, max_i=len(ticklabels)-1):
#     i = int(x) 
#     i = 0 if i < 0 else max_i if i > max_i else i
#     return dates[i]
# ax.fmt_xdata = fmt

# %%
dfMon['ET%'] =dfMon['so_et']/( dfMon['prp'])
dfMon['prp%'] =1 - dfMon['ET%'] #dfMon['prpA']/(dfMon['etA']+ dfMon['prpA'])

dfMon[['ET%','prp%']].plot(kind='bar',stacked=True)

# %%
dfAnn.head()
# Out:
#             obs_runoff     prp       so_et      sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01   10.985771  2659.6  613.861752  435.153854  12.317527   11.770462
# 2015-01-01    1.913841   808.2  476.979159  332.653075   2.925932    2.811980
# 2016-01-01    3.667234  1532.0  655.400515  461.831025   5.104403    5.270374
# 2017-01-01    1.675053  1090.4  486.415867  341.027683   2.366178    2.874133
#
#             pt_runoff  fao_runoff      fao_et       pt_et      ...       \
# Date                                                           ...
# 2014-01-01  12.862001   12.350659  450.347029  503.225470      ...
# 2015-01-01   3.626246    3.428927  292.851203  363.289747      ...
# 2016-01-01   6.276028    6.626923  398.554888  552.058491      ...
# 2017-01-01   3.371048    3.168280  156.592047  398.345034      ...
#
#             so_mm_runoff  sog_mm_runoff  pt_mm_runoff  fao_mm_runoff  \
# Date
# 2014-01-01   2022.028985    1932.223629   2111.409268    2027.467919
# ...

# %%
# ticklabels = ['']*len(dfMon)
ticklabelsY = ['2012', '', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
               
print(ticklabelsY)
# Out:
# ['2012', '', '', '', '', '2013', '', '', '', '', '', '', '', '', '', '', '', '2014', '', '', '', '', '', '', '', '', '', '', '', '2015', '', '', '', '', '', '', '', '', '', '', '', '2016', '', '', '', '', '', '', '', '', '', '']

# %%
DF = dfMon[['ET%','prp%']]
DF[DF>1]=1
DF[DF<0]=0
DF
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)

DF.plot(y=['ET%'],kind='bar', ax = ax,  edgecolor=".3",
        alpha=0.5,   
        linewidth=1.5,
           color=['g'],label = ['ET'],rot = -0,stacked=True)

for ax in [ax]:
    ax.set_ylim([-0,1.01])
#     ax.set_xlim([datetime.date(2013, 1, 1), datetime.date(2016,11,23)])
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    ax.set_ylabel('Ratio ET- Rainfall',fontsize=30)
    ax.set_xlabel('Date',fontsize=30)

ax.legend(loc='upper right',fontsize=20)

# ticklabels = ['']*len(dfMon)
# ticklabelsY = ['']*(12)

# skip = len(dfMon)//8
# ticklabels[3::skip] = dfMon['Date'].iloc[3::skip].dt.strftime('%m')
# ticklabelsY[::12] = dfMon['Date'].iloc[::1].dt.strftime('%Y')
# ax.xaxis.set_minor_formatter(mticker.FixedFormatter(ticklabels))
ticklabelsY = ['', '', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabelsY))
fig.autofmt_xdate(rotation=0)


def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax.fmt_xdata = fmt

# %%
dfF = dfMon[['ET%']]
dfF.head()
# Out:
#               ET%
# Data
# 2014-01       inf
# 2014-02  0.086176
# 2014-03  0.394746
# 2014-04  0.250205
# 2014-05  0.587189

# %%
# df[df ==-9999]=np.nan
dfF[dfF > 1] = 1
dfF.head()
dfF.mean()
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# ET%    0.549031
# dtype: float64

# %%
dfAnn.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao'],
#       dtype='object')

# %%
df11 = dfso.resample('1YS').agg('sum')
df21 = dfsog.resample('1YS').agg('sum')
df31 = dffao.resample('1YS').agg('sum')
df41 = dfpt.resample('1YS').agg('sum')
df51 = dfPrp.resample('1YS').agg('sum')
df61 = df['residual_obs + et_obs'].resample('1YS').agg('sum')

print(df11)
print(df21)
print(df31)
print(df41)
print(df51)
print(df61)
# Out:
#                  so_et
# Date
# 2012-01-01  243.433610
# 2013-01-01  676.688947
# 2014-01-01  615.741610
# 2015-01-01  754.605690
# 2016-01-01  686.587825
# 2017-01-01  797.666584
# 2018-01-01  693.603661
# 2019-01-01  184.172939
#                 sog_et
# Date
# 2012-01-01  171.654681
# 2013-01-01  472.902771
# 2014-01-01  436.622266
# 2015-01-01  526.693843
# 2016-01-01  484.748541
# 2017-01-01  558.054164
# 2018-01-01  491.140634
# 2019-01-01  127.102420
#                 fao_et
# Date
# 2012-01-01  124.617873
# 2013-01-01  435.726512
# 2014-01-01  451.615860
# 2015-01-01  495.551581
# 2016-01-01  415.497298
# 2017-01-01  366.931582
# 2018-01-01  522.292308
# 2019-01-01  129.538469
#                  pt_et
# Date
# 2012-01-01  117.468980
# 2013-01-01  524.308696
# 2014-01-01  504.607041
# 2015-01-01  592.329734
# 2016-01-01  575.983872
# 2017-01-01  649.783290
# 2018-01-01  592.254333
# 2019-01-01  120.527458
#                     prp
# Date
# 2012-01-01   302.400000
# ...

# %%
dfprpet = pd.concat([df11,df21,df31,df41,df51,df61],axis=1)
# dfprpet['Date'] = dfprpet.index

# %%
dfprpet
# Out:
#                  so_et      sog_et      fao_et       pt_et          prp  \
# Date
# 2012-01-01  243.433610  171.654681  124.617873  117.468980   302.400000
# 2013-01-01  676.688947  472.902771  435.726512  524.308696   554.500000
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.000000
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.800000
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.800000
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.400000
# 2018-01-01  693.603661  491.140634  522.292308  592.254333   947.066667
# 2019-01-01  184.172939  127.102420  129.538469  120.527458    72.316667
#
#             residual_obs + et_obs
# Date
# 2012-01-01                    NaN
# 2013-01-01                    NaN
# 2014-01-01             852.677846
# 2015-01-01             520.411875
# 2016-01-01             960.606104
# 2017-01-01             822.285695
# 2018-01-01                    NaN
# ...

# %%
dfprpet.index
# Out:
# DatetimeIndex(['2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='Date', freq='AS-JAN')

# %%
dfprpet = dfprpet.iloc[2:6,:]

# %%
dfprpet.head()
# Out:
#                  so_et      sog_et      fao_et       pt_et     prp  \
# Date
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.0
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.8
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.8
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.4
#
#             residual_obs + et_obs
# Date
# 2014-01-01             852.677846
# 2015-01-01             520.411875
# 2016-01-01             960.606104
# 2017-01-01             822.285695

# %%
years = mdates.YearLocator()
dfprpet.index = dfprpet.index.strftime('%Y')
# years_fmt = mdates.DateFormatter('%Y')
dfprpet.index
# Out:
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
dfprpet['ET%'] =dfprpet['so_et']/( dfprpet['prp'])
dfprpet['prp%'] =1# - dfprpet['ET%'] #dfMon['prpA']/(dfMon['etA']+ dfMon['prpA'])

dfprpet[['ET%','prp%']].plot(kind='bar',stacked=False)
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.style.use('default')
fig = plt.figure(figsize=(30,15))
ax = fig.add_subplot(111)
axy = ax.twinx()


dfprpet.plot(y=['so_et','sog_et','fao_et','pt_et','residual_obs + et_obs','prp'],kind='bar', ax = ax, 
             colormap='GnBu',edgecolor=".3",linewidth=1.5, rot = -0,stacked=False,
             label = ['GEO ET','GEO ET F/G','FAO ET','PT ET','Obs ET+$\Delta$','PRP'])

dfprpet.plot(y=['ET%'],kind='line', ax = axy, label = ['%ET GEOframe'],color='r',linewidth=5, rot = -0,stacked=False)
axy.set_ylim([0,1])
ax.set_ylim([-1,3000])
ax.set_ylabel('ET-PRP [mm]',fontsize=30)
ax.set_xlabel('Date',fontsize=30)
ax.legend(loc='upper center',fontsize=30, ncol=3,handleheight=1, labelspacing=0.05)             
axy.legend(loc='upper right',fontsize=30,handleheight=5)    
plt.grid(True)
for ax in [ ax,axy]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    # ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
#     ax.legend(loc='upper right',fontsize=20)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20,20))
ax11 = axes[0]
# ax21 = ax11.twinx()
ax12 = axes[1]
# ax22 = ax12.twinx()
################################################################################
dfAnn.plot(ax=ax11,kind='bar',y=['obs_D_storage','prp','so_et'], stacked=True,linewidth=1, 
           label=['storage','prp','et'],rot = -0)#,       title='Runoff - GEOframe ET', color=['k','r'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','soCum'], ax=ax21,linewidth=2, label=['Obs','Sim'],rot = -0,
#          title='Runoff - GEOframe ET', color=['b','c'],alpha = 1)
################################################################################
dfAnn.plot(ax=ax12,kind='bar',y=['so_D_storage','prp','so_et'], stacked=True,linewidth=1, 
           label=['storage','prp','et'],rot = -0)
# df2.plot(kind='line', y=['obsCum','ptCum'], ax=ax22,linewidth=2, label=['Obs','Sim'],rot = -0,
#          title='Runoff - Priestley-Taylor ET', color=['b','c'],alpha = 1)
################################################################################
ax11.legend(loc='upper left',fontsize=15)
# for ax in [ax11, ax12]:
#     ax.set_ylim([0,0.12])
#     ax.set_ylabel('Runoff [l/s]',fontsize=20)
# #     ax.set_xlabel('Date',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  

# for ax in [ ax21,ax22]:
#     ax.set_ylim([0,20])
#     ax.set_ylabel('Cumulated Runoff [m3]',fontsize=20)
#     ax.set_xlabel('Date',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    
   
# # fig.add_subplot(111, frameon=False);
# plt.grid(False)
# plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
# # plt.ylabel("Runoff \n \n", size=20, family='DejaVu Sans');       
# # plt.xlabel("Date", size=20, family='DejaVu Sans');               
# plt.title("Rio Ressi \n", size=24, family='DejaVu Sans');

#plt.tight_layout()

# %%
df.plot()

# %%
df2.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df2.plot(ax=ax1, y=['so_runoff','sog_runoff','pt_runoff','fao_runoff','obs_runoff'],kind='line', stacked=False, 
                  label=['so_runoff','sog_runoff','pt_runoff','fao_runoff','obs_runoff'],linewidth=2)#,'El + err','El + bow'],

# %%
# fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20,20))
# ax11 = axes[0]
# ax21 = ax11.twinx()
# ax12 = axes[1]
# ax22 = ax12.twinx()
# ################################################################################
# df2.plot(kind='line', y=['obs','so'], ax=ax11,linewidth=1, label=['Obs','Sim'],rot = -0,
#          title='Runoff - GEOframe ET', color=['k','r'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','soCum'], ax=ax21,linewidth=2, label=['Obs','Sim'],rot = -0,
#          title='Runoff - GEOframe ET', color=['b','c'],alpha = 1)
# ################################################################################
# df2.plot(kind='line', y=['obs','pt'], ax=ax12,linewidth=1, label=['Obs','Sim'],rot = -0,
#           color=['k','r'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','ptCum'], ax=ax22,linewidth=2, label=['Obs','Sim'],rot = -0,
#          title='Runoff - Priestley-Taylor ET', color=['b','c'],alpha = 1)
# ################################################################################
# ax11.legend(loc='upper left',fontsize=15)
# for ax in [ax11, ax12]:
#     ax.set_ylim([0,0.12])
#     ax.set_ylabel('Runoff [l/s]',fontsize=20)
# #     ax.set_xlabel('Date',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  

# for ax in [ ax21,ax22]:
#     ax.set_ylim([0,20])
#     ax.set_ylabel('Cumulated Runoff [m3]',fontsize=20)
#     ax.set_xlabel('Date',fontsize=20)
# #     ax.tick_params(axis='both', which='major', labelsize=20)
# #     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    
   
# # # fig.add_subplot(111, frameon=False);
# # plt.grid(False)
# # plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
# # # plt.ylabel("Runoff \n \n", size=20, family='DejaVu Sans');       
# # # plt.xlabel("Date", size=20, family='DejaVu Sans');               
# # plt.title("Rio Ressi \n", size=24, family='DejaVu Sans');

# #plt.tight_layout()

# %%
# fig, ax = plt.subplots(figsize=(20,10))
# ax11 = ax
# ax21 = ax.twinx()
# ################################################################################
# df2.plot(kind='line', y=['obs','so'],linewidth=2, ax = ax11, label=['Runoff Obs','Runoff Sim'],rot = -0,
#          color=['k','r'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','soCum'],linewidth=3, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#          color=['b','c'],alpha = 1)
# ################################################################################
# ax.legend(loc='upper left',fontsize=15)
# ax21.legend(loc='upper right',fontsize=15)

# # ax11.legend(loc='upper left',fontsize=15)
# for ax in [ax11]:
#     ax.set_ylim([0,0.08])
#     ax.set_ylabel('Runoff [l/s]',fontsize=20)
#     ax.set_xlabel('Date',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    

# for ax in [ax21]:
#     ax.set_ylim([0,14])
#     ax.set_ylabel('Cumulated Runoff [m3]',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    
# plt.title("Runoff - GEOframe ET", size=20, family='DejaVu Sans');

# %%
# df3 = df2

# %%
# df2 = df3

# %%
# df2[df2==-9999]=np.nan

# %%
os.getcwd()
# Out:
# '/home/drugo/Sim/RRRDP'

# %%
f=open('output/EFC-luca_15_RioRessi_SO_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_so = lines[293]
b_so = a_so[40:-1]
b_so = float(b_so)
b_so
# Out:
# 0.7560677365461426

# %%
f=open('output/EFC-luca_15_RioRessi_PT_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_pt = lines[293]
b_pt = a_pt[40:-1]
b_pt = float(b_pt)
b_pt
# Out:
# 0.7536621925728755

# %%
f=open('output/EFC-luca_15_RioRessi_FAO_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_fao = lines[293]
b_fao = a_fao[40:-1]
b_fao = float(b_fao)
b_fao
# Out:
# 0.753644864680661

# %%
df2.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et      ...       \
# Date                                                               ...
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0      ...
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0      ...
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0      ...
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0      ...
# ...

# %%
df2.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.007814
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.007159
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.006740
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.006510
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.006429
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.009280   0.007706    0.005391  0.000290  0.000000
# 2017-12-12 08:00:00    0.008293   0.007032    0.004958  0.000224  0.000000
# 2017-12-12 09:00:00    0.007574   0.006651    0.004589  0.000186  0.000000
# 2017-12-12 10:00:00    0.006976   0.006503    0.004308  0.002708  0.003355
# 2017-12-12 11:00:00    0.006518   0.006536    0.004064  0.015322  0.020300
#
#                          ...       so_mm_runoff  sog_mm_runoff  pt_mm_runoff  \
# ...

# %%
# maskYear = (dfDiff.index >= '2014-01-01 00:00:00') & (dfDiff.index <= '2016-11-23 11:00')
# maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')
# maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2015-12-31 23:00')

# %%
df2 = df3#df2.loc[maskYear]#.dropna(how='any')

# %%
from hydroeval import *

# %%
simulated_flow_so = df2['so_runoff']
simulated_flow_sog = df2['sog_runoff']
simulated_flow_pt = df2['pt_runoff']
simulated_flow_fao = df2['fao_runoff']

observed_flow = df2['obs_runoff']

# %%
simulated_flow_so = np.array(simulated_flow_so)
simulated_flow_sog = np.array(simulated_flow_sog)
simulated_flow_pt = np.array(simulated_flow_pt)
simulated_flow_fao = np.array(simulated_flow_fao)

observed_flow = np.array(observed_flow)

# %%
nse_so = evaluator(nse, simulated_flow_so, observed_flow,axis=0)
nse_sog = evaluator(nse, simulated_flow_sog, observed_flow,axis=0)
nse_pt = evaluator(nse, simulated_flow_pt, observed_flow,axis=0)
nse_fao = evaluator(nse, simulated_flow_fao, observed_flow,axis=0)

print(nse_so)
print(nse_sog)
print(nse_pt)
print(nse_fao)
# Out:
# [0.56193504]
# [0.63839087]
# [0.53175835]
# [0.57299342]

# %%
kge_so = evaluator(kge, simulated_flow_so, observed_flow,axis=1)
kge_sog = evaluator(kge, simulated_flow_sog, observed_flow,axis=1)
kge_pt = evaluator(kge, simulated_flow_pt, observed_flow,axis=1)
kge_fao = evaluator(kge, simulated_flow_fao, observed_flow,axis=1)

print(kge_so[0][0])
print(kge_sog[0][0])
print(kge_pt[0][0])
print(kge_fao[0][0])
# Out:
# 0.6781824868174212
# 0.64665853233989
# 0.5178365802364919
# 0.5311880299644518

# %%
rmse_so = evaluator(rmse, simulated_flow_so, observed_flow,axis=1)
rmse_sog = evaluator(rmse, simulated_flow_sog, observed_flow,axis=1)
rmse_pt = evaluator(rmse, simulated_flow_pt, observed_flow,axis=1)
rmse_fao = evaluator(rmse, simulated_flow_fao, observed_flow,axis=1)

print(rmse_so)
print(rmse_sog)
print(rmse_pt)
print(rmse_fao)
# Out:
# [0.00101923]
# [0.00092603]
# [0.00105376]
# [0.00100629]

# %%
pbias_so = evaluator(pbias, simulated_flow_so, observed_flow,axis=1)
pbias_sog = evaluator(pbias, simulated_flow_sog, observed_flow,axis=1)
pbias_pt = evaluator(pbias, simulated_flow_pt, observed_flow,axis=1)
pbias_fao = evaluator(pbias, simulated_flow_fao, observed_flow,axis=1)

print(pbias_so)
print(pbias_sog)
print(pbias_pt)
print(pbias_fao)
# Out:
# [-24.51575833]
# [-24.58652324]
# [-43.27084083]
# [-40.19805489]

# %%
df2.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao'],
#       dtype='object')

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'obs_mm_runoff', 'so_mm_runoff', 'sog_mm_runoff',
#        'pt_mm_runoff', 'fao_mm_runoff', 'residual_obs + et_obs',
#        'residual_obs', 'residual_so', 'residual_sog', 'residual_pt',
#        'residual_fao', 'month', 'Date', 'so_et2', 'Data', 'ET%', 'prp%'],
#       dtype='object')

# %%
dfMon[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage']].plot(figsize=(20,10))

# %%
df2[['obs_runoff','so_runoff','sog_runoff']].plot(figsize=(20,10))

# %%
dfMonM = df2.resample('MS').agg('mean')
dfS2 =dfMonM[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage']]
dfS2['obs-so']=df2['so_storage']-df2['obs_storage']
dfS2['obs-pt']=df2['pt_storage']-df2['obs_storage']
dfS2['obs-fao']=df2['fao_storage']-df2['obs_storage']

# dfS2[dfS2 < 0]=np.nan
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
dfS2['month'] = pd.DatetimeIndex(dfMon.index).month
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfS2.head()
# Out:
#             obs_storage  so_storage  sog_storage  pt_storage  fao_storage  \
# Date
# 2014-01-01   293.589871  132.095196   169.279924  184.542626   170.759209
# 2014-02-01   306.430646  205.112116   260.222117  275.102902   253.652224
# 2014-03-01   296.311792  189.289853   245.059644  260.701915   236.336632
# 2014-04-01   283.614715  174.787620   232.044432  250.190132   223.608343
# 2014-05-01   303.364000  195.099308   249.221568  264.290159   241.656785
#
#                 obs-so      obs-pt     obs-fao  month
# Date
# 2014-01-01 -157.605161 -106.796358 -118.526472      1
# 2014-02-01         NaN         NaN         NaN      2
# 2014-03-01 -105.041095  -41.270668  -61.401717      3
# 2014-04-01 -103.040702  -33.505189  -57.849569      4
# 2014-05-01  -77.903740    0.321299  -21.473469      5

# %%
# dfS2 = dfS2.dropna(how='any')

# %%
plt.style.use(['ggplot'])
dfS.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-582-1c91e7a20537> in <module>()
#       1 plt.style.use(['ggplot'])
# ----> 2 dfS.plot()
#
# NameError: name 'dfS' is not defined

# %%
dfS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-583-c43a89d8ffbb> in <module>()
# ----> 1 dfS
#
# NameError: name 'dfS' is not defined

# %%
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et      ...       \
# Date                                                               ...
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0      ...
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0      ...
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0      ...
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0      ...
# ...

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df.plot(ax=ax1, y=['obs_storage','so_storage','sog_storage','fao_storage','pt_storage'],kind='area', stacked=False, 
                  label=['obsSt','soSt','soGSt','faoSt','ptSt'],linewidth=2)#,'El + err','El + bow'],

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax11 = ax
# ax21 = ax.twinx()
################################################################################
dfS.plot(kind='area', y=['so_storage','obs_storage','fao_storage','pt_storage'],linewidth=3, ax = ax11, 
          label=['Storage - GEOframe','Storage - Obs.','Storage - FAO','Storage - PT'],rot = -0,stacked=False, 
         colormap='Dark2', alpha =0.3)

# dfS2.plot(kind='line', y=['so_storage','obs_storage','fao_storage','pt_storage'],linewidth=5, ax = ax11, 
#           rot = -0,stacked=False, 
#          colormap='Dark2', alpha =0.5)
# df2.plot(kind='line', y=['obsCum','soCum'],linewidth=3, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#          color=['b','c'],alpha = 1)
################################################################################
ax11.legend(loc='upper center',fontsize=25, bbox_to_anchor=(0.5, 1.12), ncol=4, frameon =True)
# # ax21.legend(loc='upper right',fontsize=15)

# # ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11]:
    ax.set_ylim([100,350])
    ax.set_ylabel('Storage Root Zone [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    
# plt.title("Storage - GEOframe ET", size=30, family='DejaVu Sans');               
# plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-586-5bba87ca51b1> in <module>()
#       3 # ax21 = ax.twinx()
#       4 ################################################################################
# ----> 5 dfS.plot(kind='area', y=['so_storage','obs_storage','fao_storage','pt_storage'],linewidth=3, ax = ax11,
#       6           label=['Storage - GEOframe','Storage - Obs.','Storage - FAO','Storage - PT'],rot = -0,stacked=False,
#       7          colormap='Dark2', alpha =0.3)
#
# NameError: name 'dfS' is not defined

# %%
print(dfS2.mean())
print(dfS2.std())
# runoff = Prp*area - Storage*area - ET*area

# %%
dfET= pd.read_csv('data/RioRessi/1/RioRessi_ET_SO_flat_stress.csv',sep=',',skiprows=6,low_memory=False)
dfET[dfET ==-9999]=np.nan
dfET.plot()

# %%
dfET.columns=['','Datetime','et']
dfET.head()

# %%
dfET['Datetime'] = pd.to_datetime(dfET['Datetime'], dayfirst=True)
dfET['Datetime'] = dfET['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
dfET.index = dfET['Datetime']
dfET.index = pd.DatetimeIndex(dfET.index)
dfET2=dfET
dfET2=dfET2.iloc[:,1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-ba68e2729621> in <module>()
#       1 # Reindex the dataframe using the date and drop all duplicate date
# ----> 2 dfET.index = dfET['Datetime']
#       3 dfET.index = pd.DatetimeIndex(dfET.index)
#       4 dfET2=dfET
#       5 dfET2=dfET2.iloc[:,1:]
#
# NameError: name 'dfET' is not defined

# %%
dfETD = dfET2.resample('1D').agg('sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-43ff2e6b76f9> in <module>()
# ----> 1 dfETD = dfET2.resample('1D').agg('sum')
#
# NameError: name 'dfET2' is not defined

# %%
dfETD.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-f4bd2e505e61> in <module>()
# ----> 1 dfETD.plot()
#
# NameError: name 'dfETD' is not defined

# %%
df2 = df3

# %%
df2[df2==-9999]=np.nan

# %%
# maskYear = (dfDiff.index >= '2014-01-01 00:00:00') & (dfDiff.index <= '2016-11-23 11:00')
maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')

# %%
df2 = df2.loc[maskYear].dropna(how='any')

# %%
yMean = df2['obs'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'obs'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-bb900253ffe1> in <module>()
# ----> 1 yMean = df2['obs'].mean()
#
# ...

# %%
dfDiff = pd.concat([(df2['obs']-df2['so']), 
                    (df2['obs']-df2['pt']),
                    (df2['obs']-df2['fao']),
                    ((df2['obs']-df2['so']))**2,
                    df2['obs'],
                    (df2['obs']-yMean),
                    (df2['obs']-yMean)**2],axis=1, sort=False)
dfDiff.head()
dfDiff.columns = ['errSO','errPT','errFAO','errSO2','obs','obs-mean','obs-mean2']

# %%
dfDiff[['errSO2']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-2002525ff94e> in <module>()
# ----> 1 dfDiff[['errSO2']]
#
# NameError: name 'dfDiff' is not defined

# %%
a = dfDiff['errSO2'].sum()
b = dfDiff['obs-mean2'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-dfe88ebcf7fd> in <module>()
# ----> 1 a = dfDiff['errSO2'].sum()
#       2 b = dfDiff['obs-mean2'].sum()
#
# NameError: name 'dfDiff' is not defined

# %%
df2['obs'].corr(df2['so'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'obs'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-93ab054c2d81> in <module>()
# ----> 1 df2['obs'].corr(df2['so'])
#
# ...

# %%
dfDiff.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-2f287890252d> in <module>()
# ----> 1 dfDiff.head()
#
# NameError: name 'dfDiff' is not defined

# %%
asd=dfDiff['obs-mean2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-1e84775c3054> in <module>()
# ----> 1 asd=dfDiff['obs-mean2']
#
# NameError: name 'dfDiff' is not defined

# %%
asd.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-35277245702e> in <module>()
# ----> 1 asd.sum()
#
# NameError: name 'asd' is not defined

# %%
print(a)
print(b)

# %%
c = dfDiff['errSO'].sum()*100
d = dfDiff['obs'].sum()

print(c)
print(d)

# %%
PBIAS = 1-c/d
print(PBIAS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-6fbeea403572> in <module>()
# ----> 1 PBIAS = 1-c/d
#       2 print(PBIAS)
#
# NameError: name 'c' is not defined

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
ax11 = axes[0][0]
ax21 = axes[0][1]
ax12 = axes[1][0]
ax22 = axes[1][1]
################################################################################
df2.plot(ax=ax11, y=['obs_runoff','so_runoff'],kind='line', stacked=False,label=['obs','so'],linewidth=2)
df2.plot(ax=ax21, y=['obs_runoff','sog_runoff'],kind='line', stacked=False,label=['obs','soG'],linewidth=2)
df2.plot(ax=ax12, y=['obs_runoff','pt_runoff'],kind='line', stacked=False,label=['obs','pt'],linewidth=2)
df2.plot(ax=ax22, y=['obs_runoff','fao_runoff'],kind='line', stacked=False,label=['obs','fao'],linewidth=2)

################################################################################
ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11, ax12, ax21,ax22]:
    ax.set_ylabel('Runoff [l/s]',fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  

# for ax in [ ax21,ax22]:
# #     ax.set_ylim([0,20])
#     ax.set_ylabel('Cumulated Runoff [m3]',fontsize=20)
#     ax.set_xlabel('Date',fontsize=20)
