# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/RRRDP/"                
os.chdir(path)

# %%
dfsoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoS.columns = ['','Date','so_storage']
dfsoS.index = dfsoS['Date']
dfsoS = dfsoS.iloc[:,2:]

dfsogS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_NS_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogS.columns = ['','Date','sog_storage']
dfsogS.index = dfsogS['Date']
dfsogS = dfsogS.iloc[:,2:]

dfptS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptS.columns = ['','Date','pt_storage']
dfptS.index = dfptS['Date']
dfptS = dfptS.iloc[:,2:]

dffaoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoS.columns = ['','Date','fao_storage']
dffaoS.index = dffaoS['Date']
dffaoS = dffaoS.iloc[:,2:]


dfsoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoROS.columns = ['','Date','so_runoff']
dfsoROS.index = dfsoROS['Date']
dfsoROS = dfsoROS.iloc[:,2:]

dfsogROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_NS_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogROS.columns = ['','Date','sog_runoff']
dfsogROS.index = dfsogROS['Date']
dfsogROS = dfsogROS.iloc[:,2:]

dfptROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_PT_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptROS.columns = ['','Date','pt_runoff']
dfptROS.index = dfptROS['Date']
dfptROS = dfptROS.iloc[:,2:]

dffaoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_FAO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoROS.columns = ['','Date','fao_runoff']
dffaoROS.index = dffaoROS['Date']
dffaoROS = dffaoROS.iloc[:,2:]

dfObsS= pd.read_csv('data/RioRessi/1/RioRessi_Root.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsS.columns = ['','Date','obs_storage']
dfObsS.index = dfObsS['Date']
dfObsS = dfObsS.iloc[:,2:]

dfObsR= pd.read_csv('data/RioRessi/1/RioRessi_RUNOFF.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsR.columns = ['','Date','obs_runoff']
dfObsR.index = dfObsR['Date']
dfObsR = dfObsR.iloc[:,2:]

dfPrp= pd.read_csv('data/RioRessi/1/RioRessi_PRP.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfPrp.columns = ['','Date','prp']
dfPrp.index = dfPrp['Date']
dfPrp = dfPrp.iloc[:,2:]

dfso= pd.read_csv('data/RioRessi/1/RioRessi_ET_SOSt.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfso.columns = ['','Date','so_et']
dfso.index = dfso['Date']
dfso = dfso.iloc[:,2:]

dfsog = pd.read_csv('data/RioRessi/1/RioRessi_ET_SO_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsog.columns = ['','Date','sog_et']
dfsog.index = dfsog['Date']
dfsog = dfsog.iloc[:,2:]

dfpt= pd.read_csv('data/RioRessi/1/RioRessi_ET_PT126.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfpt.columns = ['','Date','pt_et']
dfpt.index = dfpt['Date']
dfpt = dfpt.iloc[:,2:]

dffao= pd.read_csv('data/RioRessi/1/RioRessi_ET_FAO.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffao.columns = ['','Date','fao_et']
dffao.index = dffao['Date']
dffao = dffao.iloc[:,2:]

# %%
dfsgw= pd.read_csv('data/RioRessi/1/RioRessi_RootGW.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsgw.columns = ['','Date','storage_gw']
dfsgw.index = dfsgw['Date']
dfsgw = dfsgw.iloc[:,2:]
dfsgw.head()
# Out:
#                      storage_gw
# Date
# 2014-01-01 01:00:00     162.650
# 2014-01-01 02:00:00     163.000
# 2014-01-01 03:00:00     163.225
# 2014-01-01 04:00:00     163.575
# 2014-01-01 05:00:00     163.875

# %%
df = pd.concat([dfObsR,dfPrp.iloc[12432:,:],dfso.iloc[12432:,:],dfsog.iloc[12432:,:],
                dfsoROS,dfsogROS,dfptROS,dffaoROS,
                dffao.iloc[12432:,:],dfpt.iloc[12432:,:], dfObsS.iloc[12432:,:],dfsoS,dfsogS,dffaoS,dfptS,dfsgw],axis=1)
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et     so_runoff  sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN  5.927601e-13    0.001680
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN  6.475211e-13    0.001764
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN  6.029241e-13    0.001688
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN  6.392436e-13    0.001748
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN  6.096653e-13    0.001694
#
#                         pt_runoff    fao_runoff    fao_et  pt_et  obs_storage  \
# Date
# 2014-01-01 00:00:00  5.148190e-10  4.568406e-13  0.010114    0.0    291.94050
# 2014-01-01 01:00:00  5.716940e-10  4.999549e-13  0.010065    0.0    291.51000
# 2014-01-01 02:00:00  5.256259e-10  4.635961e-13  0.012050    0.0    291.23325
# 2014-01-01 03:00:00  5.629723e-10  4.942579e-13  0.012755    0.0    290.80275
# 2014-01-01 04:00:00  5.327282e-10  4.684004e-13  0.008917    0.0    290.43375
#
#                      so_storage  sog_storage  fao_storage  pt_storage  \
# Date
# 2014-01-01 00:00:00   259.00337      48.7229   224.763988  208.345172
# 2014-01-01 01:00:00   259.00337      48.7229   224.762224  208.345116
# 2014-01-01 02:00:00   259.00337      48.7229   224.760036  208.345060
# 2014-01-01 03:00:00   259.00337      48.7229   224.757637  208.345004
# 2014-01-01 04:00:00   259.00337      48.7229   224.755919  208.344948
#
#                      storage_gw
# Date
# 2014-01-01 00:00:00         NaN
# 2014-01-01 01:00:00     162.650
# 2014-01-01 02:00:00     163.000
# 2014-01-01 03:00:00     163.225
# 2014-01-01 04:00:00     163.575

# %%
df.shape
# Out:
# (46944, 16)

# %%
df2=df.dropna(subset=['obs_runoff','so_runoff','sog_runoff','pt_runoff','fao_runoff','prp',
                     'obs_storage','so_storage','sog_storage','fao_storage','pt_storage','storage_gw'])

# %%
df2.shape
# Out:
# (27904, 16)

# %%
df2.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.001366
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.001371
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.001379
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.001392
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.001409
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.007593   0.005859    0.001755  0.000290  0.000000
# 2017-12-12 08:00:00    0.007155   0.005547    0.001790  0.000224  0.000000
# 2017-12-12 09:00:00    0.006762   0.005241    0.001835  0.000186  0.000000
# 2017-12-12 10:00:00    0.006405   0.005169    0.001890  0.002708  0.003355
# 2017-12-12 11:00:00    0.006082   0.005040    0.001960  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  406.973570    76.522594   360.070097
# 2017-12-12 08:00:00     227.9550  406.845329    76.309374   360.021957
# 2017-12-12 09:00:00     229.1260  406.774536    76.126888   360.044174
# 2017-12-12 10:00:00     230.6400  406.736145    75.968592   360.103860
# 2017-12-12 11:00:00     231.7335  406.767817    75.828499   360.242168
#
#                      pt_storage  storage_gw
# Date
# 2017-12-12 07:00:00  322.396380     142.350
# 2017-12-12 08:00:00  321.287176     147.125
# 2017-12-12 09:00:00  320.254114     149.500
# 2017-12-12 10:00:00  319.289401     150.950
# 2017-12-12 11:00:00  318.386136     152.000

# %%
df.tail()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff  sog_runoff  \
# Date
# 2019-05-10 19:00:00         NaN  NaN    0.0     0.0        NaN         NaN
# 2019-05-10 20:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 21:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 22:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 23:00:00         NaN  NaN    NaN     NaN        NaN         NaN
#
#                      pt_runoff  fao_runoff    fao_et     pt_et  obs_storage  \
# Date
# 2019-05-10 19:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 20:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 21:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 22:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 23:00:00        NaN         NaN  0.011843  0.000589          NaN
#
#                      so_storage  sog_storage  fao_storage  pt_storage  \
# Date
# 2019-05-10 19:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 20:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 21:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 22:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 23:00:00         NaN          NaN          NaN         NaN
#
#                      storage_gw
# Date
# 2019-05-10 19:00:00         NaN
# 2019-05-10 20:00:00         NaN
# 2019-05-10 21:00:00         NaN
# 2019-05-10 22:00:00         NaN
# 2019-05-10 23:00:00         NaN

# %%
idf = pd.date_range('2014-01-01 00:00','2017-12-12 11:00',freq='1H')
df = df.reindex(idf)

# %%
df = df2
df3 = df2

# %%
df3.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.001366
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.001371
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.001379
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.001392
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.001409
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.007593   0.005859    0.001755  0.000290  0.000000
# 2017-12-12 08:00:00    0.007155   0.005547    0.001790  0.000224  0.000000
# 2017-12-12 09:00:00    0.006762   0.005241    0.001835  0.000186  0.000000
# 2017-12-12 10:00:00    0.006405   0.005169    0.001890  0.002708  0.003355
# 2017-12-12 11:00:00    0.006082   0.005040    0.001960  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  406.973570    76.522594   360.070097
# 2017-12-12 08:00:00     227.9550  406.845329    76.309374   360.021957
# 2017-12-12 09:00:00     229.1260  406.774536    76.126888   360.044174
# 2017-12-12 10:00:00     230.6400  406.736145    75.968592   360.103860
# 2017-12-12 11:00:00     231.7335  406.767817    75.828499   360.242168
#
#                      pt_storage  storage_gw
# Date
# 2017-12-12 07:00:00  322.396380     142.350
# 2017-12-12 08:00:00  321.287176     147.125
# 2017-12-12 09:00:00  320.254114     149.500
# 2017-12-12 10:00:00  319.289401     150.950
# 2017-12-12 11:00:00  318.386136     152.000

# %%
df['residual_obs + et_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']#-df['D_storage_gw']
df['obs_D_storage'] = df['obs_storage'].diff()
df['so_D_storage'] = df['so_storage'].diff()
df['sog_D_storage'] = df['sog_storage'].diff()
df['fao_D_storage'] = df['fao_storage'].diff()
df['pt_D_storage'] = df['pt_storage'].diff()
df['D_storage_gw'] = df['storage_gw'].diff()

df['obs_mm_runoff'] = df['obs_runoff']*1000*3600/21930
df['so_mm_runoff'] = df['so_runoff']*1000*3600/21930
df['sog_mm_runoff'] = df['sog_runoff']*1000*3600/21930
df['pt_mm_runoff'] = df['pt_runoff']*1000*3600/21930
df['fao_mm_runoff'] = df['fao_runoff']*1000*3600/21930

df['obs_runoff'] = df['obs_runoff']*3.6
df['so_runoff'] = df['so_runoff']*3.6
df['sog_runoff'] = df['sog_runoff']*3.6
df['pt_runoff'] = df['pt_runoff']*3.6
df['fao_runoff'] = df['fao_runoff']*3.6

# %%
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et     so_runoff  sog_runoff  \
# Date
# 2014-01-01 01:00:00    0.003059  0.0    NaN     NaN  2.331076e-12    0.006350
# 2014-01-01 02:00:00    0.003044  0.0    NaN     NaN  2.170527e-12    0.006079
# 2014-01-01 03:00:00    0.003015  0.0    NaN     NaN  2.301277e-12    0.006294
# 2014-01-01 04:00:00    0.002957  0.0    NaN     NaN  2.194795e-12    0.006097
# 2014-01-01 05:00:00    0.002972  0.0    NaN     NaN  2.281513e-12    0.006250
#
#                         pt_runoff    fao_runoff    fao_et  pt_et  ...  \
# Date                                                              ...
# 2014-01-01 01:00:00  2.058098e-09  1.799838e-12  0.010065    0.0  ...
# 2014-01-01 02:00:00  1.892253e-09  1.668946e-12  0.012050    0.0  ...
# 2014-01-01 03:00:00  2.026700e-09  1.779328e-12  0.012755    0.0  ...
# 2014-01-01 04:00:00  1.917821e-09  1.686241e-12  0.008917    0.0  ...
# 2014-01-01 05:00:00  2.006109e-09  1.764743e-12  0.009778    0.0  ...
#
#                      so_D_storage  sog_D_storage  fao_D_storage  pt_D_storage  \
# Date
# 2014-01-01 01:00:00           NaN            NaN            NaN           NaN
# 2014-01-01 02:00:00 -6.252776e-13  -7.105427e-14      -0.002188     -0.000056
# 2014-01-01 03:00:00 -6.821210e-13  -5.684342e-14      -0.002399     -0.000056
# 2014-01-01 04:00:00 -5.684342e-13  -7.815970e-14      -0.001718     -0.000056
# 2014-01-01 05:00:00 -6.252776e-13  -4.973799e-14      -0.001932     -0.000056
#
#                      D_storage_gw  obs_mm_runoff  so_mm_runoff  sog_mm_runoff  \
# Date
# 2014-01-01 01:00:00           NaN       0.139493  1.062962e-10       0.289573
# 2014-01-01 02:00:00         0.350       0.138824  9.897523e-11       0.277180
# 2014-01-01 03:00:00         0.225       0.137494  1.049374e-10       0.287022
# 2014-01-01 04:00:00         0.350       0.134856  1.000819e-10       0.278004
# 2014-01-01 05:00:00         0.300       0.135513  1.040362e-10       0.284987
#
#                      pt_mm_runoff  fao_mm_runoff
# Date
# 2014-01-01 01:00:00  9.384854e-08   8.207194e-11
# 2014-01-01 02:00:00  8.628606e-08   7.610332e-11
# 2014-01-01 03:00:00  9.241679e-08   8.113673e-11
# 2014-01-01 04:00:00  8.745195e-08   7.689199e-11
# 2014-01-01 05:00:00  9.147782e-08   8.047163e-11
#
# [5 rows x 27 columns]

# %%
df['residual_obs + et_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']#-df['D_storage_gw']
df['residual_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']-df['D_storage_gw']
df['residual_so'] = df['prp'] - df['so_mm_runoff'] - df['so_D_storage'] - df['so_et']
df['residual_sog'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage'] - df['sog_et']
df['residual_pt'] = df['prp'] - df['obs_mm_runoff'] - df['fao_D_storage'] - df['pt_et']
df['residual_fao'] = df['prp'] - df['obs_mm_runoff'] - df['pt_D_storage'] - df['fao_et']

df['residual_so + et_so'] = df['so_et'] + df['residual_so']
df['residual_fao + et_fao'] = df['fao_et'] + df['residual_fao']
df['residual_obs + et_so'] = df['so_et'] + df['residual_obs']
df['residual_pt + et_pt'] = df['pt_et'] + df['residual_pt']

# %%
dfMon = df.resample('1MS').agg('sum')
dfAnn = df.resample('1YS').agg('sum')

# %%
dfDay = df.resample('1D').agg('sum')

# %%
df2 = df

# %%
dfMon['month'] = pd.DatetimeIndex(dfMon.index).year#.month
dfMon['Date'] = dfMon.index

# %%
dfMon.head()
# Out:
#             obs_runoff    prp      so_et     sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01    5.142962    0.0  11.719283   8.817884   0.000008    2.848499
# 2014-02-01    4.011030  220.0  18.958799  13.668465   4.927136    4.878971
# 2014-03-01    2.968361  179.6  70.896314  49.182022   2.043301    4.096863
# 2014-04-01    2.670504  261.0  65.303575  45.605552   2.363002    3.430371
# 2014-05-01    2.149786  143.8  84.437723  58.891763   2.187812    3.510052
#
#             pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_so  \
# Date                                                       ...
# 2014-01-01   0.000001  2.613188e-07  10.421665  10.024666  ...   -13.029179
# 2014-02-01   4.642478  5.159170e+00  14.770438  15.176535  ...  -158.060024
# 2014-03-01   2.919488  2.252457e+00  50.860102  51.793558  ...     1.187108
# 2014-04-01   3.046248  2.054513e+00  44.877742  49.528728  ...    50.090914
# 2014-05-01   3.078288  3.215094e+00  61.138770  68.733898  ...    -5.049845
#
#             residual_sog  residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01     24.808993  -240.971444   -242.908733            -1.309896
# 2014-02-01   -199.008869  -105.241226    -59.416652          -139.101225
# 2014-03-01   -137.501644     3.824558      3.814775            72.083422
# 2014-04-01    134.118310    65.116403     54.366677           115.394489
# 2014-05-01     34.358493    -0.626875     19.107738            79.387877
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Date
# 2014-01-01            -232.497133             81.271160          -230.946778
# 2014-02-01             -44.646214           -151.681604           -90.064692
# 2014-03-01              54.674877            -37.873308            55.618116
# 2014-04-01              99.244419            330.452437           114.645130
# 2014-05-01              80.246508            136.112979            68.107023
#
#             month       Date
# Date
# 2014-01-01   2014 2014-01-01
# 2014-02-01   2014 2014-02-01
# 2014-03-01   2014 2014-03-01
# 2014-04-01   2014 2014-04-01
# 2014-05-01   2014 2014-05-01
#
# [5 rows x 39 columns]

# %%
dfM = dfMon[['so_et','prp','obs_mm_runoff','so_D_storage']]
dfM.columns = ['ET_Ps','Rainfall','Runoff sim.','Storage sim.']

# %%
dfM['Date'] = dfM.index
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfM.head()
# Out:
#                 ET_Ps  Rainfall  Runoff sim.  Storage sim.       Date
# Date
# 2014-01-01  11.719283       0.0   234.517172      2.335533 2014-01-01
# 2014-02-01  18.958799     220.0   182.901517    134.038151 2014-02-01
# 2014-03-01  70.896314     179.6   135.356160    -15.543516 2014-03-01
# 2014-04-01  65.303575     261.0   121.773993     31.835413 2014-04-01
# 2014-05-01  84.437723     143.8    98.029460    -22.672079 2014-05-01

# %%
dataM = dfM.melt(id_vars=['Date'], var_name='Components', value_name='Water budget')

# %%
import seaborn as sns
import matplotlib.dates as mdates

# %% [markdown]
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
from matplotlib.dates import YearLocator, MonthLocator, WeekdayLocator, DateFormatter

# %%
import datetime
import matplotlib.ticker as mticker

# %%
import matplotlib.ticker as tkr

# %%
idy = pd.date_range('2014-01-01','2017-12-12',freq='1MS')

# %%
dfMon.head()
# Out:
#             obs_runoff    prp      so_et     sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01    5.142962    0.0  11.719283   8.817884   0.000008    2.848499
# 2014-02-01    4.011030  220.0  18.958799  13.668465   4.927136    4.878971
# 2014-03-01    2.968361  179.6  70.896314  49.182022   2.043301    4.096863
# 2014-04-01    2.670504  261.0  65.303575  45.605552   2.363002    3.430371
# 2014-05-01    2.149786  143.8  84.437723  58.891763   2.187812    3.510052
#
#             pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_so  \
# Date                                                       ...
# 2014-01-01   0.000001  2.613188e-07  10.421665  10.024666  ...   -13.029179
# 2014-02-01   4.642478  5.159170e+00  14.770438  15.176535  ...  -158.060024
# 2014-03-01   2.919488  2.252457e+00  50.860102  51.793558  ...     1.187108
# 2014-04-01   3.046248  2.054513e+00  44.877742  49.528728  ...    50.090914
# 2014-05-01   3.078288  3.215094e+00  61.138770  68.733898  ...    -5.049845
#
#             residual_sog  residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01     24.808993  -240.971444   -242.908733            -1.309896
# 2014-02-01   -199.008869  -105.241226    -59.416652          -139.101225
# 2014-03-01   -137.501644     3.824558      3.814775            72.083422
# 2014-04-01    134.118310    65.116403     54.366677           115.394489
# 2014-05-01     34.358493    -0.626875     19.107738            79.387877
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Date
# 2014-01-01            -232.497133             81.271160          -230.946778
# 2014-02-01             -44.646214           -151.681604           -90.064692
# 2014-03-01              54.674877            -37.873308            55.618116
# 2014-04-01              99.244419            330.452437           114.645130
# 2014-05-01              80.246508            136.112979            68.107023
#
#             month       Date
# Date
# 2014-01-01   2014 2014-01-01
# 2014-02-01   2014 2014-02-01
# 2014-03-01   2014 2014-03-01
# 2014-04-01   2014 2014-04-01
# 2014-05-01   2014 2014-05-01
#
# [5 rows x 39 columns]

# %%
dfMon['Data'] = idy
dfMon['Data'] = pd.to_datetime(dfMon['Data'], dayfirst=True)
dfMon['Data'] = dfMon['Data'].dt.strftime('%Y-%m')
dfMon.index = dfMon['Data']

# %%
import calendar
import matplotlib.dates as mdates

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt',
#        'month', 'Date', 'Data'],
#       dtype='object')

# %%
dfETTNull = dfMon[['residual_obs + et_obs',
                   'residual_so + et_so',
                   'residual_pt + et_pt',
                   'residual_fao + et_fao',
#                    'residual_obs + et_obs', 
                   'pt_et','fao_et',
                   'so_et','residual_so']]
# dfETTNull= df[['a','b']]
# pd.concat(dfMon['residual_obs + et_obs'],dfMon[['so_et']])
# df1 = pd.DataFrame([['a', 1], ['b', 2]],
# ...                    columns=['letter', 'number'])

# %%
dfETTNull['residual_so+so_et']=dfETTNull['so_et']+dfETTNull['residual_so']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfETTNull.head()
# Out:
#          residual_obs + et_obs  residual_so + et_so  residual_pt + et_pt  \
# Data
# 2014-01            -232.378929            -1.309896          -230.946778
# 2014-02              23.383983          -139.101225           -90.064692
# 2014-03              57.557590            72.083422            55.618116
# 2014-04             145.707757           115.394489           114.645130
# 2014-05              28.624790            79.387877            68.107023
#
#          residual_fao + et_fao      pt_et     fao_et      so_et  residual_so  \
# Data
# 2014-01            -232.497133  10.024666  10.421665  11.719283   -13.029179
# 2014-02             -44.646214  15.176535  14.770438  18.958799  -158.060024
# 2014-03              54.674877  51.793558  50.860102  70.896314     1.187108
# 2014-04              99.244419  49.528728  44.877742  65.303575    50.090914
# 2014-05              80.246508  68.733898  61.138770  84.437723    -5.049845
#
#          residual_so+so_et
# Data
# 2014-01          -1.309896
# 2014-02        -139.101225
# 2014-03          72.083422
# 2014-04         115.394489
# 2014-05          79.387877

# %%
dfETTNull[dfETTNull < 0] = 0
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
dfETTNull['Data'] = dfMon['Data']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfMon.head()
# Out:
#          obs_runoff    prp      so_et     sog_et  so_runoff  sog_runoff  \
# Data
# 2014-01    5.142962    0.0  11.719283   8.817884   0.000008    2.848499
# 2014-02    4.011030  220.0  18.958799  13.668465   4.927136    4.878971
# 2014-03    2.968361  179.6  70.896314  49.182022   2.043301    4.096863
# 2014-04    2.670504  261.0  65.303575  45.605552   2.363002    3.430371
# 2014-05    2.149786  143.8  84.437723  58.891763   2.187812    3.510052
#
#          pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_sog  \
# Data                                                    ...
# 2014-01   0.000001  2.613188e-07  10.421665  10.024666  ...     24.808993
# 2014-02   4.642478  5.159170e+00  14.770438  15.176535  ...   -199.008869
# 2014-03   2.919488  2.252457e+00  50.860102  51.793558  ...   -137.501644
# 2014-04   3.046248  2.054513e+00  44.877742  49.528728  ...    134.118310
# 2014-05   3.078288  3.215094e+00  61.138770  68.733898  ...     34.358493
#
#          residual_pt  residual_fao  residual_so + et_so  \
# Data
# 2014-01  -240.971444   -242.908733            -1.309896
# 2014-02  -105.241226    -59.416652          -139.101225
# 2014-03     3.824558      3.814775            72.083422
# 2014-04    65.116403     54.366677           115.394489
# 2014-05    -0.626875     19.107738            79.387877
#
#          residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Data
# 2014-01            -232.497133             81.271160          -230.946778
# 2014-02             -44.646214           -151.681604           -90.064692
# 2014-03              54.674877            -37.873308            55.618116
# 2014-04              99.244419            330.452437           114.645130
# 2014-05              80.246508            136.112979            68.107023
#
#          month       Date     Data
# Data
# 2014-01   2014 2014-01-01  2014-01
# 2014-02   2014 2014-02-01  2014-02
# 2014-03   2014 2014-03-01  2014-03
# 2014-04   2014 2014-04-01  2014-04
# 2014-05   2014 2014-05-01  2014-05
#
# [5 rows x 40 columns]

# %%
dfM.head()
# Out:
#                 ET_Ps  Rainfall  Runoff sim.  Storage sim.       Date
# Date
# 2014-01-01  11.719283       0.0   234.517172      2.335533 2014-01-01
# 2014-02-01  18.958799     220.0   182.901517    134.038151 2014-02-01
# 2014-03-01  70.896314     179.6   135.356160    -15.543516 2014-03-01
# 2014-04-01  65.303575     261.0   121.773993     31.835413 2014-04-01
# 2014-05-01  84.437723     143.8    98.029460    -22.672079 2014-05-01

# %%
dfMon['ETdelta']=dfMon['residual_so']+dfMon['so_et']

# %%
# def fmt(x, pos=0, max_i=len(ticklabels)-1):
#     i = int(x) 
#     i = 0 if i < 0 else max_i if i > max_i else i
#     return dates[i]

# %%
ticklabels = ['']*len(dfMon)
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
fig, ax = plt.subplots(nrows = 1, ncols =1,figsize=(30,15))
ax11 = ax

dfETTNull.plot(x='Data',y=['residual_obs + et_obs','so_et','fao_et','pt_et'],kind='bar', ax = ax11,  edgecolor=".3",linewidth=1,width=0.75,
               colormap='Accent', alpha=1,
               label = ['ET$_{obs}+\Delta$','ET$_{Ps}$','ET$_{fao}$','ET$_{pt}$'],rot = -0,stacked=False)

ticklabels = ['']*len(dfMon)
skip = 3
ticklabels[0::skip] = dfMon['Date'].iloc[0::skip].dt.strftime('%Y-%m')

for ax in [ax11]:#, ax21, ax22]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)
    ax.set_xlabel('',fontsize=30)
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=30, ncol=2)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

ax11.set_ylim([-1,250])
ax11.set_ylabel('Evapotranspiration [mm]',fontsize=30,fontweight='bold')
fig.autofmt_xdate(rotation=90)
ax11.grid(True)

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
fig, ax = plt.subplots(nrows = 1, ncols =1,figsize=(30,15))
# ax11 = ax[0]
# ax12 = ax[1]
ax13 = ax

# dfETTNull.plot(x='Data',y=['residual_obs + et_obs','so_et'],kind='bar', ax = ax11,  edgecolor=".3",linewidth=1,width=0.75,
#                color=['seagreen','lime'],alpha=1,label = ['ET$_{obs}+\Delta$','ET$_{Ps}$'],rot = -0,stacked=False)

# dfMon.plot(x='Data',y=['obs_D_storage','sog_D_storage'],kind='bar', ax = ax12,  edgecolor=".3",linewidth=2.5,
#            color=['crimson','peru'],alpha=1,label = ['Storage obs.','Storage sim.'],rot = -0,stacked=False)

dfMon.plot(y=['obs_runoff','so_runoff','fao_runoff','pt_runoff'],kind='bar', ax = ax13,  edgecolor=".3",linewidth=1,width=0.75,
           colormap='Accent',alpha=1,label = ['Runoff obs','Runoff sim$_{ps}$','Runoff sim$_{fao}$','Runoff sim$_{pt}$'],rot = -0,stacked=False)

ticklabels = ['']*len(dfMon)
skip = 3#len(dfMon)//24
ticklabels[0::skip] = dfMon['Date'].iloc[0::skip].dt.strftime('%Y-%m')

for ax in [ax13]:#, ax21, ax22]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)
    ax.set_xlabel('',fontsize=30)
#     ax.set_ylim([-100,400])
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=30)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))


# ax11.set_ylim([-1,250])
# ax12.set_ylim([-100,100])
ax13.set_ylim([-0.,16])
# ax11.set_title('Simulated', fontdict={'fontsize': 30, 'fontweight': 'bold'})

# ax11.set_ylabel('Evapotranspiration [mm]',fontsize=30,fontweight='bold')
ax13.set_ylabel('Runoff [10$^{3}$ m$^{3}$]',fontsize=30,fontweight='bold')
 

fig.autofmt_xdate(rotation=90)
ax13.grid(True)
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt',
#        'month', 'Date', 'Data', 'ETdelta'],
#       dtype='object')

# %%
dfETT = dfMon[['Data','residual_obs + et_obs','so_et','sog_et','fao_et','pt_et','residual_so','residual_sog','residual_fao','residual_pt']]

# %%
dfETT['soet+r']= dfETT['so_et']+dfETT['residual_so']
dfETT['soget+r']= dfETT['sog_et']+dfETT['residual_sog']
dfETT['faoet+r']= dfETT['fao_et']+dfETT['residual_fao']
dfETT['ptet+r']= dfETT['pt_et']+dfETT['residual_pt']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
skip = len(dfMon)//4
print(skip)
# Out:
# 12

# %%
dfMon.head()
# Out:
#          obs_runoff    prp      so_et     sog_et  so_runoff  sog_runoff  \
# Data
# 2014-01    5.142962    0.0  11.719283   8.817884   0.000008    2.848499
# 2014-02    4.011030  220.0  18.958799  13.668465   4.927136    4.878971
# 2014-03    2.968361  179.6  70.896314  49.182022   2.043301    4.096863
# 2014-04    2.670504  261.0  65.303575  45.605552   2.363002    3.430371
# 2014-05    2.149786  143.8  84.437723  58.891763   2.187812    3.510052
#
#          pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_pt  \
# Data                                                    ...
# 2014-01   0.000001  2.613188e-07  10.421665  10.024666  ...  -240.971444
# 2014-02   4.642478  5.159170e+00  14.770438  15.176535  ...  -105.241226
# 2014-03   2.919488  2.252457e+00  50.860102  51.793558  ...     3.824558
# 2014-04   3.046248  2.054513e+00  44.877742  49.528728  ...    65.116403
# 2014-05   3.078288  3.215094e+00  61.138770  68.733898  ...    -0.626875
#
#          residual_fao  residual_so + et_so  residual_fao + et_fao  \
# Data
# 2014-01   -242.908733            -1.309896            -232.497133
# 2014-02    -59.416652          -139.101225             -44.646214
# 2014-03      3.814775            72.083422              54.674877
# 2014-04     54.366677           115.394489              99.244419
# 2014-05     19.107738            79.387877              80.246508
#
#          residual_obs + et_so  residual_pt + et_pt  month       Date     Data  \
# Data
# 2014-01             81.271160          -230.946778   2014 2014-01-01  2014-01
# 2014-02           -151.681604           -90.064692   2014 2014-02-01  2014-02
# 2014-03            -37.873308            55.618116   2014 2014-03-01  2014-03
# 2014-04            330.452437           114.645130   2014 2014-04-01  2014-04
# 2014-05            136.112979            68.107023   2014 2014-05-01  2014-05
#
#             ETdelta
# Data
# 2014-01   -1.309896
# 2014-02 -139.101225
# 2014-03   72.083422
# 2014-04  115.394489
# 2014-05   79.387877
#
# [5 rows x 41 columns]

# %%
dfAnn.head()
# Out:
#             obs_runoff     prp       so_et      sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01   39.545687  2659.6  613.861752  435.153854  44.967620   49.285233
# 2015-01-01    6.889082   808.2  476.830919  332.544177  13.750381   13.555794
# 2016-01-01   13.196925  1532.0  655.322637  461.775288  26.227954   20.096799
# 2017-01-01    6.030048  1090.4  486.359716  340.986681  11.789062   11.536879
#
#             pt_runoff  fao_runoff      fao_et       pt_et  ...  \
# Date                                                       ...
# 2014-01-01  46.237673   43.849447  450.336914  503.225470  ...
# 2015-01-01  12.291204   11.994478  292.709794  363.120932  ...
# 2016-01-01  22.020820   22.481078  398.530315  552.038323  ...
# 2017-01-01  12.916337   13.518876  156.592047  398.336283  ...
#
#             residual_obs + et_obs  residual_obs  residual_so  residual_sog  \
# Date
# 2014-01-01             852.386838    851.686838  -162.891374     96.424402
# 2015-01-01             520.445897    495.770897  -161.354931   -341.234485
# 2016-01-01             960.839557    939.764557  -274.168852    -10.511868
# 2017-01-01             822.292261    879.392261    43.583606    145.973127
#
#             residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01   236.877203    338.590512           450.970377
# 2015-01-01   155.211255    226.616790           315.475987
# 2016-01-01   366.826800    520.896675           381.153786
# 2017-01-01   385.071843    601.884051           529.943322
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt
# Date
# 2014-01-01             788.917361           1110.815007           740.102674
# 2015-01-01             519.326584            389.390611           518.332187
# 2016-01-01             919.426990           1283.386057           918.865122
# 2017-01-01             758.476098            873.519524           783.408126
#
# [4 rows x 37 columns]

# %%
ticklabelsY = ['2012', '', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
               
print(ticklabelsY)
# Out:
# ['2012', '', '', '', '', '2013', '', '', '', '', '', '', '', '', '', '', '', '2014', '', '', '', '', '', '', '', '', '', '', '', '2015', '', '', '', '', '', '', '', '', '', '', '', '2016', '', '', '', '', '', '', '', '', '', '']

# %%
dfAnn.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt'],
#       dtype='object')

# %%
df11 = dfso.resample('1YS').agg('sum')
df21 = dfsog.resample('1YS').agg('sum')
df31 = dffao.resample('1YS').agg('sum')
df41 = dfpt.resample('1YS').agg('sum')
df51 = dfPrp.resample('1YS').agg('sum')
df61 = df['residual_obs + et_obs'].resample('1YS').agg('sum')

# %%
dfprpet = pd.concat([df11,df21,df31,df41,df51,df61],axis=1)

# %%
dfprpet
# Out:
#                  so_et      sog_et      fao_et       pt_et          prp  \
# Date
# 2012-01-01  243.433610  171.654681  124.617873  117.468980   302.400000
# 2013-01-01  676.688947  472.902771  435.726512  524.308696   554.500000
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.000000
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.800000
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.800000
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.400000
# 2018-01-01  693.603661  491.140634  522.292308  592.254333   947.066667
# 2019-01-01  184.172939  127.102420  129.538469  120.527458    72.316667
#
#             residual_obs + et_obs
# Date
# 2012-01-01                    NaN
# 2013-01-01                    NaN
# 2014-01-01             852.386838
# 2015-01-01             520.445897
# 2016-01-01             960.839557
# 2017-01-01             822.292261
# 2018-01-01                    NaN
# 2019-01-01                    NaN

# %%
dfprpet.index
# Out:
# DatetimeIndex(['2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='Date', freq='AS-JAN')

# %%
dfprpet = dfprpet.iloc[2:6,:]

# %%
dfprpet.head()
# Out:
#                  so_et      sog_et      fao_et       pt_et     prp  \
# Date
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.0
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.8
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.8
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.4
#
#             residual_obs + et_obs
# Date
# 2014-01-01             852.386838
# 2015-01-01             520.445897
# 2016-01-01             960.839557
# 2017-01-01             822.292261

# %%
years = mdates.YearLocator()
dfprpet.index = dfprpet.index.strftime('%Y')
dfprpet.index
# Out:
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
dfprpet['ET GF%'] =100*dfprpet['so_et']/( dfprpet['prp'])
dfprpet['ET Obs%'] =100*dfprpet['residual_obs + et_obs']/( dfprpet['prp'])
dfprpet['ET FAO%'] =100*dfprpet['fao_et']/( dfprpet['prp'])
dfprpet['ET PT%'] =100*dfprpet['pt_et']/( dfprpet['prp'])
dfprpet['prp%'] =1
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# ITALIANO
plt.style.use('default')
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
axy = ax.twinx()



dfprpet.plot(y=['ET GF%'],kind='line', ax = axy, label = ['%ET$_{Ps}$'],color='r',linewidth=5, rot = -0,stacked=False)
dfprpet.plot(y=['ET Obs%'],kind='line', ax = axy, label = ['%ET$_{obs}$'],color='orange',linewidth=5, rot = -0,stacked=False)

dfprpet.plot(y=['so_et','fao_et','pt_et','residual_obs + et_obs','prp'],kind='bar', ax = ax, 
             colormap='GnBu',edgecolor=".3",linewidth=1.5, rot = -0,stacked=False,
             label = ['ET$_{Ps}$','ET$_{FAO}$','ET$_{PT}$','ET$_{obs}$+$\Delta$','PRP'])

major_ticks = np.arange(0, 3001, 600)
axy.set_ylim([0,100])
ax.set_ylim([-1,3000])
ax.set_yticks(major_ticks)
ax.set_ylabel('ET-PRP [mm]',fontsize=40,fontweight='bold')
ax.set_xlabel('Data',fontsize=40,fontweight='bold')
# ax.legend(loc='upper center',fontsize=30, ncol=3,handleheight=1, labelspacing=0.05)   
ax.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.35, 1.15),ncol=5,handleheight=1, labelspacing=0.05)   

axy.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.85, 1.15),ncol=2,handleheight=1, labelspacing=0.05)  
plt.grid(True)
for ax in [ ax,axy]:
    ax.tick_params(axis='both', which='major', labelsize=40)
    # ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
#     ax.legend(loc='upper right',fontsize=20)

# %%
f=open('output/EFC-luca_15_RioRessi_SO_NS_1500/out/luca_summary.txt')
lines=f.readlines()
a_so = lines[293]
b_so = a_so[40:-1]
b_so = float(b_so)
b_so
# Out:
# 0.7012170368084857

# %%
f=open('output/EFC-luca_15_RioRessi_PT_NS_1500/out/luca_summary.txt')
lines=f.readlines()
a_pt = lines[293]
b_pt = a_pt[40:-1]
b_pt = float(b_pt)
b_pt
# Out:
# 0.7432621025769367

# %%
f=open('output/EFC-luca_15_RioRessi_FAO_NS_1500/out/luca_summary.txt')
lines=f.readlines()
a_fao = lines[293]
b_fao = a_fao[40:-1]
b_fao = float(b_fao)
b_fao
# Out:
# 0.7201447954803379

# %%
df2.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et     so_runoff  sog_runoff  \
# Date
# 2014-01-01 01:00:00    0.003059  0.0    NaN     NaN  2.331076e-12    0.006350
# 2014-01-01 02:00:00    0.003044  0.0    NaN     NaN  2.170527e-12    0.006079
# 2014-01-01 03:00:00    0.003015  0.0    NaN     NaN  2.301277e-12    0.006294
# 2014-01-01 04:00:00    0.002957  0.0    NaN     NaN  2.194795e-12    0.006097
# 2014-01-01 05:00:00    0.002972  0.0    NaN     NaN  2.281513e-12    0.006250
#
#                         pt_runoff    fao_runoff    fao_et  pt_et  ...  \
# Date                                                              ...
# 2014-01-01 01:00:00  2.058098e-09  1.799838e-12  0.010065    0.0  ...
# 2014-01-01 02:00:00  1.892253e-09  1.668946e-12  0.012050    0.0  ...
# 2014-01-01 03:00:00  2.026700e-09  1.779328e-12  0.012755    0.0  ...
# 2014-01-01 04:00:00  1.917821e-09  1.686241e-12  0.008917    0.0  ...
# 2014-01-01 05:00:00  2.006109e-09  1.764743e-12  0.009778    0.0  ...
#
#                      residual_obs + et_obs  residual_obs  residual_so  \
# Date
# 2014-01-01 01:00:00                    NaN           NaN          NaN
# 2014-01-01 02:00:00               0.137926     -0.212074          NaN
# 2014-01-01 03:00:00               0.293006      0.068006          NaN
# 2014-01-01 04:00:00               0.234144     -0.115856          NaN
# 2014-01-01 05:00:00               0.202737     -0.097263          NaN
#
#                      residual_sog  residual_pt  residual_fao  \
# Date
# 2014-01-01 01:00:00           NaN          NaN           NaN
# 2014-01-01 02:00:00           NaN    -0.136637     -0.150819
# 2014-01-01 03:00:00           NaN    -0.135095     -0.150193
# 2014-01-01 04:00:00           NaN    -0.133138     -0.143717
# 2014-01-01 05:00:00           NaN    -0.133581     -0.145235
#
#                      residual_so + et_so  residual_fao + et_fao  \
# Date
# 2014-01-01 01:00:00                  NaN                    NaN
# 2014-01-01 02:00:00                  NaN              -0.138768
# 2014-01-01 03:00:00                  NaN              -0.137438
# 2014-01-01 04:00:00                  NaN              -0.134800
# 2014-01-01 05:00:00                  NaN              -0.135456
#
#                      residual_obs + et_so  residual_pt + et_pt
# Date
# 2014-01-01 01:00:00                   NaN                  NaN
# 2014-01-01 02:00:00                   NaN            -0.136637
# 2014-01-01 03:00:00                   NaN            -0.135095
# 2014-01-01 04:00:00                   NaN            -0.133138
# 2014-01-01 05:00:00                   NaN            -0.133581
#
# [5 rows x 37 columns]

# %%
df2.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.025905  0.0       NaN       NaN   0.004919
# 2017-12-12 08:00:00    0.022905  0.0  0.000980  0.000488   0.004937
# 2017-12-12 09:00:00    0.020718  0.0  0.005354  0.004186   0.004965
# 2017-12-12 10:00:00    0.019104  0.0  0.016122  0.013651   0.005010
# 2017-12-12 11:00:00    0.017604  0.0  0.023910  0.020138   0.005073
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.027334   0.021092    0.006318  0.000290  0.000000
# 2017-12-12 08:00:00    0.025759   0.019970    0.006445  0.000224  0.000000
# 2017-12-12 09:00:00    0.024344   0.018866    0.006607  0.000186  0.000000
# 2017-12-12 10:00:00    0.023059   0.018607    0.006805  0.002708  0.003355
# 2017-12-12 11:00:00    0.021897   0.018144    0.007054  0.015322  0.020300
#
#                      ...  residual_obs + et_obs  residual_obs  residual_so  \
# Date                 ...
# 2017-12-12 07:00:00  ...               0.539741     -3.935259          NaN
# 2017-12-12 08:00:00  ...              -1.411960     -6.186960    -0.097877
# 2017-12-12 09:00:00  ...              -2.115733     -4.490733    -0.160946
# 2017-12-12 10:00:00  ...              -2.385135     -3.835135    -0.206202
# 2017-12-12 11:00:00  ...              -1.896236     -2.946236    -0.286926
#
#                      residual_sog  residual_pt  residual_fao  \
# Date
# 2017-12-12 07:00:00           NaN    -1.167056      0.007205
# 2017-12-12 08:00:00     -1.412447    -0.996320      0.064520
# 2017-12-12 09:00:00     -2.119919    -0.966950      0.088143
# 2017-12-12 10:00:00     -2.398786    -0.934177      0.090869
# 2017-12-12 11:00:00     -1.916374    -0.961345      0.085208
#
#                      residual_so + et_so  residual_fao + et_fao  \
# Date
# 2017-12-12 07:00:00                  NaN               0.007495
# 2017-12-12 08:00:00            -0.096897               0.064744
# 2017-12-12 09:00:00            -0.155592               0.088329
# 2017-12-12 10:00:00            -0.190079               0.093577
# 2017-12-12 11:00:00            -0.263017               0.100530
#
#                      residual_obs + et_so  residual_pt + et_pt
# Date
# 2017-12-12 07:00:00                   NaN            -1.167056
# 2017-12-12 08:00:00             -6.185979            -0.996320
# 2017-12-12 09:00:00             -4.485379            -0.966950
# 2017-12-12 10:00:00             -3.819013            -0.930822
# 2017-12-12 11:00:00             -2.922326            -0.941044
#
# [5 rows x 37 columns]

# %%
df2 = df3

# %%
df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']].tail()
# Out:
#                      obs_storage  so_storage  sog_storage  pt_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  406.973570    76.522594  322.396380
# 2017-12-12 08:00:00     227.9550  406.845329    76.309374  321.287176
# 2017-12-12 09:00:00     229.1260  406.774536    76.126888  320.254114
# 2017-12-12 10:00:00     230.6400  406.736145    75.968592  319.289401
# 2017-12-12 11:00:00     231.7335  406.767817    75.828499  318.386136
#
#                      fao_storage  storage_gw
# Date
# 2017-12-12 07:00:00   360.070097     142.350
# 2017-12-12 08:00:00   360.021957     147.125
# 2017-12-12 09:00:00   360.044174     149.500
# 2017-12-12 10:00:00   360.103860     150.950
# 2017-12-12 11:00:00   360.242168     152.000

# %%
df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']].plot()

# %%
dfS2 =df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']]
dfMonM = dfS2.resample('MS').agg('mean')
dfS2['sog_storage']=df3['obs_storage']+df3['storage_gw']

dfS2[dfS2 < 0]=np.nan
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
dfS2['month'] = pd.DatetimeIndex(dfS2.index).month
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfMonM[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']].plot()

# %%
dfS2.tail()
# Out:
#                      obs_storage  so_storage  sog_storage  pt_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  406.973570     369.9375  322.396380
# 2017-12-12 08:00:00     227.9550  406.845329     375.0800  321.287176
# 2017-12-12 09:00:00     229.1260  406.774536     378.6260  320.254114
# 2017-12-12 10:00:00     230.6400  406.736145     381.5900  319.289401
# 2017-12-12 11:00:00     231.7335  406.767817     383.7335  318.386136
#
#                      fao_storage  storage_gw  month
# Date
# 2017-12-12 07:00:00   360.070097     142.350     12
# 2017-12-12 08:00:00   360.021957     147.125     12
# 2017-12-12 09:00:00   360.044174     149.500     12
# 2017-12-12 10:00:00   360.103860     150.950     12
# 2017-12-12 11:00:00   360.242168     152.000     12

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax11 = ax
# ax21 = ax.twinx()
################################################################################
dfS2.plot(ax=ax11, y=['obs_storage','so_storage','sog_storage','pt_storage','fao_storage'],
          kind='line', stacked=False, colormap='Dark2', alpha =0.9,linewidth=3,
                  label=['GEOframe','FAO','Storage RZ + GW','PT','Obs.'])
################################################################################
ax11.legend(loc='upper center',fontsize=25, bbox_to_anchor=(0.5, 1.12), ncol=5, frameon =True)

for ax in [ax11]:
    ax.set_ylim([50,500])
    ax.set_ylabel('Storage Root Zone [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)

# %%
df2 = df3

# %%
df2[df2==-9999]=np.nan

# %%
maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')

# %%
df2 = df2.loc[maskYear].dropna(how='any')

# %%
dfRun = df3

# %%
dfRun['obs_runoff_cum'] = dfRun[['obs_runoff']].resample('48MS').agg(['cumsum'])

# %%
dfRun['obs_litri_runoff'] = dfRun['obs_runoff']*1000
dfRun['so_litri_runoff'] = dfRun['so_runoff']*1000
dfRun['sog_litri_runoff'] = dfRun['sog_runoff']*1000
dfRun['pt_litri_runoff'] = dfRun['pt_runoff']*1000
dfRun['fao_litri_runoff'] = dfRun['fao_runoff']*1000


dfRun['obs_runoff_cum'] = dfRun[['obs_runoff']].resample('48MS').agg(['cumsum'])
dfRun['so_runoff_cum'] = dfRun[['so_runoff']].resample('48MS').agg(['cumsum'])
dfRun['sog_runoff_cum'] = dfRun[['sog_runoff']].resample('48MS').agg(['cumsum'])
dfRun['pt_runoff_cum'] = dfRun[['pt_runoff']].resample('48MS').agg(['cumsum'])
dfRun['fao_runoff_cum'] = dfRun[['fao_runoff']].resample('48MS').agg(['cumsum'])

# %%
dfRun.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.025905  0.0       NaN       NaN   0.004919
# 2017-12-12 08:00:00    0.022905  0.0  0.000980  0.000488   0.004937
# 2017-12-12 09:00:00    0.020718  0.0  0.005354  0.004186   0.004965
# 2017-12-12 10:00:00    0.019104  0.0  0.016122  0.013651   0.005010
# 2017-12-12 11:00:00    0.017604  0.0  0.023910  0.020138   0.005073
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.027334   0.021092    0.006318  0.000290  0.000000
# 2017-12-12 08:00:00    0.025759   0.019970    0.006445  0.000224  0.000000
# 2017-12-12 09:00:00    0.024344   0.018866    0.006607  0.000186  0.000000
# 2017-12-12 10:00:00    0.023059   0.018607    0.006805  0.002708  0.003355
# 2017-12-12 11:00:00    0.021897   0.018144    0.007054  0.015322  0.020300
#
#                      ...  obs_runoff_cum  obs_litri_runoff  so_litri_runoff  \
# Date                 ...
# 2017-12-12 07:00:00  ...       65.581410            25.905         4.918691
# 2017-12-12 08:00:00  ...       65.604315            22.905         4.937278
# 2017-12-12 09:00:00  ...       65.625033            20.718         4.964622
# 2017-12-12 10:00:00  ...       65.644137            19.104         5.010357
# 2017-12-12 11:00:00  ...       65.661741            17.604         5.073396
#
#                      sog_litri_runoff  pt_litri_runoff  fao_litri_runoff  \
# Date
# 2017-12-12 07:00:00         27.333682        21.092284          6.317551
# 2017-12-12 08:00:00         25.758644        19.970395          6.444764
# 2017-12-12 09:00:00         24.343606        18.866214          6.606718
# 2017-12-12 10:00:00         23.058929        18.607047          6.805167
# 2017-12-12 11:00:00         21.896985        18.143955          7.054217
#
#                      so_runoff_cum  sog_runoff_cum  pt_runoff_cum  \
# Date
# 2017-12-12 07:00:00      96.715032       94.379647      93.390447
# 2017-12-12 08:00:00      96.719969       94.405405      93.410417
# 2017-12-12 09:00:00      96.724933       94.429749      93.429283
# 2017-12-12 10:00:00      96.729944       94.452808      93.447890
# 2017-12-12 11:00:00      96.735017       94.474705      93.466034
#
#                      fao_runoff_cum
# Date
# 2017-12-12 07:00:00       91.816967
# 2017-12-12 08:00:00       91.823412
# 2017-12-12 09:00:00       91.830019
# 2017-12-12 10:00:00       91.836824
# 2017-12-12 11:00:00       91.843878
#
# [5 rows x 47 columns]

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt


def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)


# fig, host = plt.subplots()
fig, host = plt.subplots(figsize=(30,20))

fig.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

par2.spines["right"].set_position(("axes", 1.09))
make_patch_spines_invisible(par2)
par2.spines["right"].set_visible(True)

dfRun.plot(kind='line', y=['so_litri_runoff'], ax=host,linewidth=3,  label=['Runoff sim.'],rot = 30,
        color=['red'],alpha = 0.75)
dfRun.plot(kind='line', y=['obs_runoff_cum','so_runoff_cum'], ax=par1,linewidth=3, label=['Obs. cum.','Sim. cum.'],rot = -0,
         color=['gray','orange'],alpha = 1)
dfRun.plot(kind='line', y=['obs_litri_runoff'], ax=host,linewidth=3, label=['Runoff obs.'],rot = 30,
         color=['k'],alpha = 0.5)
par2.plot(dfRun.index,-dfRun['prp'],label='Rainfall',color="blue",linewidth=3)

host.set_ylim(0, 120)
par1.set_ylim(0, 120)
par2.set_ylim(-80, 0)

host.set_xlabel('Date',fontsize=30)
host.set_ylabel('Runoff [l/s]',fontsize=30)
par1.set_ylabel('Cumulated Runoff [10$^{3}$ m$^{3}$]',fontsize=30)
par2.set_ylabel('Rainfall [mm]',fontsize=30)
plt.title('Runoff - Prospero \n \n',size=30)

tkw = dict(size=4, width=1.5)
host.tick_params(axis='y')#, colors=p1.get_color(), **tkw)
par1.tick_params(axis='y')#, colors=p2.get_color(), **tkw)
par2.tick_params(axis='y')#, colors=p3.get_color(), **tkw)
host.tick_params(axis='x')#, **tkw)

y2_ticks = np.linspace(80,0, 9)
y2_ticklabels = [str(i) for i in y2_ticks]
par2.set_yticklabels(y2_ticklabels)

ax11.legend(loc='upper left',fontsize=15)
for ax in [ host,par1, par2]:
    ax.set_xlabel('Date',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30) 
    
# lines = [p1, p2, p3]
host.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.15, 1.07), ncol=2, frameon =False)
par1.legend(loc='upper right',fontsize=30, bbox_to_anchor=(0.8, 1.07), ncol=2, frameon =False)
par2.legend(loc='upper left',fontsize=30, bbox_to_anchor=(0.85, 1.07), ncol=1, frameon =False)

plt.show()
