# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/RRRDP/"                
os.chdir(path)

# %%
# # Open with dataframe the file
# dfsoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated.csv',
#                   parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
# dfsoS.columns = ['','Date','soSt']
# dfsoS.index = dfsoS['Date']
# dfsoS = dfsoS.iloc[:,2:]

# dfsogS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated_FG.csv',
#                   parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
# dfsogS.columns = ['','Date','soGSt']
# dfsogS.index = dfsogS['Date']
# dfsogS = dfsogS.iloc[:,2:]

# dfptS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_KGE_validated.csv',
#                   parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
# dfptS.columns = ['','Date','ptSt']
# dfptS.index = dfptS['Date']
# dfptS = dfptS.iloc[:,2:]

# dffaoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_KGE_validated.csv',
#                   parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
# dffaoS.columns = ['','Date','faoSt']
# dffaoS.index = dffaoS['Date']
# dffaoS = dffaoS.iloc[:,2:]

# dfObsS= pd.read_csv('data/RioRessi/1/RioRessi_Root14.csv',
#                   parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
# dfObsS.columns = ['','Date','obsSt']
# dfObsS.index = dfObsS['Date']
# dfObsS = dfObsS.iloc[:,2:]

# %% [markdown]
# # NS

# %%
# Open with dataframe the file
dfsoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoS.columns = ['','Date','soSt']
dfsoS.index = dfsoS['Date']
dfsoS = dfsoS.iloc[:,2:]

dfsogS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_NS_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogS.columns = ['','Date','soGSt']
dfsogS.index = dfsogS['Date']
dfsogS = dfsogS.iloc[:,2:]

dfptS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptS.columns = ['','Date','ptSt']
dfptS.index = dfptS['Date']
dfptS = dfptS.iloc[:,2:]

dffaoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_NS_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoS.columns = ['','Date','faoSt']
dffaoS.index = dffaoS['Date']
dffaoS = dffaoS.iloc[:,2:]

dfObsS= pd.read_csv('data/RioRessi/1/RioRessi_Root14.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsS.columns = ['','Date','obsSt']
dfObsS.index = dfObsS['Date']
dfObsS = dfObsS.iloc[:,2:]

# %%
df = pd.concat([dfsoS,dfsogS,dfptS,dffaoS,dfObsS],axis=1)
df.head()
# Out:
#                            soSt       soGSt        ptSt       faoSt      obsSt
# Date
# 2014-01-01 00:00:00  172.044099  172.098228  102.831912  173.414028  294.26400
# 2014-01-01 01:00:00  172.075124  172.149160  102.831912  173.411428  293.80650
# 2014-01-01 02:00:00  172.086537  172.167895  102.831912  173.408274  295.84575
# 2014-01-01 03:00:00  172.090735  172.174788  102.831912  173.404891  293.07450
# 2014-01-01 04:00:00  172.092280  172.177323  102.831912  173.402501  295.13850

# %%
#df.rename(columns={list(df)[1]:'Datetime'}, inplace=True)
# df.columns = ['','Datetime','so','pt','fao','obs']
# df[df ==-9999]=np.nan

# %%
# df['Datetime'] = pd.to_datetime(df['Datetime'], dayfirst=True)
# df['Datetime'] = df['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
# df.index = df['Datetime']
# df.index = pd.DatetimeIndex(df.index)
df2=df
# df2df2.iloc[:,2:]
idx = pd.date_range(t_start, t_end,freq="H")
indice =0

# %%
df2['soCum'] = df2['soSt'].resample('46MS').agg(['cumsum'])
df2['soGCum'] = df2['soGSt'].resample('46MS').agg(['cumsum'])
df2['ptCum'] = df2['ptSt'].resample('46MS').agg(['cumsum'])
df2['obsCum'] = df2['obsSt'].resample('46MS').agg(['cumsum'])

# %%
# df2['obs']=df2['obs']*1000
# df2['soG']=df2['soG']*1000
# df2['so']=df2['so']*1000
# df2['pt']=df2['pt']*1000
# df2['fao']=df2['fao']*1000

# %%
df2.head()
# Out:
#                            soSt       soGSt        ptSt       faoSt  \
# Date
# 2014-01-01 00:00:00  172.044099  172.098228  102.831912  173.414028
# 2014-01-01 01:00:00  172.075124  172.149160  102.831912  173.411428
# 2014-01-01 02:00:00  172.086537  172.167895  102.831912  173.408274
# 2014-01-01 03:00:00  172.090735  172.174788  102.831912  173.404891
# 2014-01-01 04:00:00  172.092280  172.177323  102.831912  173.402501
#
#                          obsSt       soCum      soGCum       ptCum      obsCum
# Date
# 2014-01-01 00:00:00  294.26400  172.044099  172.098228  102.831912   294.26400
# 2014-01-01 01:00:00  293.80650  344.119223  344.247389  205.663825   588.07050
# 2014-01-01 02:00:00  295.84575  516.205759  516.415284  308.495737   883.91625
# 2014-01-01 03:00:00  293.07450  688.296494  688.590072  411.327649  1176.99075
# 2014-01-01 04:00:00  295.13850  860.388774  860.767395  514.159561  1472.12925

# %%
# idx = pd.date_range('2012-08-01 00:00','2016-11-23 23:00', freq='1H')
# idx
#df.index = idx

# %%
# maskYear = (df['Datetime'] > '2015-01-01 00:00:00') & (df['Datetime'] <= '2015-12-31 23:00:00')

# %%
#df2 = df.iloc[:,2:]
#df2 = df2.loc[maskYear]
#df2[df2 >0.015]=0.015
# df2 = df

# %%
# fig = plt.figure(figsize=(20,10))
# ax1 = fig.add_subplot(111)
# #df3['Discharge [m^3/s]'].plot(ax1)
# df2.plot(ax=ax1, y=['so','pt','fao','obs'],kind='line', stacked=False, 
#                   label=['so','pt','fao','obs'],linewidth=2)#,'El + err','El + bow'],

# %%
# fig = plt.figure(figsize=(20,10))
# ax1 = fig.add_subplot(111)
# #df3['Discharge [m^3/s]'].plot(ax1)
# df2.plot(ax=ax1, y=['obs'],         kind='line', stacked=False, 
#                   label=['idro'],linewidth=6)#,'El + err','El + bow'],
# df2.plot(ax=ax1, y=['so'],         kind='line', stacked=False, 
#                   label=['idroso'],linewidth=2)#,'El + err','El + bow'],
# df2.plot(ax=ax1, y=['pt'],         kind='line', stacked=False, 
#                   label=['pt'],linewidth=2)#,'El + err','El + bow'],
# #df2.plot(ax=ax1, y=['idroAllKGE_mod'],         kind='line', stacked=False, 
# df2.plot(ax=ax1, y=['fao'],         kind='line', stacked=False, 
#                   label=['fao'],linewidth=2)#,'El + err','El + bow'],

#                #   label=['idroAllKGE_mod'],linewidth=2)#,'El + err','El + bow'],

# %%
# import plotly.plotly as py
# import plotly.tools as tls

# %%
# # Learn about API authentication here: https://plot.ly/python/getting-started
# # Find your api_key here: https://plot.ly/settings/api

# ax = plt.subplot(111)

# t = np.arange(0.0, 5.0, 0.01)
# s = np.cos(2*np.pi*t)
# line, = plt.plot(t, s, lw=2)

# plt.annotate('local max', xy=(2, 1), xytext=(2.9, 1.1),
#              arrowprops=dict(facecolor='black', shrink=0.05))

# plt.ylim(-2,2)
# fig = plt.gcf()
# # plot_url = py.plot_mpl(fig, filename='mpl-simple-annotation')

# %%
# import plotly.plotly as py
# import plotly.graph_objs as go

# trace1 = go.Scatter(
#     x=[0, 1, 2, 3, 4, 5, 6, 7, 8],
#     y=[0, 1, 3, 2, 4, 3, 4, 6, 5]
# )
# trace2 = go.Scatter(
#     x=[0, 1, 2, 3, 4, 5, 6, 7, 8],
#     y=[0, 4, 5, 1, 2, 2, 3, 4, 2]
# )
# data = [trace1, trace2]
# layout = go.Layout(
#     showlegend=False,
#     annotations=[
#         dict(
#             x=2,
#             y=5,
#             xref='x',
#             yref='y',
#             text='max=5',
#             showarrow=True,
#             font=dict(
#                 family='Courier New, monospace',
#                 size=16,
#                 color='#ffffff'
#             ),
#             align='center',
#             arrowhead=2,
#             arrowsize=1,
#             arrowwidth=2,
#             arrowcolor='#636363',
#             ax=20,
#             ay=-30,
#             bordercolor='#c7c7c7',
#             borderwidth=2,
#             borderpad=4,
#             bgcolor='#ff7f0e',
#             opacity=0.8
#         )
#     ]
# )
# # fig = go.Figure(data=data, layout=layout)

# %%
import datetime as dt

# %%
# maskYear = (dfDiff.index >= '2014-01-01 00:00:00') & (dfDiff.index <= '2016-11-23 11:00')
# maskYear = (df2.index >= '2014-01-01 00:00') & (df2.index <= '2015-12-31 23:00')
maskYear = (df2.index >= '2014-01-01 00:00') & (df2.index <= '2016-11-23 11:00')


# maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')
# maskYear = (df2.index >= '2012-08-20 19:00') & (df2.index <= '2014-12-31 23:00')

# %%
df2 = df2.loc[maskYear]#.dropna(how='any')

# %%
# s = pd.Series({Timestamp('2014-11-08 00:00:00'): 345,
#     Timestamp('2014-11-09 00:00:00'): 678,
#     Timestamp('2014-11-10 00:00:00'): 987,
#     Timestamp('2014-11-11 00:00:00'): 258})

# fig = plt.figure()
# ax = fig.gca()
# s.plot(ax=ax)

# i = 0
# ax.text(s.index[i], s.iloc[i], "Hello")
# ax.text(dt.date(2014, 11, 9), 500, "World")
# ax.text(Timestamp("2014-11-10"), 777, "!!!")

# plt.show()

# %%
# fig = plt.figure(figsize=(20,10))
# ax1 = fig.add_subplot(111)
# #df3['Discharge [m^3/s]'].plot(ax1)
# # style
# # plt.style.use('seaborn-darkgrid')
 
# # create a color palette
# palette = plt.get_cmap('Set1')

# df2.plot(ax=ax1, y=['obs'],         kind='line', stacked=False, color=palette(4),
#                   label=['obs'],linewidth=3)#,'El + err','El + bow'],
# df2.plot(ax=ax1, y=['so'],         kind='line', stacked=False, 
#                   label=['so'],linewidth=3, color=palette(5))#,'El + err','El + bow'],
# df2.plot(ax=ax1, y=['pt'],         kind='line', stacked=False, 
#                   label=['pt'],linewidth=3, color=palette(6))#,'El + err','El + bow'],

# i = 0
# # ax1.text(df2.index[i], df2.iloc[i], "Hello")
# ax1.text(dt.date(2014, 11, 9), 0.08, "World")
# # ax.text(Datetime("2014-11-10 00:00"), 0.08, "!!!")

# plt.axvline(x=dt.date(2014, 11, 9), color='k', linestyle='--')
# # plt.axvline(x=0.33088437)
# # plt.axvline(x=2.20589566)
# plt.show()
# # ax.text(dt.date(2014, 11, 9), 0.08, "World")

# # plt.annotate('local max', xy=(datetime.date(2012, 8, 20), 10), xytext=(2.9, 1.1),
# #              arrowprops=dict(facecolor='black', shrink=0.05))
# # fig.text(x=15, y=15.0, s=2)
# # plt.text(x=-0, y=0.1, s= round(1,3))
# # plt.text(x=0.1, y=0.03, s= round(1,3))

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20,20))
ax11 = axes[0]
ax21 = ax11.twinx()
ax12 = axes[1]
ax22 = ax12.twinx()
################################################################################
df2.plot(kind='line', y=['obsSt','soSt','soGSt'], ax=ax11,linewidth=1, cmap="BuPu", label=['Obs','Sim','SimGrass'],rot = -0,
         title='Runoff - GEOframe ET', color=['k','r','g'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','soCum','soGCum'], ax=ax21,linewidth=2, label=['Obs','Sim','SimGrass'],rot = -0,
#          title='Runoff - GEOframe ET', color=['b','c','m'],alpha = 1)
################################################################################
df2.plot(kind='line', y=['obsSt','ptSt'], ax=ax12,linewidth=1, label=['Obs','Sim'],rot = -0,
          color=['k','r'],alpha = 1)
# df2.plot(kind='line', y=['obsCum','ptCum'], ax=ax22,linewidth=2, label=['Obs','Sim'],rot = -0,
#          title='Runoff - Priestley-Taylor ET', color=['b','c'],alpha = 1)
################################################################################
ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11, ax12]:
#     ax.set_ylim([0,0.12])
    ax.set_ylabel('Runoff [l/s]',fontsize=20)
#     ax.set_xlabel('Date',fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  

for ax in [ ax21,ax22]:
#     ax.set_ylim([0,20])
    ax.set_ylabel('Cumulated Runoff [m3]',fontsize=20)
    ax.set_xlabel('Date',fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=20)
#     ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    
   
# # fig.add_subplot(111, frameon=False);
# plt.grid(False)
# plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
# # plt.ylabel("Runoff \n \n", size=20, family='DejaVu Sans');       
# # plt.xlabel("Date", size=20, family='DejaVu Sans');               
# plt.title("Rio Ressi \n", size=24, family='DejaVu Sans');

#plt.tight_layout()
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:211: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   warnings.warn("'color' and 'colormap' cannot be used "
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/plotting/_style.py:31: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   warnings.warn("'color' and 'colormap' cannot be used "

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df2.plot(ax=ax1, y=['obsSt','soSt','soGSt','faoSt','ptSt'],kind='area', stacked=False, 
                  label=['obsSt','soSt','soGSt','faoSt','ptSt'],linewidth=2)#,'El + err','El + bow'],

# %%
dfM = df2.resample('MS').agg('mean')

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
dfM.plot(ax=ax1, y=['obsSt','soSt','soGSt','faoSt','ptSt'],kind='area', stacked=False, 
                  label=['obsSt','soSt','soGSt','faoSt','ptSt'],linewidth=2)#,'El + err','El + bow'],

# %%
dfS2 = df
dfS2['obs-so']=dfS2['obsSt']-dfS2['soSt']
dfS2['obs-pt']=dfS2['ptSt']-dfS2['faoSt']
dfS2['obs-fao']=dfS2['faoSt']-dfS2['obsSt']

# dfS2[dfS2 < 0]=np.nan

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax11 = ax
# ax21 = ax.twinx()
################################################################################
dfS2.plot(kind='area', y=['soSt','obs-so','obs-fao','obs-pt'],linewidth=1, ax = ax11, 
          label=['Storage - GEOframe','Storage - Obs.','Storage - FAO','Storage - PT'],rot = -0,
         colormap='Dark2',
#           color=['g','k'],
         alpha =0.5)
# df2.plot(kind='line', y=['obsCum','soCum'],linewidth=3, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#          color=['b','c'],alpha = 1)
################################################################################
ax11.legend(loc='upper center',fontsize=25, bbox_to_anchor=(0.5, 1.12), ncol=4, frameon =True)
# # ax21.legend(loc='upper right',fontsize=15)

# # ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11]:
    ax.set_ylim([100,500])
    ax.set_ylabel('Storage Root Zone [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)  
    
# plt.title("Storage - GEOframe ET", size=30, family='DejaVu Sans');               
# plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-7730569ca576> in <module>()
#       7          colormap='Dark2',
#       8 #           color=['g','k'],
# ----> 9          alpha =0.5)
#      10 # df2.plot(kind='line', y=['obsCum','soCum'],linewidth=3, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#      11 #          color=['b','c'],alpha = 1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     983                              stacking_id=stacking_id,
#     984                              is_errorbar=is_errorbar,
# --> 985                              **kwds)
#     986             self._add_legend_handle(newlines[0], label, index=i)
#     987
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1022         ax._plot_data.append((data, cls._kind, kwds))
#    1023
# -> 1024         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1025         # set date formatter, locators and rescale limits
#    1026         format_dateaxis(ax, ax.freq, data.index)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1111         if column_num == 0:
#    1112             cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1113         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
#    1114
#    1115         # need to remove label, because subplots uses mpl legend as it is
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _get_stacked_values(cls, ax, stacking_id, values, label)
#    1060                          'all positive or negative.'
#    1061                          '{0} contains both positive and negative values'
# -> 1062                          .format(label))
#    1063
#    1064     @classmethod
#
# ValueError: When stacked is True, each column must be either all positive or negative.Storage - Obs. contains both positive and negative values

# %%
fig, ax = plt.subplots(figsize=(200,20))
ax11 = ax
ax21 = ax.twinx()
################################################################################
df2.plot(kind='line', y=['obs','so'],linewidth=6, ax = ax11, label=['Runoff Obs','Runoff Sim'],rot = -0,
#          colormap='Dark2',
         color=['k','r'],
         alpha = 1)
df2.plot(kind='line', y=['obsCum','soCum'],linewidth=6, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
         colormap='tab10',
#          color=['b','c'],
         alpha = 1)
################################################################################
ax.legend(loc='upper left',fontsize=60)
ax21.legend(loc='upper right',fontsize=60)

# ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11]:
    ax.set_ylim([0,80])
    ax.set_ylabel('Runoff [l/s]',fontsize=60)
    ax.set_xlabel('Date',fontsize=60)
    ax.tick_params(axis='both', which='major', labelsize=60)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 60)  
#     ax.set_yscale('log')
#     ax.set_ylim([10E-3,10E2])

ax11.text(dt.date(2016, 4, 10), 45, "calibration NS = 0.68",fontsize=60)
ax11.text(dt.date(2016, 4, 10), 35, "calibration KGE = 0.79",fontsize=60)

ax11.text(dt.date(2013, 1, 10), 45, "validation NS = 0.56",fontsize=60)
ax11.text(dt.date(2013, 1, 10), 35, "validation KGE = 0.69",fontsize=60)
plt.axvline(x=dt.date(2015, 1, 2), linewidth = 10, color='k', linestyle='--')

# plt.annotate('validation NS = 0.56', xy=(dt.date(2015, 9, 10), 5), xytext=(dt.date(2015, 5, 10), 8),
#              arrowprops=dict(facecolor='black', shrink=0.5))

for ax in [ax21]:
    ax.set_ylim([0,40])
    ax.set_ylabel('\n Cumulated Runoff [m^3]',fontsize=60)
    ax.tick_params(axis='both', which='major', labelsize=60)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 60)  

plt.title("Runoff - GEOframe ET", size=80, family='DejaVu Sans');               
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-ca9d13edf7b6> in <module>()
#       6 #          colormap='Dark2',
#       7          color=['k','r'],
# ----> 8          alpha = 1)
#       9 df2.plot(kind='line', y=['obsCum','soCum'],linewidth=6, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#      10          colormap='tab10',
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1786
#    1787                 # don't overwrite
# -> 1788                 data = data[y].copy()
#    1789
#    1790                 if isinstance(data, ABCSeries):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['obs' 'so'] not in index"

# %%
df3 = df2

# %%
df2 = df3

# %%
maskYear = (df2.index >= '2014-01-01 00:00') & (df2.index <= '2016-12-31 23:00')

# %%
df2 = df2.loc[maskYear]#.dropna(how='any')

# %%
from hydroeval import *

# %%
simulated_flow = df2.soSt
observed_flow = df2.obsSt
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_so = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_so = evaluator(kgem, simulated_flow, observed_flow,axis=1)
rmse_so = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_so)
print(kge_so)
print(rmse_so)
# Out:
# [-0.10947646]
# [[0.13859083 0.33855365 0.4664441  0.85917179]]
# [84.65558533]

# %%
simulated_flow = df2.soGSt
observed_flow = df2.obsSt
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_soG = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_soG = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_soG = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_soG)
print(kge_soG)
print(rmse_soG)
# Out:
# [-0.01604935]
# [0.04191648]
# [81.67089507]

# %%
simulated_flow = df2.ptSt
observed_flow = df2.obsSt
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_pt = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_pt = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_pt = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_pt)
print(kge_pt)
print(rmse_pt)
# Out:
# [-0.52256376]
# [-0.08623362]
# [143.5246927]

# %%
simulated_flow = df2.faoSt
observed_flow = df2.obsSt
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_fao = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_fao = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_fao = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_fao)
print(kge_fao)
print(rmse_fao)
# Out:
# [-0.03236969]
# [0.01312165]
# [83.01555211]

# %% [markdown]
# # 2016-2017

# %%
df2 = df3
maskYear = (df2.index >= '2016-01-01 00:00') & (df2.index <= '2017-12-12 12:00')

# %%
df2 = df2.loc[maskYear]#.dropna(how='any')

# %%
simulated_flow = df2.so
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_so = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_so = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_so = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_so)
print(kge_so)
print(rmse_so)
# Out:
# [0.5290075]
# [0.33929397]
# [0.53124782]

# %%
simulated_flow = df2.pt
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_pt = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_pt = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_pt = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_pt)
print(kge_pt)
print(rmse_pt)
# Out:
# [0.53550511]
# [0.37717405]
# [0.52645325]

# %%
simulated_flow = df2.fao
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_fao = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_fao = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_fao = evaluator(rmse, simulated_flow, observed_flow,axis=1)
print(nse_fao)
print(kge_fao)
print(rmse_fao)
# Out:
# [0.3640564]
# [0.06740522]
# [0.65356399]

# %% [markdown]
# # 2014-2017

# %%
df2 = df3
maskYear = (df2.index >= '2014-01-01 00:00') & (df2.index <= '2017-12-12 12:00')

# %%
df2 = df2.loc[maskYear]#.dropna(how='any')

# %%
simulated_flow = df2.so
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_so = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_so = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_so = evaluator(rmse, simulated_flow, observed_flow,axis=1)
pbias_so = evaluator(pbias, simulated_flow, observed_flow)

print(nse_so)
print(kge_so)
print(rmse_so)
print(pbias_so)
# Out:
# [0.62865502]
# [0.42046128]
# [0.72430424]
# [-35.18303004]

# %%
simulated_flow = df2.pt
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_pt = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_pt = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_pt = evaluator(rmse, simulated_flow, observed_flow,axis=1)
pbias_pt = evaluator(pbias, simulated_flow, observed_flow)

print(nse_pt)
print(kge_pt)
print(rmse_pt)
print(pbias_pt)
# Out:
# [0.64081862]
# [0.51304139]
# [0.70969773]
# [-25.66419049]

# %%
simulated_flow = df2.fao
observed_flow = df2.obs
simulated_flow = np.array(simulated_flow)
observed_flow = np.array(observed_flow)
nse_fao = evaluator(nse_c2m, simulated_flow, observed_flow,axis=0)
kge_fao = evaluator(kge_c2m, simulated_flow, observed_flow,axis=1)
rmse_fao = evaluator(rmse, simulated_flow, observed_flow,axis=1)
pbias_fao = evaluator(pbias, simulated_flow, observed_flow)

print(nse_fao)
print(kge_fao)
print(rmse_fao)
print(pbias_fao)
# Out:
# [0.58630457]
# [0.4774032]
# [0.77462921]
# [-33.03451916]

# %%
# Ratio NS sim NS th
0.58/0.667
# Out:
# 0.8695652173913042

# %%
0.58/0.8695652173913042
# Out:
# 0.667

# %%
# Rescaled NS 2012/2014
0.37579382/0.8695652173913042
# Out:
# 0.43216289300000005

# %%
my_kge = evaluator(kge, simulated_flow, observed_flow,axis=0)
my_kge
# Out:
# array([[0.59570596],
#        [0.76816288],
#        [0.76443763],
#        [1.23284241]])

# %%
# Rescaled KG 2012/2014
0.60487331/0.8695652173913042
# Out:
# 0.6956043065000002

# %%
mypbias = evaluator(pbias, simulated_flow, observed_flow,axis=0)
mypbias
# Out:
# array([-23.2842415])

# %%
df2.so.corr(df2.obs)
# Out:
# 0.7681628814582443

# %%
df2 = df3

# %%
df2[df2==-9999]=np.nan

# %%
# maskYear = (dfDiff.index >= '2014-01-01 00:00:00') & (dfDiff.index <= '2016-11-23 11:00')
maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')
# maskYear = (df2.index >= '2012-08-20 19:00') & (df2.index <= '2014-12-31 23:00')

# %%
df2 = df2.loc[maskYear]#.dropna(how='any')

# %%
simulated_flow = df2.so

# %%
observed_flow = df2.obs

# %%
simulated_flow = np.array(simulated_flow)

# %%
observed_flow = np.array(observed_flow)

# %%
my_kge = evaluator(kge, simulated_flow, observed_flow,axis=0)
my_kge

# %%
# Open with dataframe the file
dfSso= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_NS_D_validated.csv',sep=',',skiprows=6,low_memory=False)
dfSpt= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_NS_D_validated.csv',sep=',',skiprows=6,low_memory=False)
dfSfao= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_NS_D_validated.csv',sep=',',skiprows=6,low_memory=False)
# dfSObs= pd.read_csv('data/RioRessi/1/RioRessi_Root.csv',sep=',',skiprows=2,low_memory=False)
dfSObs= pd.read_csv('data/RioRessi/1/RioRessi_ROOT_D.csv',sep=',',skiprows=0,low_memory=False)


print(dfSso.head(2))
print(dfSpt.head(2))
print(dfSfao.head(2))
print(dfSObs.head(2))

# %%
dfS = pd.concat([dfSso,dfSpt.iloc[:,2],dfSfao.iloc[:,2],dfSObs.iloc[:,1]],axis=1)
dfS.head()

# %%
#df.rename(columns={list(df)[1]:'Datetime'}, inplace=True)
dfS.columns = ['','Datetime','so','pt','fao','obs']
dfS[dfS ==-9999]=np.nan
dfS[dfS ==-0]=np.nan

# %%
dfS['Datetime'] = pd.to_datetime(dfS['Datetime'], dayfirst=True)
dfS['Datetime'] = dfS['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
dfS.index = dfS['Datetime']
dfS.index = pd.DatetimeIndex(dfS.index)
dfS2=dfS
dfS2=dfS2.iloc[:,2:]
idx = pd.date_range(t_start, t_end,freq="H")
indice =0

# %%
dfS2['obs-so']=dfS2['obs']-dfS2['so']
dfS2[dfS2 < 0]=np.nan

# %%
dfS2 = dfS2.dropna(how='any')

# %%
# idx = pd.date_range("2012-08-20 19:00","2016-11-23 11:00",freq='1H')
idx = pd.date_range("2012-08-20","2016-11-23",freq='1D')

dfS2 = dfS2.reindex(idx)

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
dfS2.plot(ax=ax1, y=['so','pt','fao','obs','obs-so'],kind='line', stacked=False, 
                  label=['so','pt','fao','obs','obs-so'],linewidth=2)#,'El + err','El + bow'],

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax11 = ax
# ax21 = ax.twinx()
################################################################################
dfS2.plot(kind='area', y=['so','obs-so'],linewidth=1, ax = ax11, label=['Storage Obs','Storage Sim'],rot = -0,
         color=['r','k'],alpha =0.5)
# df2.plot(kind='line', y=['obsCum','soCum'],linewidth=3, ax = ax21,label=['Cum.Runoff Obs','Cum.Runoff Sim'],rot = -0,
#          color=['b','c'],alpha = 1)
################################################################################
ax11.legend(loc='upper left',fontsize=15)
# # ax21.legend(loc='upper right',fontsize=15)

# # ax11.legend(loc='upper left',fontsize=15)
for ax in [ax11]:
#     ax.set_ylim([0,0.08])
    ax.set_ylabel('Storage Root Zone [mm/m2]',fontsize=20)
    ax.set_xlabel('Date',fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
    
plt.title("Storage - GEOframe ET", size=20, family='DejaVu Sans');

# %%
# runoff = Prp*area - Storage*area - ET*area

# %%
dfET= pd.read_csv('data/RioRessi/1/RioRessi_ET_SO_flat_stress.csv',sep=',',skiprows=6,low_memory=False)
dfET[dfET ==-9999]=np.nan
dfET.plot()

# %%
dfET.columns=['','Datetime','et']
dfET.head()

# %%
dfET['Datetime'] = pd.to_datetime(dfET['Datetime'], dayfirst=True)
dfET['Datetime'] = dfET['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
dfET.index = dfET['Datetime']
dfET.index = pd.DatetimeIndex(dfET.index)
dfET2=dfET
dfET2=dfET2.iloc[:,1:]

# %%
dfETD = dfET2.resample('1D').agg('sum')

# %%
dfETD.plot()

# %%
df2 = df3

# %%
df2[df2==-9999]=np.nan

# %%
# maskYear = (dfDiff.index >= '2014-01-01 00:00:00') & (dfDiff.index <= '2016-11-23 11:00')
maskYear = (df2.index >= '2015-01-01 00:00') & (df2.index <= '2016-11-23 11:00')

# %%
df2 = df2.loc[maskYear].dropna(how='any')

# %%
yMean = df2['obs'].mean()

# %%
dfDiff = pd.concat([(df2['obs']-df2['so']), 
                    (df2['obs']-df2['pt']),
                    (df2['obs']-df2['fao']),
                    ((df2['obs']-df2['so']))**2,
                    df2['obs'],
                    (df2['obs']-yMean),
                    (df2['obs']-yMean)**2],axis=1, sort=False)
dfDiff.head()
dfDiff.columns = ['errSO','errPT','errFAO','errSO2','obs','obs-mean','obs-mean2']

# %%
dfDiff[['errSO2']]

# %%
a = dfDiff['errSO2'].sum()
b = dfDiff['obs-mean2'].sum()

# %%
df2['obs'].corr(df2['so'])

# %%
dfDiff.head()

# %%
asd=dfDiff['obs-mean2']

# %%
asd.sum()

# %%
print(a)
print(b)

# %%
c = dfDiff['errSO'].sum()*100
d = dfDiff['obs'].sum()

print(c)
print(d)

# %%
PBIAS = 1-c/d
print(PBIAS)

# %%
df3 = df2.resample('1D').agg(['sum'])

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df3.plot(ax=ax1, y=['obs'],         kind='line', stacked=False, 
                  label=['obs'],linewidth=3)#,'El + err','El + bow'],
df3.plot(ax=ax1, y=['so'],         kind='line', stacked=False, 
                  label=['so'],linewidth=2)#,'El + err','El + bow'],
df3.plot(ax=ax1, y=['pt'],         kind='line', stacked=False, 
                  label=['pt'],linewidth=2)#,'El + err','El + bow'],

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df3.plot(ax=ax1, y=['obs'],         kind='line', stacked=False, 
                  label=['obs'],linewidth=2)#,'El + err','El + bow'],
df3.plot(ax=ax1, y=['so'],         kind='line', stacked=False, 
                  label=['so'],linewidth=2)#,'El + err','El + bow'],

# %%
df3.reindex(idx,fill_value='-9999')

# %%
df3 = df3.fillna(-9999)
df3.to_csv('RioRessi1216.csv')

# %%
## period & input name file
t_start='2012-01-01 00:15'
t_end='2018-10-01 00:00'
nameFile = 'meteorological_data_Valli_del_Pasubio_Castana.csv'
fmt = '%Y/%m/%d %H:%M:%S'

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/Silva/data/RioRessi/OriginalData"                
os.chdir(path)

# %%
# Open with dataframe the file
df= pd.read_csv(nameFile,sep=',',skiprows=0,low_memory=False)

# %%
df.rename(columns={list(df)[0]:'Datetime'}, inplace=True)
df[df ==-9999]=np.nan

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'], dayfirst=True)
df['Datetime'] = df['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
df.index = df['Datetime']
df.index = pd.DatetimeIndex(df.index)
df2=df
df2=df2.iloc[:,1:]
idx = pd.date_range(t_start, t_end,freq="H")
indice =0

# %%
df3 = df2.resample('1h').agg(['mean'])
df3.reindex(idx,fill_value='-9999')

df3 = df3.fillna(-9999)
df3 = df3

# %%
df3.to_csv('PasubioRH_RAD.csv')
df3 = df3

# %%
## period & input name file
t_start='2012-01-01 00:15'
t_end='2018-10-01 00:00'
nameFile = 'meteorological_data_Valli_del_Pasubio_Castana_wind.csv'
fmt = '%Y/%m/%d %H:%M:%S'

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/Silva/data/RioRessi/OriginalData"                
os.chdir(path)

# %%
# Open with dataframe the file
df= pd.read_csv(nameFile,sep=',',skiprows=0,low_memory=False)

# %%
df.rename(columns={list(df)[0]:'Datetime'}, inplace=True)
df[df ==-9999]=np.nan
df

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'], dayfirst=True)
df['Datetime'] = df['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
df.index = df['Datetime']
df.index = pd.DatetimeIndex(df.index)
df2=df
df2=df2.iloc[:,1:]
idx = pd.date_range(t_start, t_end,freq="H")
indice =0

# %%
df3 = df2.resample('1h').agg(['mean'])
df3.reindex(idx,fill_value='-9999')

df3 = df3.fillna(-9999)
df3 = df3
df3

# %%
df3.to_csv('PasubioWind.csv')
df3 = df3
df3

# %%
## period & input name file
t_start='2012-01-01 00:15'
t_end='2018-10-01 00:00'
nameFile = 'meteorological_data_Valli_del_Pasubio_Castana_wind.csv'
fmt = '%Y/%m/%d %H:%M:%S'

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/Silva/data/ReDellaPietra/"                
os.chdir(path)

# %%
idx = pd.date_range('2018-07-31 11:00','2018-07-09 17:35', freq='1T')
idx
#df.index = idx

# %%
# Open with dataframe the file
df= pd.read_csv(nameFile,sep=',',skiprows=8,low_memory=False)

# %%
dateHour = df.Date +' '+ df.Time

# %%
df.Date = dateHour

# %%
df.rename(columns={list(df)[2]:'Datetime'}, inplace=True)
df[df ==-9999]=np.nan
df

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])#, dayfirst=True)
df['Datetime'] = df['Datetime'].dt.strftime('%Y-%m-%d %H:%M')

# %%
# Reindex the dataframe using the date and drop all duplicate date
df.index = df['Datetime']
df.index = pd.DatetimeIndex(df.index)
df2=df
df2=df2.iloc[:,4:]
df2

# %%
#df3 = df2.resample('H').agg(['mean'])
df2 = df2.fillna(-9999)
df2.to_csv('Ressi1216.csv')
#df3 = df3
#df3

# %%
figur = plt.figure(figsize= (50,10)
df3['Discharge [m^3/s]'].plot()
#df3['Water depth [cm]'].plot()

# %%
df44 = df3['Discharge [m^3/s]'].iloc[85+348:109+348]

# %%
df44.plot()

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
#df3['Discharge [m^3/s]'].plot(ax1)
df3.plot(ax=ax1, y=['Discharge [m^3/s]'],         kind='line', stacked=False, 
                  label=['flow'],linewidth=2)#,'El + err','El + bow'],
