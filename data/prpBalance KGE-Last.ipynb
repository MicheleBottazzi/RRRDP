# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#define and set path to the inut folder
path = "/home/drugo/Sim/RRRDP/"                
os.chdir(path)

# %%
#lettura storage simulati
dfsoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoS.columns = ['','Date','so_storage']
dfsoS.index = dfsoS['Date']
dfsoS = dfsoS.iloc[:,2:]

dfsogS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_SO_KGE_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogS.columns = ['','Date','sog_storage']
dfsogS.index = dfsogS['Date']
dfsogS = dfsogS.iloc[:,2:]

dfptS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_PT_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptS.columns = ['','Date','pt_storage']
dfptS.index = dfptS['Date']
dfptS = dfptS.iloc[:,2:]

dffaoS= pd.read_csv('output/RioRessiOut/Calibrazione/Storage_1_RioRessi_FAO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoS.columns = ['','Date','fao_storage']
dffaoS.index = dffaoS['Date']
dffaoS = dffaoS.iloc[:,2:]

#lettura runoff simulati
dfsoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsoROS.columns = ['','Date','so_runoff']
dfsoROS.index = dfsoROS['Date']
dfsoROS = dfsoROS.iloc[:,2:]

dfsogROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_SO_KGE_validated_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsogROS.columns = ['','Date','sog_runoff']
dfsogROS.index = dfsogROS['Date']
dfsogROS = dfsogROS.iloc[:,2:]

dfptROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_PT_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfptROS.columns = ['','Date','pt_runoff']
dfptROS.index = dfptROS['Date']
dfptROS = dfptROS.iloc[:,2:]

dffaoROS= pd.read_csv('output/RioRessiOut/Calibrazione/Idrogramma_1_RioRessi_FAO_KGE_validated.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffaoROS.columns = ['','Date','fao_runoff']
dffaoROS.index = dffaoROS['Date']
dffaoROS = dffaoROS.iloc[:,2:]

#lettura dati osservati simulati
dfObsS= pd.read_csv('data/RioRessi/1/RioRessi_Root.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsS.columns = ['','Date','obs_storage']
dfObsS.index = dfObsS['Date']
dfObsS = dfObsS.iloc[:,2:]

dfObsR= pd.read_csv('data/RioRessi/1/RioRessi_RUNOFF.csv',
                  parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfObsR.columns = ['','Date','obs_runoff']
dfObsR.index = dfObsR['Date']
dfObsR = dfObsR.iloc[:,2:]

dfPrp= pd.read_csv('data/RioRessi/1/RioRessi_PRP.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfPrp.columns = ['','Date','prp']
dfPrp.index = dfPrp['Date']
dfPrp = dfPrp.iloc[:,2:]

#lettura ET simulate
dfso= pd.read_csv('data/RioRessi/1/RioRessi_ET_SOSt.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfso.columns = ['','Date','so_et']
dfso.index = dfso['Date']
dfso = dfso.iloc[:,2:]

dfsog = pd.read_csv('data/RioRessi/1/RioRessi_ET_SO_FG.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsog.columns = ['','Date','sog_et']
dfsog.index = dfsog['Date']
dfsog = dfsog.iloc[:,2:]

dfpt= pd.read_csv('data/RioRessi/1/RioRessi_ET_PT126.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfpt.columns = ['','Date','pt_et']
dfpt.index = dfpt['Date']
dfpt = dfpt.iloc[:,2:]

dffao= pd.read_csv('data/RioRessi/1/RioRessi_ET_FAO.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dffao.columns = ['','Date','fao_et']
dffao.index = dffao['Date']
dffao = dffao.iloc[:,2:]

# %%
#lettura storage ground water calcoato con formula che mi hai mandato per mail
dfsgw= pd.read_csv('data/RioRessi/1/RioRessi_RootGW.csv',
                  parse_dates=['yyyy-MM-dd HH:mm'],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfsgw.columns = ['','Date','storage_gw']
dfsgw.index = dfsgw['Date']
dfsgw = dfsgw.iloc[:,2:]
dfsgw.head()
# Out:
#                      storage_gw
# Date
# 2014-01-01 01:00:00       492.0
# 2014-01-01 02:00:00       492.0
# 2014-01-01 03:00:00       492.0
# 2014-01-01 04:00:00       492.0
# 2014-01-01 05:00:00       492.0

# %%
# metto tutto in unico dataset, facendo partire dal 2014-01-01. Alcuni hanno .iloc perchè sono serie temporali più lunghe (2012)
df = pd.concat([dfObsR,dfPrp.iloc[12432:,:],dfso.iloc[12432:,:],dfsog.iloc[12432:,:],
                dfsoROS,dfsogROS,dfptROS,dffaoROS,
                dffao.iloc[12432:,:],dfpt.iloc[12432:,:], dfObsS.iloc[12432:,:],dfsoS,
                dfsogS,dffaoS,dfptS,
                dfsgw],axis=1)
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 00:00:00    0.000858  0.0    NaN     NaN   0.000227  1.245559e-10
# 2014-01-01 01:00:00    0.000850  0.0    NaN     NaN   0.000249  1.650393e-10
# 2014-01-01 02:00:00    0.000846  0.0    NaN     NaN   0.000231  1.679004e-10
# 2014-01-01 03:00:00    0.000838  0.0    NaN     NaN   0.000245  1.799243e-10
# 2014-01-01 04:00:00    0.000821  0.0    NaN     NaN   0.000233  1.758101e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et  obs_storage  \
# Date
# 2014-01-01 00:00:00   0.000169  9.613060e-18  0.010114    0.0    291.94050
# 2014-01-01 01:00:00   0.000189  1.092695e-17  0.010065    0.0    291.51000
# 2014-01-01 02:00:00   0.000172  9.933847e-18  0.012050    0.0    291.23325
# 2014-01-01 03:00:00   0.000186  1.068453e-17  0.012755    0.0    290.80275
# 2014-01-01 04:00:00   0.000175  1.011714e-17  0.008917    0.0    290.43375
#
#                      so_storage  sog_storage  fao_storage  pt_storage  \
# Date
# 2014-01-01 00:00:00  134.335339   172.098228   173.414028  185.144142
# 2014-01-01 01:00:00  134.335339   172.149160   173.411428  185.144136
# 2014-01-01 02:00:00  134.335339   172.167895   173.408274  185.144131
# 2014-01-01 03:00:00  134.335339   172.174788   173.404891  185.144125
# 2014-01-01 04:00:00  134.335339   172.177323   173.402501  185.144120
#
#                      storage_gw
# Date
# 2014-01-01 00:00:00         NaN
# 2014-01-01 01:00:00       492.0
# 2014-01-01 02:00:00       492.0
# 2014-01-01 03:00:00       492.0
# 2014-01-01 04:00:00       492.0

# %%
df.shape
# Out:
# (46944, 16)

# %%
# faccio un drop di tutti i nan value
df2=df.dropna(subset=['obs_runoff','so_runoff','sog_runoff','pt_runoff','fao_runoff','prp',
                     'obs_storage','so_storage','sog_storage','fao_storage','pt_storage','storage_gw'])

# %%
# droppati circa 40% dei dati
df2.shape
# Out:
# (27900, 16)

# %%
df2.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.007814
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.007159
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.006740
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.006510
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.006429
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.009280   0.007706    0.005391  0.000290  0.000000
# 2017-12-12 08:00:00    0.008293   0.007032    0.004958  0.000224  0.000000
# 2017-12-12 09:00:00    0.007574   0.006651    0.004589  0.000186  0.000000
# 2017-12-12 10:00:00    0.006976   0.006503    0.004308  0.002708  0.003355
# 2017-12-12 11:00:00    0.006518   0.006536    0.004064  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  214.444608   272.641472   268.871841
# 2017-12-12 08:00:00     227.9550  214.069070   271.768721   268.018411
# 2017-12-12 09:00:00     229.1260  213.904313   270.992916   267.230426
# 2017-12-12 10:00:00     230.6400  213.845834   270.296435   266.499161
# 2017-12-12 11:00:00     231.7335  213.947826   269.663348   265.817730
#
#                      pt_storage  storage_gw
# Date
# 2017-12-12 07:00:00  291.898381       356.0
# 2017-12-12 08:00:00  291.628932       360.0
# 2017-12-12 09:00:00  291.509479       364.0
# 2017-12-12 10:00:00  291.469784       368.0
# 2017-12-12 11:00:00  291.588052       372.0

# %%
df.tail()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff  sog_runoff  \
# Date
# 2019-05-10 19:00:00         NaN  NaN    0.0     0.0        NaN         NaN
# 2019-05-10 20:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 21:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 22:00:00         NaN  NaN    NaN     NaN        NaN         NaN
# 2019-05-10 23:00:00         NaN  NaN    NaN     NaN        NaN         NaN
#
#                      pt_runoff  fao_runoff    fao_et     pt_et  obs_storage  \
# Date
# 2019-05-10 19:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 20:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 21:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 22:00:00        NaN         NaN  0.011843  0.000589          NaN
# 2019-05-10 23:00:00        NaN         NaN  0.011843  0.000589          NaN
#
#                      so_storage  sog_storage  fao_storage  pt_storage  \
# Date
# 2019-05-10 19:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 20:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 21:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 22:00:00         NaN          NaN          NaN         NaN
# 2019-05-10 23:00:00         NaN          NaN          NaN         NaN
#
#                      storage_gw
# Date
# 2019-05-10 19:00:00         NaN
# 2019-05-10 20:00:00         NaN
# 2019-05-10 21:00:00         NaN
# 2019-05-10 22:00:00         NaN
# 2019-05-10 23:00:00         NaN

# %%
idf = pd.date_range('2014-01-01 00:00','2017-12-12 11:00',freq='1H')
df = df.reindex(idf)

# %%
# passaggio per assicuarmi di avere il dataset copiato in un paio di altri dataset
df = df2
df3 = df2

# %%
# df['storage_gw'] = -df['storage_gw']

# %%
df3.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.007196  0.0       NaN       NaN   0.007814
# 2017-12-12 08:00:00    0.006363  0.0  0.000980  0.000488   0.007159
# 2017-12-12 09:00:00    0.005755  0.0  0.005354  0.004186   0.006740
# 2017-12-12 10:00:00    0.005307  0.0  0.016122  0.013651   0.006510
# 2017-12-12 11:00:00    0.004890  0.0  0.023910  0.020138   0.006429
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.009280   0.007706    0.005391  0.000290  0.000000
# 2017-12-12 08:00:00    0.008293   0.007032    0.004958  0.000224  0.000000
# 2017-12-12 09:00:00    0.007574   0.006651    0.004589  0.000186  0.000000
# 2017-12-12 10:00:00    0.006976   0.006503    0.004308  0.002708  0.003355
# 2017-12-12 11:00:00    0.006518   0.006536    0.004064  0.015322  0.020300
#
#                      obs_storage  so_storage  sog_storage  fao_storage  \
# Date
# 2017-12-12 07:00:00     227.5875  214.444608   272.641472   268.871841
# 2017-12-12 08:00:00     227.9550  214.069070   271.768721   268.018411
# 2017-12-12 09:00:00     229.1260  213.904313   270.992916   267.230426
# 2017-12-12 10:00:00     230.6400  213.845834   270.296435   266.499161
# 2017-12-12 11:00:00     231.7335  213.947826   269.663348   265.817730
#
#                      pt_storage  storage_gw
# Date
# 2017-12-12 07:00:00  291.898381       356.0
# 2017-12-12 08:00:00  291.628932       360.0
# 2017-12-12 09:00:00  291.509479       364.0
# 2017-12-12 10:00:00  291.469784       368.0
# 2017-12-12 11:00:00  291.588052       372.0

# %%
df['obs_storage'] = df['obs_storage'] - df['storage_gw']
df['obs_D_storage'] = df['obs_storage'].diff()
df['so_D_storage'] = df['so_storage'].diff()
df['sog_D_storage'] = df['sog_storage'].diff()
df['fao_D_storage'] = df['fao_storage'].diff()
df['pt_D_storage'] = df['pt_storage'].diff()
df['D_storage_gw'] = df['storage_gw'].diff()

# calcolo run offin mm --> da m3/s *1000*3600 per avere mm/h --> /21930 (area mm2 ressi)  per avere un runoff in mm/m2
df['obs_mm_runoff'] = df['obs_runoff']*1000*3600/21930
df['so_mm_runoff'] = df['so_runoff']*1000*3600/21930
df['sog_mm_runoff'] = df['sog_runoff']*1000*3600/21930
df['pt_mm_runoff'] = df['pt_runoff']*1000*3600/21930
df['fao_mm_runoff'] = df['fao_runoff']*1000*3600/21930

#runoff da m3/s a l/h
# !!! da qui in poi i runoff sono sovrascritti
df['obs_runoff'] = df['obs_runoff']*3.6
df['so_runoff'] = df['so_runoff']*3.6
df['sog_runoff'] = df['sog_runoff']*3.6
df['pt_runoff'] = df['pt_runoff']*3.6
df['fao_runoff'] = df['fao_runoff']*3.6

# %%
df.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 01:00:00    0.003059  0.0    NaN     NaN   0.000897  5.941415e-10
# 2014-01-01 02:00:00    0.003044  0.0    NaN     NaN   0.000831  6.044416e-10
# 2014-01-01 03:00:00    0.003015  0.0    NaN     NaN   0.000882  6.477276e-10
# 2014-01-01 04:00:00    0.002957  0.0    NaN     NaN   0.000840  6.329163e-10
# 2014-01-01 05:00:00    0.002972  0.0    NaN     NaN   0.000872  6.520384e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et  ...  \
# Date                                                           ...
# 2014-01-01 01:00:00   0.000680  3.933701e-17  0.010065    0.0  ...
# 2014-01-01 02:00:00   0.000621  3.576185e-17  0.012050    0.0  ...
# 2014-01-01 03:00:00   0.000668  3.846429e-17  0.012755    0.0  ...
# 2014-01-01 04:00:00   0.000629  3.642169e-17  0.008917    0.0  ...
# 2014-01-01 05:00:00   0.000660  3.796572e-17  0.009778    0.0  ...
#
#                      so_D_storage  sog_D_storage  fao_D_storage  pt_D_storage  \
# Date
# 2014-01-01 01:00:00           NaN            NaN            NaN           NaN
# 2014-01-01 02:00:00 -1.087699e-10       0.018735      -0.003153     -0.000005
# 2014-01-01 03:00:00 -1.087983e-10       0.006892      -0.003383     -0.000005
# 2014-01-01 04:00:00 -1.087983e-10       0.002535      -0.002390     -0.000005
# 2014-01-01 05:00:00 -1.088267e-10       0.000933      -0.002647     -0.000005
#
#                      D_storage_gw  obs_mm_runoff  so_mm_runoff  sog_mm_runoff  \
# Date
# 2014-01-01 01:00:00           NaN       0.139493      0.040913   2.709263e-08
# 2014-01-01 02:00:00           0.0       0.138824      0.037908   2.756231e-08
# 2014-01-01 03:00:00           0.0       0.137494      0.040238   2.953614e-08
# 2014-01-01 04:00:00           0.0       0.134856      0.038295   2.886075e-08
# 2014-01-01 05:00:00           0.0       0.135513      0.039774   2.973272e-08
#
#                      pt_mm_runoff  fao_mm_runoff
# Date
# 2014-01-01 01:00:00      0.031012   1.793753e-15
# 2014-01-01 02:00:00      0.028313   1.630727e-15
# 2014-01-01 03:00:00      0.030469   1.753958e-15
# 2014-01-01 04:00:00      0.028678   1.660816e-15
# 2014-01-01 05:00:00      0.030096   1.731223e-15
#
# [5 rows x 27 columns]

# %%
# calcolo i bilanci idrici

#et stimata
df['residual_obs + et_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']#-df['D_storage_gw']
# come sopra, l'avevo riscritta per provare a sottrargli l'et di prospero a vedere come venire il residuo, poi scartato perchè veniva qualcosa di molto rumoroso
df['residual_obs'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage']-df['D_storage_gw']
# bilanci idrici residuo con et sim
df['residual_so'] = df['prp'] - df['so_mm_runoff'] - df['so_D_storage'] - df['so_et']
df['residual_sog'] = df['prp'] - df['obs_mm_runoff'] - df['obs_D_storage'] - df['sog_et']
df['residual_pt'] = df['prp'] - df['obs_mm_runoff'] - df['fao_D_storage'] - df['pt_et']
df['residual_fao'] = df['prp'] - df['obs_mm_runoff'] - df['pt_D_storage'] - df['fao_et']

df['residual_so + et_so'] = df['so_et'] + df['residual_so']
df['residual_fao + et_fao'] = df['fao_et'] + df['residual_fao']
df['residual_obs + et_so'] = df['so_et'] + df['residual_obs']
df['residual_pt + et_pt'] = df['pt_et'] + df['residual_pt']

# %%
# aggregati a scala annuale e mensile (sommati, non cumulati)
dfMon = df.resample('1MS').agg('sum')
dfAnn = df.resample('1YS').agg('sum')

# %%
# come sopra ma giornaliero
dfDay = df.resample('1D').agg('sum')

# %%
df2 = df

# %%
dfMon['month'] = pd.DatetimeIndex(dfMon.index).year#.month
dfMon['Date'] = dfMon.index

# %%
dfMon.head()
# Out:
#             obs_runoff    prp      so_et     sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01    5.142962    0.0  11.719283   8.817884   0.413336  5.693305e-07
# 2014-02-01    3.992974  220.0  18.615831  13.415968   4.751921  3.769985e+00
# 2014-03-01    2.968361  179.6  70.896314  49.182022   3.325399  2.725670e+00
# 2014-04-01    2.670504  261.0  65.303575  45.605552   2.344645  2.677747e+00
# 2014-05-01    2.149786  143.8  84.437723  58.891763   2.959776  2.720192e+00
#
#             pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_so  \
# Date                                                       ...
# 2014-01-01   0.338014  2.369581e-14  10.421665  10.024666  ...   -12.754703
# 2014-02-01   3.744637  1.967919e+00  14.488155  14.830565  ...   -89.657815
# 2014-03-01   3.580958  2.590736e+00  50.860102  51.793558  ...   -28.504036
# 2014-04-01   2.941092  2.843249e+00  44.877742  49.528728  ...    54.209365
# 2014-05-01   3.271845  3.241835e+00  61.138770  68.733898  ...   -31.509839
#
#             residual_sog  residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01   -171.191007  -237.363594   -242.544864            -1.035420
# 2014-02-01     10.066999   -55.448498    -59.540972           -71.041984
# 2014-03-01     50.498356     5.523956      3.070659            42.392278
# 2014-04-01    -69.881690    54.767727     62.030437           119.512940
# 2014-05-01     62.358493     4.242183     11.937651            52.927883
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Date
# 2014-01-01            -232.133264             45.346160          -227.338928
# 2014-02-01             -45.052817           -165.901201           -40.617933
# 2014-03-01              53.930761            -17.423308            57.317514
# 2014-04-01             106.908179            245.027437           104.296454
# 2014-05-01              73.076421            177.687979            72.976081
#
#             month       Date
# Date
# 2014-01-01   2014 2014-01-01
# 2014-02-01   2014 2014-02-01
# 2014-03-01   2014 2014-03-01
# 2014-04-01   2014 2014-04-01
# 2014-05-01   2014 2014-05-01
#
# [5 rows x 39 columns]

# %%
dfM = dfMon[['so_et','prp','obs_mm_runoff','so_D_storage']]
dfM.columns = ['ET_Ps','Rainfall','Runoff sim.','Storage sim.']

# %%
df['residual_obs + et_obs'].plot()

# %%
dfMon['obs_D_storage'].plot()

# %%
dfM['Date'] = dfM.index
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfM.head()
# Out:
#                 ET_Ps  Rainfall  Runoff sim.  Storage sim.       Date
# Date
# 2014-01-01  11.719283       0.0   234.517172     -5.695896 2014-01-01
# 2014-02-01  18.615831     220.0   182.078146     73.146531 2014-02-01
# 2014-03-01  70.896314     179.6   135.356160    -15.161364 2014-03-01
# 2014-04-01  65.303575     261.0   121.773993     23.455005 2014-04-01
# 2014-05-01  84.437723     143.8    98.029460    -14.238974 2014-05-01

# %%
dataM = dfM.melt(id_vars=['Date'], var_name='Components', value_name='Water budget')

# %%
import seaborn as sns
import matplotlib.dates as mdates

# %% [markdown]
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
from matplotlib.dates import YearLocator, MonthLocator, WeekdayLocator, DateFormatter

# %%
import datetime
import matplotlib.ticker as mticker

# %%
import matplotlib.ticker as tkr

# %%
idy = pd.date_range('2014-01-01','2017-12-12',freq='1MS')

# %%
dfMon.head()
# Out:
#             obs_runoff    prp      so_et     sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01    5.142962    0.0  11.719283   8.817884   0.413336  5.693305e-07
# 2014-02-01    3.992974  220.0  18.615831  13.415968   4.751921  3.769985e+00
# 2014-03-01    2.968361  179.6  70.896314  49.182022   3.325399  2.725670e+00
# 2014-04-01    2.670504  261.0  65.303575  45.605552   2.344645  2.677747e+00
# 2014-05-01    2.149786  143.8  84.437723  58.891763   2.959776  2.720192e+00
#
#             pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_so  \
# Date                                                       ...
# 2014-01-01   0.338014  2.369581e-14  10.421665  10.024666  ...   -12.754703
# 2014-02-01   3.744637  1.967919e+00  14.488155  14.830565  ...   -89.657815
# 2014-03-01   3.580958  2.590736e+00  50.860102  51.793558  ...   -28.504036
# 2014-04-01   2.941092  2.843249e+00  44.877742  49.528728  ...    54.209365
# 2014-05-01   3.271845  3.241835e+00  61.138770  68.733898  ...   -31.509839
#
#             residual_sog  residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01   -171.191007  -237.363594   -242.544864            -1.035420
# 2014-02-01     10.066999   -55.448498    -59.540972           -71.041984
# 2014-03-01     50.498356     5.523956      3.070659            42.392278
# 2014-04-01    -69.881690    54.767727     62.030437           119.512940
# 2014-05-01     62.358493     4.242183     11.937651            52.927883
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Date
# 2014-01-01            -232.133264             45.346160          -227.338928
# 2014-02-01             -45.052817           -165.901201           -40.617933
# 2014-03-01              53.930761            -17.423308            57.317514
# 2014-04-01             106.908179            245.027437           104.296454
# 2014-05-01              73.076421            177.687979            72.976081
#
#             month       Date
# Date
# 2014-01-01   2014 2014-01-01
# 2014-02-01   2014 2014-02-01
# 2014-03-01   2014 2014-03-01
# 2014-04-01   2014 2014-04-01
# 2014-05-01   2014 2014-05-01
#
# [5 rows x 39 columns]

# %%
dfMon['Data'] = idy
dfMon['Data'] = pd.to_datetime(dfMon['Data'], dayfirst=True)
dfMon['Data'] = dfMon['Data'].dt.strftime('%Y-%m')
dfMon.index = dfMon['Data']

# %%
import calendar
import matplotlib.dates as mdates

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt',
#        'month', 'Date', 'Data'],
#       dtype='object')

# %%
# faccio un solo dataset con et e et con sommati i relativi residui derivanti dal 
# bilancio idrico ['residual_so + et_so','residual_pt + et_pt','residual_fao + et_fao']
dfETTNull = dfMon[['residual_obs + et_obs',
                   'residual_so + et_so',
                   'residual_pt + et_pt',
                   'residual_fao + et_fao',
                   'pt_et','fao_et',
                   'so_et','residual_so']]

# %%
dfETTNull['residual_so+so_et']=dfETTNull['so_et']+dfETTNull['residual_so']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfETTNull.head()
# Out:
#          residual_obs + et_obs  residual_so + et_so  residual_pt + et_pt  \
# Data
# 2014-01            -232.378929            -1.035420          -227.338928
# 2014-02              24.207354           -71.041984           -40.617933
# 2014-03              61.557590            42.392278            57.317514
# 2014-04              53.707757           119.512940           104.296454
# 2014-05             136.624790            52.927883            72.976081
#
#          residual_fao + et_fao      pt_et     fao_et      so_et  residual_so  \
# Data
# 2014-01            -232.133264  10.024666  10.421665  11.719283   -12.754703
# 2014-02             -45.052817  14.830565  14.488155  18.615831   -89.657815
# 2014-03              53.930761  51.793558  50.860102  70.896314   -28.504036
# 2014-04             106.908179  49.528728  44.877742  65.303575    54.209365
# 2014-05              73.076421  68.733898  61.138770  84.437723   -31.509839
#
#          residual_so+so_et
# Data
# 2014-01          -1.035420
# 2014-02         -71.041984
# 2014-03          42.392278
# 2014-04         119.512940
# 2014-05          52.927883

# %%
# ET negative poste uguali a zero
dfETTNull[dfETTNull < 0] = 0
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfETTNull['Data'] = dfMon['Data']
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# dfMon.head()

# %%
# dfM.head()

# %%
# dfMon['ETdelta']=dfMon['residual_so']+dfMon['so_et']

# %%
ticklabels = ['']*len(dfMon)
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
fig, ax = plt.subplots(nrows = 1, ncols =1,figsize=(30,15))
ax11 = ax

dfETTNull.plot(x='Data',y=['residual_obs + et_obs','so_et','fao_et','pt_et'],kind='bar', ax = ax11,  edgecolor=".3",linewidth=1,width=0.75,
               colormap='Accent', alpha=1,
               label = ['ET$_{obs}+\Delta$','ET$_{Ps}$','ET$_{fao}$','ET$_{pt}$'],rot = -0,stacked=False)

ticklabels = ['']*len(dfMon)
skip = 3
ticklabels[0::skip] = dfMon['Date'].iloc[0::skip].dt.strftime('%Y-%m')

for ax in [ax11]:#, ax21, ax22]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)
    ax.set_xlabel('',fontsize=30)
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=30, ncol=2)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))

ax11.set_ylim([-1,250])
ax11.set_ylabel('Evapotranspiration [mm]',fontsize=30,fontweight='bold')
fig.autofmt_xdate(rotation=90)
ax11.grid(True)

def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
fig, ax = plt.subplots(nrows = 1, ncols =1,figsize=(30,15))
ax13 = ax

dfMon.plot(y=['obs_runoff','so_runoff','fao_runoff','pt_runoff'],kind='bar', ax = ax13,  edgecolor=".3",linewidth=1,width=0.75,
           colormap='Accent',alpha=1,label = ['Runoff obs','Runoff sim$_{ps}$','Runoff sim$_{fao}$','Runoff sim$_{pt}$'],rot = -0,stacked=False)

ticklabels = ['']*len(dfMon)
skip = 3#len(dfMon)//24
ticklabels[0::skip] = dfMon['Date'].iloc[0::skip].dt.strftime('%Y-%m')

for ax in [ax13]:#, ax21, ax22]:
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)
    ax.set_xlabel('',fontsize=30)
#     ax.set_ylim([-100,400])
    ax.fmt_xdata = fmt
    ax.legend(loc='upper right',fontsize=30)
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
    ax.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))


ax13.set_ylim([-0.,16])
ax13.set_ylabel('Runoff [10$^{3}$ m$^{3}$]',fontsize=30,fontweight='bold')
 

fig.autofmt_xdate(rotation=90)
ax13.grid(True)
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]

# %%
dfMon.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt',
#        'month', 'Date', 'Data'],
#       dtype='object')

# %%
dfETT = dfMon[['Data','residual_obs + et_obs','so_et','sog_et','fao_et','pt_et','residual_so','residual_sog','residual_fao','residual_pt']]

# %%
# dfETT['soet+r']= dfETT['so_et']+dfETT['residual_so']
# dfETT['soget+r']= dfETT['sog_et']+dfETT['residual_sog']
# dfETT['faoet+r']= dfETT['fao_et']+dfETT['residual_fao']
# dfETT['ptet+r']= dfETT['pt_et']+dfETT['residual_pt']

# %%
skip = len(dfMon)//4
print(skip)
# Out:
# 12

# %%
dfMon.head()
# Out:
#          obs_runoff    prp      so_et     sog_et  so_runoff    sog_runoff  \
# Data
# 2014-01    5.142962    0.0  11.719283   8.817884   0.413336  5.693305e-07
# 2014-02    3.992974  220.0  18.615831  13.415968   4.751921  3.769985e+00
# 2014-03    2.968361  179.6  70.896314  49.182022   3.325399  2.725670e+00
# 2014-04    2.670504  261.0  65.303575  45.605552   2.344645  2.677747e+00
# 2014-05    2.149786  143.8  84.437723  58.891763   2.959776  2.720192e+00
#
#          pt_runoff    fao_runoff     fao_et      pt_et  ...  residual_sog  \
# Data                                                    ...
# 2014-01   0.338014  2.369581e-14  10.421665  10.024666  ...   -171.191007
# 2014-02   3.744637  1.967919e+00  14.488155  14.830565  ...     10.066999
# 2014-03   3.580958  2.590736e+00  50.860102  51.793558  ...     50.498356
# 2014-04   2.941092  2.843249e+00  44.877742  49.528728  ...    -69.881690
# 2014-05   3.271845  3.241835e+00  61.138770  68.733898  ...     62.358493
#
#          residual_pt  residual_fao  residual_so + et_so  \
# Data
# 2014-01  -237.363594   -242.544864            -1.035420
# 2014-02   -55.448498    -59.540972           -71.041984
# 2014-03     5.523956      3.070659            42.392278
# 2014-04    54.767727     62.030437           119.512940
# 2014-05     4.242183     11.937651            52.927883
#
#          residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt  \
# Data
# 2014-01            -232.133264             45.346160          -227.338928
# 2014-02             -45.052817           -165.901201           -40.617933
# 2014-03              53.930761            -17.423308            57.317514
# 2014-04             106.908179            245.027437           104.296454
# 2014-05              73.076421            177.687979            72.976081
#
#          month       Date     Data
# Data
# 2014-01   2014 2014-01-01  2014-01
# 2014-02   2014 2014-02-01  2014-02
# 2014-03   2014 2014-03-01  2014-03
# 2014-04   2014 2014-04-01  2014-04
# 2014-05   2014 2014-05-01  2014-05
#
# [5 rows x 40 columns]

# %%
dfAnn.head()
# Out:
#             obs_runoff     prp       so_et      sog_et  so_runoff  sog_runoff  \
# Date
# 2014-01-01   39.527631  2659.6  613.518783  434.901357  44.322357   42.361000
# 2015-01-01    6.887730   808.2  476.471176  332.292975  10.530827   10.121415
# 2016-01-01   13.201579  1532.0  655.276548  461.735940  18.374499   18.972704
# 2017-01-01    6.029205  1090.4  485.539228  340.415637   8.516994   10.346076
#
#             pt_runoff  fao_runoff      fao_et       pt_et  ...  \
# Date                                                       ...
# 2014-01-01  46.288105   44.454816  450.054632  502.879500  ...
# 2015-01-01  13.051382   12.341585  292.494742  362.859003  ...
# 2016-01-01  22.592095   23.855922  398.420767  551.891702  ...
# 2017-01-01  12.133963   11.404868  156.347202  397.526956  ...
#
#             residual_obs + et_obs  residual_obs  residual_so  residual_sog  \
# Date
# 2014-01-01             861.210209    853.210209  -102.054175    241.500270
# 2015-01-01             528.507531    520.507531  -148.276580    163.078351
# 2016-01-01             952.627308    960.627308   -79.390405     81.315231
# 2017-01-01             694.330702    822.330702    77.771927    506.582611
#
#             residual_pt  residual_fao  residual_so + et_so  \
# Date
# 2014-01-01   296.165341    334.910461           511.464608
# 2015-01-01   160.584448    224.270983           328.194597
# 2016-01-01   366.685719    522.438158           575.886144
# 2017-01-01   365.900277    611.528453           563.311155
#
#             residual_fao + et_fao  residual_obs + et_so  residual_pt + et_pt
# Date
# 2014-01-01             784.955028           1145.920410           799.044841
# 2015-01-01             516.765725            467.842503           523.443451
# 2016-01-01             920.858925           1106.327719           918.577421
# 2017-01-01             767.875656            972.537476           763.427234
#
# [4 rows x 37 columns]

# %%
# ticklabels = ['']*len(dfMon)
ticklabelsY = ['2012', '', '', '', '', 
               '2013', '', '', '', '', '', '', '', '', '', '', '', 
               '2014', '', '', '', '', '', '', '', '', '', '', '',
               '2015', '', '', '', '', '', '', '', '', '', '', '',
               '2016', '', '', '', '', '', '', '', '', '', '']
               
print(ticklabelsY)
# Out:
# ['2012', '', '', '', '', '2013', '', '', '', '', '', '', '', '', '', '', '', '2014', '', '', '', '', '', '', '', '', '', '', '', '2015', '', '', '', '', '', '', '', '', '', '', '', '2016', '', '', '', '', '', '', '', '', '', '']

# %%
dfAnn.columns
# Out:
# Index(['obs_runoff', 'prp', 'so_et', 'sog_et', 'so_runoff', 'sog_runoff',
#        'pt_runoff', 'fao_runoff', 'fao_et', 'pt_et', 'obs_storage',
#        'so_storage', 'sog_storage', 'fao_storage', 'pt_storage', 'storage_gw',
#        'obs_D_storage', 'so_D_storage', 'sog_D_storage', 'fao_D_storage',
#        'pt_D_storage', 'D_storage_gw', 'obs_mm_runoff', 'so_mm_runoff',
#        'sog_mm_runoff', 'pt_mm_runoff', 'fao_mm_runoff',
#        'residual_obs + et_obs', 'residual_obs', 'residual_so', 'residual_sog',
#        'residual_pt', 'residual_fao', 'residual_so + et_so',
#        'residual_fao + et_fao', 'residual_obs + et_so', 'residual_pt + et_pt'],
#       dtype='object')

# %%
# Creo dataset annuale precipitazioni ed ET per calcolare % et/prp

df11 = dfso.resample('1YS').agg('sum')
df21 = dfsog.resample('1YS').agg('sum')
df31 = dffao.resample('1YS').agg('sum')
df41 = dfpt.resample('1YS').agg('sum')
df51 = dfPrp.resample('1YS').agg('sum')
df61 = df['residual_obs + et_obs'].resample('1YS').agg('sum')

# %%
dfprpet = pd.concat([df11,df21,df31,df41,df51,df61],axis=1)
# dfprpet['Date'] = dfprpet.index

# %%
dfprpet
# Out:
#                  so_et      sog_et      fao_et       pt_et          prp  \
# Date
# 2012-01-01  243.433610  171.654681  124.617873  117.468980   302.400000
# 2013-01-01  676.688947  472.902771  435.726512  524.308696   554.500000
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.000000
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.800000
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.800000
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.400000
# 2018-01-01  693.603661  491.140634  522.292308  592.254333   947.066667
# 2019-01-01  184.172939  127.102420  129.538469  120.527458    72.316667
#
#             residual_obs + et_obs
# Date
# 2012-01-01                    NaN
# 2013-01-01                    NaN
# 2014-01-01             861.210209
# 2015-01-01             528.507531
# 2016-01-01             952.627308
# 2017-01-01             694.330702
# 2018-01-01                    NaN
# 2019-01-01                    NaN

# %%
dfprpet.index
# Out:
# DatetimeIndex(['2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='Date', freq='AS-JAN')

# %%
dfprpet = dfprpet.iloc[2:6,:]

# %%
dfprpet.head()
# Out:
#                  so_et      sog_et      fao_et       pt_et     prp  \
# Date
# 2014-01-01  615.741610  436.622266  451.615860  504.607041  2965.0
# 2015-01-01  754.605690  526.693843  495.551581  592.329734  1138.8
# 2016-01-01  686.587825  484.748541  415.497298  575.983872  1677.8
# 2017-01-01  797.666584  558.054164  366.931582  649.783290  1408.4
#
#             residual_obs + et_obs
# Date
# 2014-01-01             861.210209
# 2015-01-01             528.507531
# 2016-01-01             952.627308
# 2017-01-01             694.330702

# %%
years = mdates.YearLocator()
dfprpet.index = dfprpet.index.strftime('%Y')
dfprpet.index
# Out:
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
dfprpet['ET GF%'] =100*dfprpet['so_et']/( dfprpet['prp'])
dfprpet['ET Obs%'] =100*dfprpet['residual_obs + et_obs']/( dfprpet['prp'])
dfprpet['ET FAO%'] =100*dfprpet['fao_et']/( dfprpet['prp'])
dfprpet['ET PT%'] =100*dfprpet['pt_et']/( dfprpet['prp'])
dfprpet['prp%'] =1
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# ITALIANO
plt.style.use('default')
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
axy = ax.twinx()



dfprpet.plot(y=['ET GF%'],kind='line', ax = axy, label = ['%ET$_{Ps}$'],color='r',linewidth=5, rot = -0,stacked=False)
dfprpet.plot(y=['ET Obs%'],kind='line', ax = axy, label = ['%ET$_{obs}$'],color='orange',linewidth=5, rot = -0,stacked=False)

dfprpet.plot(y=['so_et','fao_et','pt_et','residual_obs + et_obs','prp'],kind='bar', ax = ax, 
             colormap='GnBu',edgecolor=".3",linewidth=1.5, rot = -0,stacked=False,
             label = ['ET$_{Ps}$','ET$_{FAO}$','ET$_{PT}$','ET$_{obs}$+$\Delta$','PRP'])

# dfprpet.plot(y=['ET FAO%'],kind='line', ax = axy, label = ['%ET GEOframe'],color='g',linewidth=5, rot = -0,stacked=False)
# dfprpet.plot(y=['ET PT%'],kind='line', ax = axy, label = ['%ET oss'],color='b',linewidth=5, rot = -0,stacked=False)
major_ticks = np.arange(0, 3001, 600)
axy.set_ylim([0,100])
ax.set_ylim([-1,3000])
ax.set_yticks(major_ticks)
ax.set_ylabel('ET-PRP [mm]',fontsize=40,fontweight='bold')
ax.set_xlabel('Data',fontsize=40,fontweight='bold')
# ax.legend(loc='upper center',fontsize=30, ncol=3,handleheight=1, labelspacing=0.05)   
ax.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.35, 1.15),ncol=5,handleheight=1, labelspacing=0.05)   

axy.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.85, 1.15),ncol=2,handleheight=1, labelspacing=0.05)  
plt.grid(True)
for ax in [ ax,axy]:
    ax.tick_params(axis='both', which='major', labelsize=40)
    # ax.tick_params(axis = 'both', which = 'minor', labelsize = 20)  
#     ax.legend(loc='upper right',fontsize=20)

# %%
# apro i risultati finali delle calibrazioni e leggo il KGE (NS nel caso di NS)
f=open('output/EFC-luca_15_RioRessi_SO_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_so = lines[293]
b_so = a_so[40:-1]
b_so = float(b_so)
b_so
# Out:
# 0.7560677365461426

# %%
f=open('output/EFC-luca_15_RioRessi_PT_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_pt = lines[293]
b_pt = a_pt[40:-1]
b_pt = float(b_pt)
b_pt
# Out:
# 0.7536621925728755

# %%
f=open('output/EFC-luca_15_RioRessi_FAO_KGE_1500/out/luca_summary.txt')
lines=f.readlines()
a_fao = lines[293]
b_fao = a_fao[40:-1]
b_fao = float(b_fao)
b_fao
# Out:
# 0.753644864680661

# %%
df2.head()
# Out:
#                      obs_runoff  prp  so_et  sog_et  so_runoff    sog_runoff  \
# Date
# 2014-01-01 01:00:00    0.003059  0.0    NaN     NaN   0.000897  5.941415e-10
# 2014-01-01 02:00:00    0.003044  0.0    NaN     NaN   0.000831  6.044416e-10
# 2014-01-01 03:00:00    0.003015  0.0    NaN     NaN   0.000882  6.477276e-10
# 2014-01-01 04:00:00    0.002957  0.0    NaN     NaN   0.000840  6.329163e-10
# 2014-01-01 05:00:00    0.002972  0.0    NaN     NaN   0.000872  6.520384e-10
#
#                      pt_runoff    fao_runoff    fao_et  pt_et  ...  \
# Date                                                           ...
# 2014-01-01 01:00:00   0.000680  3.933701e-17  0.010065    0.0  ...
# 2014-01-01 02:00:00   0.000621  3.576185e-17  0.012050    0.0  ...
# 2014-01-01 03:00:00   0.000668  3.846429e-17  0.012755    0.0  ...
# 2014-01-01 04:00:00   0.000629  3.642169e-17  0.008917    0.0  ...
# 2014-01-01 05:00:00   0.000660  3.796572e-17  0.009778    0.0  ...
#
#                      residual_obs + et_obs  residual_obs  residual_so  \
# Date
# 2014-01-01 01:00:00                    NaN           NaN          NaN
# 2014-01-01 02:00:00               0.137926      0.137926          NaN
# 2014-01-01 03:00:00               0.293006      0.293006          NaN
# 2014-01-01 04:00:00               0.234144      0.234144          NaN
# 2014-01-01 05:00:00               0.202737      0.202737          NaN
#
#                      residual_sog  residual_pt  residual_fao  \
# Date
# 2014-01-01 01:00:00           NaN          NaN           NaN
# 2014-01-01 02:00:00           NaN    -0.135671     -0.150870
# 2014-01-01 03:00:00           NaN    -0.134111     -0.150244
# 2014-01-01 04:00:00           NaN    -0.132466     -0.143768
# 2014-01-01 05:00:00           NaN    -0.132866     -0.145285
#
#                      residual_so + et_so  residual_fao + et_fao  \
# Date
# 2014-01-01 01:00:00                  NaN                    NaN
# 2014-01-01 02:00:00                  NaN              -0.138819
# 2014-01-01 03:00:00                  NaN              -0.137489
# 2014-01-01 04:00:00                  NaN              -0.134851
# 2014-01-01 05:00:00                  NaN              -0.135507
#
#                      residual_obs + et_so  residual_pt + et_pt
# Date
# 2014-01-01 01:00:00                   NaN                  NaN
# 2014-01-01 02:00:00                   NaN            -0.135671
# 2014-01-01 03:00:00                   NaN            -0.134111
# 2014-01-01 04:00:00                   NaN            -0.132466
# 2014-01-01 05:00:00                   NaN            -0.132866
#
# [5 rows x 37 columns]

# %%
df2.tail()
# Out:
#                      obs_runoff  prp     so_et    sog_et  so_runoff  \
# Date
# 2017-12-12 07:00:00    0.025905  0.0       NaN       NaN   0.028130
# 2017-12-12 08:00:00    0.022905  0.0  0.000980  0.000488   0.025773
# 2017-12-12 09:00:00    0.020718  0.0  0.005354  0.004186   0.024264
# 2017-12-12 10:00:00    0.019104  0.0  0.016122  0.013651   0.023437
# 2017-12-12 11:00:00    0.017604  0.0  0.023910  0.020138   0.023146
#
#                      sog_runoff  pt_runoff  fao_runoff    fao_et     pt_et  \
# Date
# 2017-12-12 07:00:00    0.033409   0.027743    0.019409  0.000290  0.000000
# 2017-12-12 08:00:00    0.029854   0.025316    0.017849  0.000224  0.000000
# 2017-12-12 09:00:00    0.027267   0.023943    0.016519  0.000186  0.000000
# 2017-12-12 10:00:00    0.025115   0.023409    0.015510  0.002708  0.003355
# 2017-12-12 11:00:00    0.023464   0.023530    0.014629  0.015322  0.020300
#
#                      ...  residual_obs + et_obs  residual_obs  residual_so  \
# Date                 ...
# 2017-12-12 07:00:00  ...               4.539741      0.539741          NaN
# 2017-12-12 08:00:00  ...               2.588040     -1.411960    -0.800674
# 2017-12-12 09:00:00  ...               1.884267     -2.115733    -0.947020
# 2017-12-12 10:00:00  ...               1.614865     -2.385135    -1.026359
# 2017-12-12 11:00:00  ...               2.103764     -1.896236    -1.181354
#
#                      residual_sog  residual_pt  residual_fao  \
# Date
# 2017-12-12 07:00:00           NaN    -0.253440     -0.958692
# 2017-12-12 08:00:00      2.587553    -0.191030     -0.775235
# 2017-12-12 09:00:00      1.880081    -0.156749     -0.825466
# 2017-12-12 10:00:00      1.601214    -0.143226     -0.834149
# 2017-12-12 11:00:00      2.083626    -0.141605     -0.936326
#
#                      residual_so + et_so  residual_fao + et_fao  \
# Date
# 2017-12-12 07:00:00                  NaN              -0.958401
# 2017-12-12 08:00:00            -0.799694              -0.775011
# 2017-12-12 09:00:00            -0.941666              -0.825280
# 2017-12-12 10:00:00            -1.010237              -0.831441
# 2017-12-12 11:00:00            -1.157444              -0.921004
#
#                      residual_obs + et_so  residual_pt + et_pt
# Date
# 2017-12-12 07:00:00                   NaN            -0.253440
# 2017-12-12 08:00:00             -1.410979            -0.191030
# 2017-12-12 09:00:00             -2.110379            -0.156749
# 2017-12-12 10:00:00             -2.369013            -0.139871
# 2017-12-12 11:00:00             -1.872326            -0.121305
#
# [5 rows x 37 columns]

# %%
df2 = df3

# %%
df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']].tail()
# Out:
#                      obs_storage  so_storage  sog_storage  pt_storage  \
# Date
# 2017-12-12 07:00:00    -128.4125  214.444608   272.641472  291.898381
# 2017-12-12 08:00:00    -132.0450  214.069070   271.768721  291.628932
# 2017-12-12 09:00:00    -134.8740  213.904313   270.992916  291.509479
# 2017-12-12 10:00:00    -137.3600  213.845834   270.296435  291.469784
# 2017-12-12 11:00:00    -140.2665  213.947826   269.663348  291.588052
#
#                      fao_storage  storage_gw
# Date
# 2017-12-12 07:00:00   268.871841       356.0
# 2017-12-12 08:00:00   268.018411       360.0
# 2017-12-12 09:00:00   267.230426       364.0
# 2017-12-12 10:00:00   266.499161       368.0
# 2017-12-12 11:00:00   265.817730       372.0

# %%
# leggo gli storage, anche qui c'è la simulazione foresta/prato (SOG), si può ignorare
df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']].plot()

# %%
dfS2 =df3[['obs_storage','so_storage','sog_storage','pt_storage','fao_storage','storage_gw']]
dfMonM = dfS2.resample('MS').agg('mean')
dfS2['storage_RZ+GW']=df3['obs_storage']+df3['storage_gw']


dfS2[dfS2 < 0]=np.nan
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
dfS2['month'] = pd.DatetimeIndex(dfS2.index).month
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfS2.tail()
# Out:
#                      obs_storage  so_storage  sog_storage  pt_storage  \
# Date
# 2017-12-12 07:00:00          NaN  214.444608   272.641472  291.898381
# 2017-12-12 08:00:00          NaN  214.069070   271.768721  291.628932
# 2017-12-12 09:00:00          NaN  213.904313   270.992916  291.509479
# 2017-12-12 10:00:00          NaN  213.845834   270.296435  291.469784
# 2017-12-12 11:00:00          NaN  213.947826   269.663348  291.588052
#
#                      fao_storage  storage_gw  storage_RZ+GW  month
# Date
# 2017-12-12 07:00:00   268.871841       356.0       227.5875     12
# 2017-12-12 08:00:00   268.018411       360.0       227.9550     12
# 2017-12-12 09:00:00   267.230426       364.0       229.1260     12
# 2017-12-12 10:00:00   266.499161       368.0       230.6400     12
# 2017-12-12 11:00:00   265.817730       372.0       231.7335     12

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax11 = ax
################################################################################
dfS2.plot(ax=ax11, y=['obs_storage','so_storage','storage_RZ+GW','pt_storage','fao_storage'],
          kind='line', stacked=False, colormap='Dark2', alpha =0.9,linewidth=3,
                  label=['GEOframe','FAO','Storage RZ + GW','PT','Obs.'])
################################################################################
ax11.legend(loc='upper center',fontsize=25, bbox_to_anchor=(0.5, 1.12), ncol=5, frameon =True)

for ax in [ax11]:
    ax.set_ylim([50,500])
    ax.set_ylabel('Storage Root Zone [mm/m$^{2}$]',fontsize=30)
    ax.set_xlabel('',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30)

# %%
# Creo un df con i runoff

# %%
dfRun = df[['obs_runoff','so_runoff','sog_runoff','pt_runoff','fao_runoff','prp']]

# %%
dfRun['obs_runoff_cum'] = dfRun[['obs_runoff']].resample('48MS').agg(['cumsum'])
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Calcolo i litri ora
dfRun['obs_litri_runoff'] = dfRun['obs_runoff']*1000
dfRun['so_litri_runoff'] = dfRun['so_runoff']*1000
dfRun['sog_litri_runoff'] = dfRun['sog_runoff']*1000
dfRun['pt_litri_runoff'] = dfRun['pt_runoff']*1000
dfRun['fao_litri_runoff'] = dfRun['fao_runoff']*1000

# Calcolo cumulata
dfRun['obs_runoff_cum'] = dfRun[['obs_runoff']].resample('48MS').agg(['cumsum'])
dfRun['so_runoff_cum'] = dfRun[['so_runoff']].resample('48MS').agg(['cumsum'])
dfRun['sog_runoff_cum'] = dfRun[['sog_runoff']].resample('48MS').agg(['cumsum'])
dfRun['pt_runoff_cum'] = dfRun[['pt_runoff']].resample('48MS').agg(['cumsum'])
dfRun['fao_runoff_cum'] = dfRun[['fao_runoff']].resample('48MS').agg(['cumsum'])

# da un sacco di warning perchè uso dei comandi 'antiquati', ignorali
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
dfRun.tail()
# Out:
#                      obs_runoff  so_runoff  sog_runoff  pt_runoff  fao_runoff  \
# Date
# 2017-12-12 07:00:00    0.025905   0.028130    0.033409   0.027743    0.019409
# 2017-12-12 08:00:00    0.022905   0.025773    0.029854   0.025316    0.017849
# 2017-12-12 09:00:00    0.020718   0.024264    0.027267   0.023943    0.016519
# 2017-12-12 10:00:00    0.019104   0.023437    0.025115   0.023409    0.015510
# 2017-12-12 11:00:00    0.017604   0.023146    0.023464   0.023530    0.014629
#
#                      prp  obs_runoff_cum  obs_litri_runoff  so_litri_runoff  \
# Date
# 2017-12-12 07:00:00  0.0       65.565814            25.905        28.130361
# 2017-12-12 08:00:00  0.0       65.588719            22.905        25.772844
# 2017-12-12 09:00:00  0.0       65.609437            20.718        24.263839
# 2017-12-12 10:00:00  0.0       65.628541            19.104        23.436939
# 2017-12-12 11:00:00  0.0       65.646145            17.604        23.146087
#
#                      sog_litri_runoff  pt_litri_runoff  fao_litri_runoff  \
# Date
# 2017-12-12 07:00:00         33.409059        27.743052         19.408559
# 2017-12-12 08:00:00         29.853605        25.315842         17.849160
# 2017-12-12 09:00:00         27.267026        23.943425         16.519009
# 2017-12-12 10:00:00         25.114531        23.409087         15.509635
# 2017-12-12 11:00:00         23.464221        23.530017         14.629400
#
#                      so_runoff_cum  sog_runoff_cum  pt_runoff_cum  \
# Date
# 2017-12-12 07:00:00      81.648057       81.695496      93.969346
# 2017-12-12 08:00:00      81.673830       81.725350      93.994662
# 2017-12-12 09:00:00      81.698094       81.752617      94.018606
# 2017-12-12 10:00:00      81.721531       81.777732      94.042015
# 2017-12-12 11:00:00      81.744677       81.801196      94.065545
#
#                      fao_runoff_cum
# Date
# 2017-12-12 07:00:00       91.992684
# 2017-12-12 08:00:00       92.010533
# 2017-12-12 09:00:00       92.027052
# 2017-12-12 10:00:00       92.042562
# 2017-12-12 11:00:00       92.057191

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt


def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

fig, host = plt.subplots(figsize=(30,20))

fig.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

par2.spines["right"].set_position(("axes", 1.09))
make_patch_spines_invisible(par2)
par2.spines["right"].set_visible(True)

dfRun.plot(kind='line', y=['so_litri_runoff'], ax=host,linewidth=3,  label=['Runoff sim.'],rot = 30,
        color=['red'],alpha = 0.75)
dfRun.plot(kind='line', y=['obs_runoff_cum','so_runoff_cum'], ax=par1,linewidth=3, label=['Obs. cum.','Sim. cum.'],rot = -0,
         color=['gray','orange'],alpha = 1)
dfRun.plot(kind='line', y=['obs_litri_runoff'], ax=host,linewidth=3, label=['Runoff obs.'],rot = 30,
         color=['k'],alpha = 0.5)
par2.plot(dfRun.index,-dfRun['prp'],label='Rainfall',color="blue",linewidth=3)

host.set_ylim(0, 120)
par1.set_ylim(0, 120)
par2.set_ylim(-80, 0)

host.set_xlabel('Date',fontsize=30)
host.set_ylabel('Runoff [l/s]',fontsize=30)
par1.set_ylabel('Cumulated Runoff [10$^{3}$ m$^{3}$]',fontsize=30)
par2.set_ylabel('Rainfall [mm]',fontsize=30)
plt.title('Runoff - Prospero \n \n',size=30)

tkw = dict(size=4, width=1.5)
host.tick_params(axis='y')#, colors=p1.get_color(), **tkw)
par1.tick_params(axis='y')#, colors=p2.get_color(), **tkw)
par2.tick_params(axis='y')#, colors=p3.get_color(), **tkw)
host.tick_params(axis='x')#, **tkw)

y2_ticks = np.linspace(80,0, 9)
y2_ticklabels = [str(i) for i in y2_ticks]
par2.set_yticklabels(y2_ticklabels)

ax11.legend(loc='upper left',fontsize=15)
for ax in [ host,par1, par2]:
    ax.set_xlabel('Date',fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 30) 
    
host.legend(loc='upper center',fontsize=30, bbox_to_anchor=(0.15, 1.07), ncol=2, frameon =False)
par1.legend(loc='upper right',fontsize=30, bbox_to_anchor=(0.8, 1.07), ncol=2, frameon =False)
par2.legend(loc='upper left',fontsize=30, bbox_to_anchor=(0.85, 1.07), ncol=1, frameon =False)

plt.show()

# %%
dfRun[['obs_runoff_cum','so_runoff_cum']].tail(1)
# Out:
#                      obs_runoff_cum  so_runoff_cum
# Date
# 2017-12-12 11:00:00       65.646145      81.744677
