# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import os
import glob

# %%
os.getcwd()
# Out:
# '/home/drugo/Sim/RRRDP/data/RioRessi/1'

# %%
dateparseD = lambda x: pd.datetime.strptime(x, '%d/%m/%Y %H:%M')
dateparseM = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
dateparseY = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M')

# df = pd.read_csv(infile, parse_dates=['datetime'], date_parser=dateparse)

# %%
path = "/home/drugo/Sim/RRRDP/"                
os.chdir(path)

# %%
cd data/RioRessi/1/
# Out:
# /home/drugo/Sim/RRRDP/data/RioRessi/1

# %%
ls
# Out:
# build/           nse_prova.csv                   simulation/
# build.xml        oms_console/                    simulation_Noce/
# data/            output/                         simulation_ReDellaPietra/
# DataRessi.ipynb  PRP-FLOW Re della pietra.ipynb  simulation_RioRessi/
# dist/            PRP-FLOW Ressi.ipynb            simulation_setup/
# graph.jar        prpKriging.ipynb                src/
# lib/             rioressiDataReader.ipynb        Untitled.ipynb
# nbproject/       rioressi output Reader.ipynb
# NOCE/            rioressiReader.ipynb

# %% [markdown]
# # ET

# %%
os.getcwd()
# Out:
# '/home/drugo/Sim/RRRDP'

# %%
os.chdir('/home/drugo/Sim/RRRDP/')

# %%
dfET_PT= pd.read_csv('data/RioRessi/1/RioRessi_ET_PT.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfET_PT.columns = ['','Date','ET_PT']
dfET_PT.index = dfET_PT['Date']
dfET_PT = dfET_PT.iloc[:,2:]
dfET_PT.head()
# Out:
#                      ET_PT
# Date
# 2012-08-01 00:00:00    0.0
# 2012-08-01 01:00:00    0.0
# 2012-08-01 02:00:00    0.0
# 2012-08-01 03:00:00    0.0
# 2012-08-01 04:00:00    0.0

# %%
dfET_FAO= pd.read_csv('data/RioRessi/1/RioRessi_ET_FAO.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfET_FAO.columns = ['','Date','ET_FAO']
dfET_FAO.index = dfET_FAO['Date']
dfET_FAO = dfET_FAO.iloc[:,2:]
dfET_FAO.head()
# Out:
#                        ET_FAO
# Date
# 2012-08-01 00:00:00  0.011039
# 2012-08-01 01:00:00  0.009415
# 2012-08-01 02:00:00  0.011049
# 2012-08-01 03:00:00  0.013671
# 2012-08-01 04:00:00  0.010506

# %%
dfET_SO= pd.read_csv('output/RioRessiOut/RioRessi_Transpiration.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfET_SO.columns = ['','Date','ET SO']
dfET_SO.index = dfET_SO['Date']
dfET_SO = dfET_SO.iloc[:,2:]
dfET_SO.head()
# Out:
#                      ET SO
# Date
# 2012-08-01 00:00:00    NaN
# 2012-08-01 01:00:00    NaN
# 2012-08-01 02:00:00    NaN
# 2012-08-01 03:00:00    NaN
# 2012-08-01 04:00:00    NaN

# %%
dfET_SO_G= pd.read_csv('output/RioRessiOut/RioRessi_Transpiration_Grass.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfET_SO_G.columns = ['','Date','ET SO G']
dfET_SO_G.index = dfET_SO_G['Date']
dfET_SO_G = dfET_SO_G.iloc[:,2:]
dfET_SO_G.head()
# Out:
#                      ET SO G
# Date
# 2012-08-01 00:00:00      NaN
# 2012-08-01 01:00:00      NaN
# 2012-08-01 02:00:00      NaN
# 2012-08-01 03:00:00      NaN
# 2012-08-01 04:00:00      NaN

# %%
# dfET_SO_SH= pd.read_csv('output/RioRessiOut/RioRessi_ET_SO_Shadow.csv', parse_dates=['yyyy-MM-dd HH:mm'],
#                  sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
# dfET_SO_SH.columns = ['','Date','ET SO SH']
# dfET_SO_SH.index = dfET_SO_SH['Date']
# dfET_SO_SH = dfET_SO_SH.iloc[:,2:]
# dfET_SO_SH.head()

# %%
dfET = pd.concat([dfET_PT,dfET_FAO,dfET_SO,dfET_SO_G],axis=1)
# dfET = pd.concat([dfET_PT,dfET_FAO,dfET_SO_SUN,dfET_SO_SH],axis=1)
# dfET['SO'] = dfET['ET SO SUN'] + dfET['ET SO SH']

# %%
dfET
# Out:
#                         ET_PT    ET_FAO     ET SO   ET SO G
# Date
# 2012-08-01 00:00:00  0.000000  0.011039       NaN       NaN
# 2012-08-01 01:00:00  0.000000  0.009415       NaN       NaN
# 2012-08-01 02:00:00  0.000000  0.011049       NaN       NaN
# 2012-08-01 03:00:00  0.000000  0.013671       NaN       NaN
# 2012-08-01 04:00:00  0.000000  0.010506       NaN       NaN
# 2012-08-01 05:00:00  0.000374  0.015346       NaN       NaN
# 2012-08-01 06:00:00  0.000374  0.017551  0.053212  0.051168
# 2012-08-01 07:00:00  0.000973  0.004931  0.071345  0.056855
# 2012-08-01 08:00:00  0.000973  0.001951  0.053085  0.036080
# 2012-08-01 09:00:00  0.000973  0.009689  0.188320  0.115428
# 2012-08-01 10:00:00  0.000973  0.015886  0.267255  0.153749
# 2012-08-01 11:00:00  0.000973  0.029108  0.373832  0.207440
# 2012-08-01 12:00:00  0.000973  0.050568  0.473049  0.258031
# 2012-08-01 13:00:00  0.000973  0.066811  0.502295  0.274171
# 2012-08-01 14:00:00  0.000973  0.054009  0.415356  0.231389
# 2012-08-01 15:00:00  0.000973  0.056339  0.396619  0.230513
# 2012-08-01 16:00:00  0.000973  0.040771  0.268982  0.168182
# 2012-08-01 17:00:00  0.000973  0.023728  0.133098  0.093640
# 2012-08-01 18:00:00  0.000374  0.026151  0.042543  0.035622
# 2012-08-01 19:00:00  0.000374  0.018887  0.014019  0.013887
# 2012-08-01 20:00:00  0.000000  0.017659       NaN       NaN
# 2012-08-01 21:00:00  0.000000  0.017093       NaN       NaN
# 2012-08-01 22:00:00  0.000000  0.015798       NaN       NaN
# 2012-08-01 23:00:00  0.000000  0.015383       NaN       NaN
# 2012-08-02 00:00:00  0.000000  0.014755       NaN       NaN
# 2012-08-02 01:00:00  0.000000  0.018229       NaN       NaN
# 2012-08-02 02:00:00  0.000000  0.011785       NaN       NaN
# 2012-08-02 03:00:00  0.000000  0.012240       NaN       NaN
# 2012-08-02 04:00:00  0.000000  0.013630       NaN       NaN
# 2012-08-02 05:00:00  0.000374  0.015478       NaN       NaN
# ...                       ...       ...       ...       ...
# 2019-05-09 18:00:00  0.000000  0.008934  0.033165  0.029235
# 2019-05-09 19:00:00  0.000000  0.005265  0.004206  0.004203
# 2019-05-09 20:00:00  0.000000  0.004376       NaN       NaN
# 2019-05-09 21:00:00  0.000000  0.004607       NaN       NaN
# 2019-05-09 22:00:00  0.000000  0.003855       NaN       NaN
# 2019-05-09 23:00:00  0.000000  0.002973       NaN       NaN
# 2019-05-10 00:00:00  0.000000  0.002589       NaN       NaN
# 2019-05-10 01:00:00  0.000000  0.001592       NaN       NaN
# 2019-05-10 02:00:00  0.000000  0.001502       NaN       NaN
# 2019-05-10 03:00:00  0.000000  0.001508       NaN       NaN
# 2019-05-10 04:00:00  0.000000  0.001413       NaN       NaN
# 2019-05-10 05:00:00  0.000000  0.001283  0.005861  0.005861
# 2019-05-10 06:00:00  0.005389  0.008107  0.034459  0.032411
# 2019-05-10 07:00:00  0.035934  0.046387  0.074603  0.058503
# 2019-05-10 08:00:00  0.049737  0.064350  0.106953  0.072814
# 2019-05-10 09:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 10:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 11:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 12:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 13:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 14:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 15:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 16:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 17:00:00  0.000973  0.012547  0.000000  0.000000
# 2019-05-10 18:00:00  0.000374  0.011843  0.000000  0.000000
# 2019-05-10 19:00:00  0.000374  0.011843  0.000000  0.000000
# 2019-05-10 20:00:00  0.000374  0.011843       NaN       NaN
# 2019-05-10 21:00:00  0.000374  0.011843       NaN       NaN
# 2019-05-10 22:00:00  0.000374  0.011843       NaN       NaN
# 2019-05-10 23:00:00  0.000374  0.011843       NaN       NaN
#
# [59376 rows x 4 columns]

# %%
dfET[['ET_PT']].plot()
dfET[['ET_FAO']].plot()
dfET[['ET SO']].plot()
dfET[['ET SO G']].plot()

# %%
dfETY = dfET.resample('Y').agg('sum')

# %%
dfETY
# Out:
#                  ET_PT      ET_FAO       ET SO     ET SO G
# Date
# 2012-12-31   74.583479  121.894127  208.444034  134.865328
# 2013-12-31  332.894410  414.868524  581.405717  364.399826
# 2014-12-31  320.385423  451.615860  534.432013  338.812518
# 2015-12-31  376.082371  458.802481  645.697347  407.690339
# 2016-12-31  365.704046  353.974824  595.237596  374.259487
# 2017-12-31  412.560819  583.096195  687.184848  428.923480
# 2018-12-31  376.034497  522.292308  605.019870  377.261399
# 2019-12-31   76.525370  129.538469  153.094738  101.110101

# %% [markdown]
# # Latent heat

# %% [markdown]
# # ET

# %%
os.getcwd()
# Out:
# '/home/drugo/Sim/RRRDP'

# %%
os.chdir('/home/drugo/Sim/RRRDP/')

# %%
dfEL_PT= pd.read_csv('data/RioRessi/1/RioRessi_latentHeat_PT.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfEL_PT.columns = ['','Date','EL PT']
dfEL_PT.index = dfEL_PT['Date']
dfEL_PT = dfEL_PT.iloc[:,2:]
dfEL_PT.head()
# Out:
#                      EL PT
# Date
# 2012-08-01 00:00:00    NaN
# 2012-08-01 01:00:00    NaN
# 2012-08-01 02:00:00    NaN
# 2012-08-01 03:00:00    NaN
# 2012-08-01 04:00:00    NaN

# %%
dfEL_FAO= pd.read_csv('data/RioRessi/1/RioRessi_latentHeat_PT.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfEL_FAO.columns = ['','Date','EL FAO']
dfEL_FAO.index = dfEL_FAO['Date']
dfEL_FAO = dfEL_FAO.iloc[:,2:]
dfEL_FAO.head()
# Out:
#                      EL FAO
# Date
# 2012-08-01 00:00:00     NaN
# 2012-08-01 01:00:00     NaN
# 2012-08-01 02:00:00     NaN
# 2012-08-01 03:00:00     NaN
# 2012-08-01 04:00:00     NaN

# %%
dfEL_SO= pd.read_csv('output/RioRessiOut/RioRessi_ET_SO.csv', parse_dates=['yyyy-MM-dd HH:mm'],
                 sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
dfEL_SO.columns = ['','Date','EL SO']
dfEL_SO.index = dfEL_SO['Date']
dfEL_SO = dfEL_SO.iloc[:,2:]
dfEL_SO.head()
# Out:
#                      EL SO
# Date
# 2012-08-01 00:00:00    NaN
# 2012-08-01 01:00:00    NaN
# 2012-08-01 02:00:00    NaN
# 2012-08-01 03:00:00    NaN
# 2012-08-01 04:00:00    NaN

# %%
# dfET_SO_SH= pd.read_csv('output/RioRessiOut/RioRessi_ET_SO_Shadow.csv', parse_dates=['yyyy-MM-dd HH:mm'],
#                  sep=',',skiprows=6,low_memory=False, na_values=-9999)#, date_parser=dateparseD)
# dfET_SO_SH.columns = ['','Date','ET SO SH']
# dfET_SO_SH.index = dfET_SO_SH['Date']
# dfET_SO_SH = dfET_SO_SH.iloc[:,2:]
# dfET_SO_SH.head()

# %%
dfEL = pd.concat([dfEL_PT,dfEL_FAO,dfEL_SO],axis=1)
# dfET = pd.concat([dfET_PT,dfET_FAO,dfET_SO_SUN,dfET_SO_SH],axis=1)
# dfET['SO'] = dfET['ET SO SUN'] + dfET['ET SO SH']

# %%
dfEL
# Out:
#                      EL PT  EL FAO       EL SO
# Date
# 2012-08-01 00:00:00    NaN     NaN         NaN
# 2012-08-01 01:00:00    NaN     NaN         NaN
# 2012-08-01 02:00:00    NaN     NaN         NaN
# 2012-08-01 03:00:00    NaN     NaN         NaN
# 2012-08-01 04:00:00    NaN     NaN         NaN
# 2012-08-01 05:00:00    NaN     NaN         NaN
# 2012-08-01 06:00:00    NaN     NaN   36.213434
# 2012-08-01 07:00:00    NaN     NaN   48.554107
# 2012-08-01 08:00:00    NaN     NaN   36.127093
# 2012-08-01 09:00:00    NaN     NaN  128.162461
# 2012-08-01 10:00:00    NaN     NaN  181.882048
# 2012-08-01 11:00:00    NaN     NaN  254.413540
# 2012-08-01 12:00:00    NaN     NaN  321.936175
# 2012-08-01 13:00:00    NaN     NaN  341.839483
# 2012-08-01 14:00:00    NaN     NaN  282.672780
# 2012-08-01 15:00:00    NaN     NaN  269.921336
# 2012-08-01 16:00:00    NaN     NaN  183.057121
# 2012-08-01 17:00:00    NaN     NaN   90.580695
# 2012-08-01 18:00:00    NaN     NaN   28.952974
# 2012-08-01 19:00:00    NaN     NaN    9.540404
# 2012-08-01 20:00:00    NaN     NaN         NaN
# 2012-08-01 21:00:00    NaN     NaN         NaN
# 2012-08-01 22:00:00    NaN     NaN         NaN
# 2012-08-01 23:00:00    NaN     NaN         NaN
# 2012-08-02 00:00:00    NaN     NaN         NaN
# 2012-08-02 01:00:00    NaN     NaN         NaN
# 2012-08-02 02:00:00    NaN     NaN         NaN
# 2012-08-02 03:00:00    NaN     NaN         NaN
# 2012-08-02 04:00:00    NaN     NaN         NaN
# 2012-08-02 05:00:00    NaN     NaN         NaN
# ...                    ...     ...         ...
# 2019-05-09 18:00:00    0.0     0.0   22.570635
# 2019-05-09 19:00:00    0.0     0.0    2.862754
# 2019-05-09 20:00:00    0.0     0.0         NaN
# 2019-05-09 21:00:00    0.0     0.0         NaN
# 2019-05-09 22:00:00    0.0     0.0         NaN
# 2019-05-09 23:00:00    0.0     0.0         NaN
# 2019-05-10 00:00:00    0.0     0.0         NaN
# 2019-05-10 01:00:00    0.0     0.0         NaN
# 2019-05-10 02:00:00    0.0     0.0         NaN
# 2019-05-10 03:00:00    0.0     0.0         NaN
# 2019-05-10 04:00:00    0.0     0.0         NaN
# 2019-05-10 05:00:00    0.0     0.0    3.988479
# 2019-05-10 06:00:00    0.0     0.0   23.451208
# 2019-05-10 07:00:00    0.0     0.0   50.771355
# 2019-05-10 08:00:00    0.0     0.0   72.787403
# 2019-05-10 09:00:00    NaN     NaN    0.000000
# 2019-05-10 10:00:00    NaN     NaN    0.000000
# 2019-05-10 11:00:00    NaN     NaN    0.000000
# 2019-05-10 12:00:00    NaN     NaN    0.000000
# 2019-05-10 13:00:00    NaN     NaN    0.000000
# 2019-05-10 14:00:00    NaN     NaN    0.000000
# 2019-05-10 15:00:00    NaN     NaN    0.000000
# 2019-05-10 16:00:00    NaN     NaN    0.000000
# 2019-05-10 17:00:00    NaN     NaN    0.000000
# 2019-05-10 18:00:00    NaN     NaN    0.000000
# 2019-05-10 19:00:00    NaN     NaN    0.000000
# 2019-05-10 20:00:00    NaN     NaN         NaN
# 2019-05-10 21:00:00    NaN     NaN         NaN
# 2019-05-10 22:00:00    NaN     NaN         NaN
# 2019-05-10 23:00:00    NaN     NaN         NaN
#
# [59376 rows x 3 columns]

# %%
dfEL[['EL PT']].plot()
dfEL[['EL FAO']].plot()
dfEL[['EL SO']].plot()
